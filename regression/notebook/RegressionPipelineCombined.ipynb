# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score, f1_score, precision_recall_fscore_support
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report

# %%
pd.set_option('max_columns', None)

# %%
combined_data_file = "../../data/Data-Jul16/combined_jul16.csv"
data_2020_file = "../../data/Data-Jul16/F20_jul05.csv"
data_historical = pd.read_csv(combined_data_file, encoding = "ISO-8859-1")

# %%
data_2020 = pd.read_csv(data_2020_file, encoding = "ISO-8859-1")
data_2016 = data_historical.loc[data_historical['YEAR'] == 2016]
data_2012 = data_historical.loc[data_historical['YEAR'] == 2012]
data_2008 = data_historical.loc[data_historical['YEAR'] == 2008]

year_df_dict = {2020:data_2020, 2016:data_2016, 2012:data_2012, 2008:data_2008}

# %%
data_historical['COUNTY_TOTALVOTES'] = data_historical['COUNTY_TOTALVOTES'].astype(np.int64)

# %% [markdown]
# ### PrepData###

# %%
data_historical['REP_VOTES%'] = data_historical['REP_VOTES'] / data_historical['COUNTY_TOTALVOTES']
data_historical['DEM_VOTES%'] = data_historical['DEM_VOTES'] / data_historical['COUNTY_TOTALVOTES']
data_2020['REP_VOTES%'] = data_2020['REP_VOTES'] / data_2020['COUNTY_TOTALVOTES']
data_2020['DEM_VOTES%'] = data_2020['DEM_VOTES']/ data_2020['COUNTY_TOTALVOTES']

# %%
data_historical.drop(['REP_VOTES', 'DEM_VOTES'], axis=1, inplace=True)
data_2020.drop(['REP_VOTES', 'DEM_VOTES'], axis=1, inplace=True)

# %%
data_historical.drop(['WINNING_CANDIDATE', 'WINNING_PARTY_BINARY', 'REP_CANDIDATE', 'DEM_CANDIDATE', 'AVG_WAGE_SALARY', 'WINNING_PARTY', 'COUNTY', 'STATE', 'REP_VOTES%', 'DEM_VOTES%', 'MARGIN_VICTORY'], axis=1, inplace=True)

# %%
def train_test_split_by_year(X, y, year, cols=None):
    
    if year != None:
        year_filter =  X['YEAR'] < year
        X = X[year_filter]
        y = y[year_filter]
        
    X = X.drop('YEAR', axis=1)
    y = np.delete(y, 1, axis=1)
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    
    if (cols == None):
        return X_train, X_test, y_train, y_test
    else:
        return X_train[cols], X_test[cols], y_train, y_test

# %% [markdown]
# # Step 1 #

# %% [markdown]
# ### Build/Train Model#1: Linear regression to preidct total votes by county###

# %%
year = 2020
target_df = year_df_dict.get(year)

# %%
X = data_historical.drop(['COUNTY_TOTALVOTES'], axis=1)
y = data_historical[['COUNTY_TOTALVOTES', 'YEAR']].values

# %%
X_train, X_test, y_train, y_test = train_test_split_by_year(X, y, year)

# %%
linear_model = LinearRegression()

# %%
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = linear_model.predict(X_test)

# %%
print("Accuracy score={:.2f}".format(linear_model.score(X_test, y_test) * 100))
# Out:
# Accuracy score=98.76

# %% [markdown]
# ### Generate Total Votes Predictions by County###

# %%
target_df.drop(['COUNTY_TOTALVOTES'], inplace=True, axis=1, errors='ignore')

# %%
target_df.drop(['ID', 'YEAR', 'Unnamed: 0', 'Unnamed: 0.1', 'WINNING_CANDIDATE', 'WINNING_PARTY_BINARY', 'REP_CANDIDATE', 'DEM_CANDIDATE', 'WINNING_PARTY', 'COUNTY', 'STATE', 'REP_VOTES%', 'DEM_VOTES%', 'REP_VOTES', 'DEM_VOTES', 'COUNTY_TOTALVOTES', 'MARGIN_VICTORY', 'AVG_WAGE_SALARY'], axis=1, inplace=True, errors='ignore')

# %%
y_pred_target = linear_model.predict(target_df)

# %%
#merge predictions with the target dataset. 
target_df['COUNTY_TOTALVOTES'] = y_pred_target

# %%
target_df['COUNTY_TOTALVOTES'] = target_df['COUNTY_TOTALVOTES'].astype(np.int64)

# %%
import datetime

x = datetime.datetime.now()
day = x.day
month = x.month

date_str = str(month) + str(day)

# %%
#save file (will be used by next step in the pipeline)
filename_step1 = '../../data/F20_step1_output_' + date_str + '.csv'
target_df.to_csv(filename_step1)

# %% [markdown]
# # Step 2 #

# %%
# start clean and reimport everything again. 
data = pd.read_csv(combined_data_file, encoding = "ISO-8859-1")

# %%
data_2020 = pd.read_csv(data_2020_file, encoding = "ISO-8859-1")
data_2016 = data.loc[data['YEAR'] == 2016]
data_2012 = data.loc[data['YEAR'] == 2012]
data_2008 = data.loc[data['YEAR'] == 2008]

# %% [markdown]
# ### Build/Train Model#2: Random Forest Classifier to predict County Winner###

# %%
data.drop(['REP_VOTES', 'DEM_VOTES', 'MARGIN_VICTORY', 'WINNING_CANDIDATE', 'REP_CANDIDATE', 'DEM_CANDIDATE', 'WINNING_PARTY', 'COUNTY', 'STATE'], axis=1, inplace=True)
data.drop(['AA_FEMALE', 'AA_MALE', 'BA_FEMALE', 'BA_MALE', 'H_FEMALE', 'H_MALE', 'IA_FEMALE', 'IA_MALE', 'NA_FEMALE', 'NA_MALE' , 'TOT_FEMALE', 'TOT_MALE', 'TOT_POP', 'WA_FEMALE', 'WA_MALE', 'TOT_POP_LESS19', 'TOT_MALE_LESS19', 'TOT_FEMALE_LESS19', 'TOT_POP_20to39', 'TOT_MALE_20to39', 'TOT_FEMALE_20to39', 'TOT_POP_40to59', 'TOT_MALE_40to59', 'TOT_FEMALE_40to59', 'TOT_POP_Above60', 'TOT_MALE_Above60', 'TOT_FEMALE_Above60'] , axis=1, inplace=True)

# %%
significant_cols = [
 'STATE_FIPS',
 'COUNTY_FIPS',
 'COUNTY_TOTALVOTES',
 'HOUSE_WINNING_BINARY',
 'SENATE_WINNING_BINARY',
 'UNEMPLOYMENT_RATE',
 'BA_FEMALE%',
 'BA_MALE%',
 'H_FEMALE%',
 'IA_FEMALE%',
 'WA_FEMALE%',
 'WA_MALE%',
 'TOT_FEMALE%',
 'TOT_MALE%',
 'TOT_POP_LESS19%',
 'TOT_POP_40to59%',
 'TOT_POP_Above60%']

# %%
X = data.drop('WINNING_PARTY_BINARY', axis=1)
y = data[['WINNING_PARTY_BINARY', 'YEAR']].values

X_train, X_test, y_train, y_test = train_test_split_by_year(X, y, year, significant_cols)

# %%
rfc4 = RandomForestClassifier(n_estimators=10).fit(X_train, y_train)

rfc_pred4= rfc4.predict(X_test)

print("Experiment#rfc4: {:.3f}%".format(accuracy_score(y_test, rfc_pred4) * 100))
# Out:
# /Users/eelrufaie/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# Experiment#rfc4: 89.153%

# %%
print(classification_report(y_test, rfc_pred4))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.64      0.72      1006
#            1       0.91      0.96      0.93      3714
#
#    micro avg       0.89      0.89      0.89      4720
#    macro avg       0.86      0.80      0.82      4720
# weighted avg       0.89      0.89      0.89      4720

# %% [markdown]
# ### Predict County winner ###

# %%
target_year_data = pd.read_csv(filename_step1, encoding = "ISO-8859-1")

# %%
## use with significant model only..
## for now drop AVG_WAGE_SALARY till data is fixed. 
data_significant = target_year_data[[
 'STATE_FIPS',
 'COUNTY_FIPS',
 'COUNTY_TOTALVOTES',
 'HOUSE_WINNING_BINARY',
 'SENATE_WINNING_BINARY',
 'UNEMPLOYMENT_RATE',
 'BA_FEMALE%',
 'BA_MALE%',
 'H_FEMALE%',
 'IA_FEMALE%',
 'WA_FEMALE%',
 'WA_MALE%',
 'TOT_FEMALE%',
 'TOT_MALE%',
 'TOT_POP_LESS19%',
 'TOT_POP_40to59%',
 'TOT_POP_Above60%']]

# %%
y_pred = rfc4.predict(data_significant)

# %%
target_year_data['WINNING_PARTY_BINARY'] = y_pred

# %%
#save to csv
filename_step2 = '../../data/F20_step2_output_' + date_str + '.csv'
target_year_data.to_csv(filename_step2)

# %% [markdown]
# # Step 3

# %% [markdown]
# ### Build/Train Model#3: Linear Regression to predict R/D Votes for every county###

# %%
votes_historcail_df = pd.read_csv(combined_data_file, encoding = "ISO-8859-1")
votes_df = pd.read_csv(filename_step2)

# %%
votes_historcail_df_copy = votes_historcail_df[['YEAR','STATE_FIPS', 'COUNTY_FIPS', 'COUNTY_TOTALVOTES', 'WINNING_PARTY_BINARY', 'REP_VOTES']]

# %%
votes_historcail_df_copy['REP_VOTES%'] = votes_historcail_df_copy['REP_VOTES'] / votes_historcail_df_copy['COUNTY_TOTALVOTES']
votes_historcail_df_copy.drop('REP_VOTES', axis=1, inplace=True)
# Out:
# /Users/eelrufaie/Library/Python/3.7/lib/python/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /Users/eelrufaie/Library/Python/3.7/lib/python/site-packages/pandas/core/frame.py:3997: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X = votes_historcail_df_copy.drop(['REP_VOTES%'], axis=1)
y = votes_historcail_df_copy[['REP_VOTES%', 'YEAR']].values

# %%
X_train, X_test, y_train, y_test = train_test_split_by_year(X, y, year)

# %%
linear_model = LinearRegression()
linear_model.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None,
#          normalize=False)

# %%
y_pred = linear_model.predict(X_test)

# %%
print("Accuracy score={:.2f}".format(linear_model.score(X_test, y_test) * 100))
# Out:
# Accuracy score=55.64

# %%
from sklearn import metrics
print('Mean Absolute Error:', metrics.mean_absolute_error(y_test, y_pred))
print('Mean Squared Error:', metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# Mean Absolute Error: 0.076685018440759
# Mean Squared Error: 0.009344243792511753
# Root Mean Squared Error: 0.09666562880627091

# %% [markdown]
# ### Predict R and D Total votes per County###

# %%
votes_df_copy = votes_df[['STATE_FIPS', 'COUNTY_FIPS', 'COUNTY_TOTALVOTES', 'WINNING_PARTY_BINARY']]

# %%
y_pred = linear_model.predict(votes_df_copy)

# %%
target_year_data['REP_VOTES%'] = y_pred

# %%
#info D total votes. 
target_year_data['DEM_VOTES%'] = 1 - target_year_data['REP_VOTES%']

# %%
target_year_data['REP_VOTES'] = target_year_data['REP_VOTES%'] * target_year_data['COUNTY_TOTALVOTES']
target_year_data['DEM_VOTES'] = target_year_data['DEM_VOTES%'] * target_year_data['COUNTY_TOTALVOTES']

# %%
target_year_data['REP_VOTES'] = target_year_data['REP_VOTES'].astype(np.int64)
target_year_data['DEM_VOTES'] = target_year_data['DEM_VOTES'].astype(np.int64)

# %%
#save to csv
filename_step3 = '../../data/F20_step3_output_' + date_str + '.csv'
target_year_data.to_csv(filename_step3)

# %% [markdown]
# # Step 4

# %% [markdown]
# ### Calculate Winner###

# %%
electoral_ref = pd.read_excel('../../data/Electoral College Votes.xlsx')
target_data = pd.read_csv(filename_step3)
data_historical = pd.read_csv(combined_data_file, encoding = "ISO-8859-1")
states_aggr = pd.read_csv('../../data/state_aggregated_0726.csv')

# %%
states_aggr
# Out:
#      YEAR  STATE_FIPS          STATE TOTAL_DEM_VOTES TOTAL_REP_VOTES  \
# 0    2012           1        Alabama         795,696       1,255,925
# 1    2012           2         Alaska         142,458         192,750
# 2    2012           4        Arizona       1,025,232       1,233,654
# 3    2012           5       Arkansas         394,409         647,744
# 4    2012           6     California       7,854,285       4,839,958
# ..    ...         ...            ...             ...             ...
# 308  2020          51       Virginia             NaN             NaN
# 309  2020          53     Washington             NaN             NaN
# 310  2020          54  West Virginia             NaN             NaN
# 311  2020          55      Wisconsin             NaN             NaN
# 312  2020          56        Wyoming             NaN             NaN
#
#     TOTAL_VOTES  MARGIN_VICTORY  ABS_MARGIN_VICTORY  WINNING_PARTY  \
# 0     2,051,621        0.224325            0.224325            1.0
# 1       335,208        0.150032            0.150032            1.0
# 2     2,258,886        0.092268            0.092268            1.0
# 3     1,042,153        0.243088            0.243088            1.0
# 4    12,694,243       -0.237456            0.237456            0.0
# ..          ...             ...                 ...            ...
# 308         NaN             NaN                 NaN            NaN
# 309         NaN             NaN                 NaN            NaN
# 310         NaN             NaN                 NaN            NaN
# 311         NaN             NaN                 NaN            NaN
# 312         NaN             NaN                 NaN            NaN
#
#      ELECTORAL_VOTES    TOP_TOPIC
# 0                  9      Economy
# 1                  3      Economy
# 2                 11      Economy
# 3                  6      Economy
# 4                 55      Economy
# ..               ...          ...
# 308               13      Economy
# 309               12      Economy
# 310                5      Economy
# 311               10  Immigration
# 312                3      Economy
#
# [313 rows x 11 columns]

# %%
### 1) create a new df with StateFips/Count
state_fips_map = {}
for index, row in data_historical.iterrows():
    state = row['STATE']
    if (state_fips_map.get(state) == None):
        state_fips_map[state] = row['STATE_FIPS']
        
state_fips_df = pd.DataFrame(list(state_fips_map.items()), columns=['STATE','STATE_FIPS'])

# %%
df = electoral_ref.merge(state_fips_df, left_on='STATE', right_on='STATE')

# %%
target_data.drop('Unnamed: 0', inplace=True, axis=1)

# %%
"""extract how counties prediction for every state"""
visited = {}
electoral_votes = {'D':0, 'R':0 }
for index, row in target_data.iterrows():
    state = int(row['STATE_FIPS'])
    
    rep_votes = int(row['REP_VOTES'])
    dem_votes = int(row['DEM_VOTES'])

    if (visited.get(state) == None):
        electoral_votes = {'D': dem_votes, 'R': rep_votes }
        visited[state] = electoral_votes
    else:
        #update existing map
        current_votes = visited.get(state)
        current_r = current_votes.get('R')
        current_d = current_votes.get('D')
        total_dem = current_d + dem_votes
        total_rep = current_r + rep_votes
        electoral_votes = {'D': total_dem, 'R': total_rep }
        visited[state] = electoral_votes

# %%
votes_pred_df = pd.DataFrame(list(visited.items()), columns=['STATE_FIPS','PRED_VOTES'])

# %%
for index, row in votes_pred_df.iterrows():
    key_val = row['PRED_VOTES']
    d_votes = key_val.get('D')
    r_votes = key_val.get('R')
    votes_pred_df.loc[index, 'PRED_DEM_VOTES'] = key_val.get('D')
    votes_pred_df.loc[index, 'PRED_REP_VOTES'] = key_val.get('R')

# %%
votes_pred_df.drop('PRED_VOTES', inplace=True, axis=1)
votes_pred_df['PRED_DEM_VOTES'] = votes_pred_df['PRED_DEM_VOTES'].astype(np.int64)
votes_pred_df['PRED_REP_VOTES'] = votes_pred_df['PRED_REP_VOTES'].astype(np.int64)
votes_pred_df
# Out:
#     STATE_FIPS  PRED_DEM_VOTES  PRED_REP_VOTES
# 0            1         1037054         1083735
# 1            2          242744          223455
# 2            4         1779734          820395
# 3            5          504135          715696
# 4            6        10310902         3766648
# 5            8         1438440         1081870
# 6            9         1009105          628031
# 7           10          254355          191128
# 8           11          175106           99503
# 9           12         4778981         4164215
# 10          13         2481183         2176821
# 11          15          275174          161201
# 12          16          352606          453046
# 13          17         3407080         1997317
# 14          18         1280069         1624800
# 15          19          687180          885855
# 16          20          678273          783093
# 17          21          909870         1136565
# 18          22          928694          957437
# 19          23          339919          346877
# 20          24         1542211         1104639
# 21          25         1839449         1338228
# 22          26         2347027         2328821
# 23          27         1348395         1299551
# 24          28          499957          683966
# 25          29         1312314         1429981
# 26          30          193386          338412
# 27          31          404417          471848
# 28          32          778449          442180
# 29          33          360671          350917
# 30          34         2093826         1704839
# 31          35          358547          341786
# 32          36         4748238         3295141
# 33          37         2265045         2332583
# 34          38          137653          240314
# 35          39         2411058         2887223
# 36          40          539277          870006
# 37          41          985283          860764
# 38          42         2783074         3037659
# 39          44          291387          192688
# 40          45         1105509         1105988
# 41          46          180472          288514
# 42          47         1240851         1692049
# 43          48         5148690         4746269
# 44          49          384010          648731
# 45          50          180784          121856
# 46          51         1899056         1972977
# 47          53         1903998         1322014
# 48          54          272345          489903
# 49          55         1206508         1490251
# 50          56           70504          131363

# %%
"""determine the winner of every state"""
for index, row in votes_pred_df.iterrows():
    
    total_r = row['PRED_REP_VOTES']
    total_d = row['PRED_DEM_VOTES']
    
    votes_pred_df.loc[index, 'PRED_WINNING_PARTY'] = '0' if total_d > total_r else '1'

# %%
votes_pred_df
# Out:
#     STATE_FIPS  PRED_DEM_VOTES  PRED_REP_VOTES PRED_WINNING_PARTY
# 0            1         1037054         1083735                  1
# 1            2          242744          223455                  0
# 2            4         1779734          820395                  0
# 3            5          504135          715696                  1
# 4            6        10310902         3766648                  0
# 5            8         1438440         1081870                  0
# 6            9         1009105          628031                  0
# 7           10          254355          191128                  0
# 8           11          175106           99503                  0
# 9           12         4778981         4164215                  0
# 10          13         2481183         2176821                  0
# 11          15          275174          161201                  0
# 12          16          352606          453046                  1
# 13          17         3407080         1997317                  0
# 14          18         1280069         1624800                  1
# 15          19          687180          885855                  1
# 16          20          678273          783093                  1
# 17          21          909870         1136565                  1
# 18          22          928694          957437                  1
# 19          23          339919          346877                  1
# 20          24         1542211         1104639                  0
# 21          25         1839449         1338228                  0
# 22          26         2347027         2328821                  0
# 23          27         1348395         1299551                  0
# 24          28          499957          683966                  1
# 25          29         1312314         1429981                  1
# 26          30          193386          338412                  1
# 27          31          404417          471848                  1
# 28          32          778449          442180                  0
# 29          33          360671          350917                  0
# 30          34         2093826         1704839                  0
# 31          35          358547          341786                  0
# 32          36         4748238         3295141                  0
# 33          37         2265045         2332583                  1
# 34          38          137653          240314                  1
# 35          39         2411058         2887223                  1
# 36          40          539277          870006                  1
# 37          41          985283          860764                  0
# 38          42         2783074         3037659                  1
# 39          44          291387          192688                  0
# 40          45         1105509         1105988                  1
# 41          46          180472          288514                  1
# 42          47         1240851         1692049                  1
# 43          48         5148690         4746269                  0
# 44          49          384010          648731                  1
# 45          50          180784          121856                  0
# 46          51         1899056         1972977                  1
# 47          53         1903998         1322014                  0
# 48          54          272345          489903                  1
# 49          55         1206508         1490251                  1
# 50          56           70504          131363                  1

# %%
votes_pred_df
# Out:
#     STATE_FIPS  PRED_DEM_VOTES  PRED_REP_VOTES PRED_WINNING_PARTY
# 0            1         1037054         1083735                  1
# 1            2          242744          223455                  0
# 2            4         1779734          820395                  0
# 3            5          504135          715696                  1
# 4            6        10310902         3766648                  0
# 5            8         1438440         1081870                  0
# 6            9         1009105          628031                  0
# 7           10          254355          191128                  0
# 8           11          175106           99503                  0
# 9           12         4778981         4164215                  0
# 10          13         2481183         2176821                  0
# 11          15          275174          161201                  0
# 12          16          352606          453046                  1
# 13          17         3407080         1997317                  0
# 14          18         1280069         1624800                  1
# 15          19          687180          885855                  1
# 16          20          678273          783093                  1
# 17          21          909870         1136565                  1
# 18          22          928694          957437                  1
# 19          23          339919          346877                  1
# 20          24         1542211         1104639                  0
# 21          25         1839449         1338228                  0
# 22          26         2347027         2328821                  0
# 23          27         1348395         1299551                  0
# 24          28          499957          683966                  1
# 25          29         1312314         1429981                  1
# 26          30          193386          338412                  1
# 27          31          404417          471848                  1
# 28          32          778449          442180                  0
# 29          33          360671          350917                  0
# 30          34         2093826         1704839                  0
# 31          35          358547          341786                  0
# 32          36         4748238         3295141                  0
# 33          37         2265045         2332583                  1
# 34          38          137653          240314                  1
# 35          39         2411058         2887223                  1
# 36          40          539277          870006                  1
# 37          41          985283          860764                  0
# 38          42         2783074         3037659                  1
# 39          44          291387          192688                  0
# 40          45         1105509         1105988                  1
# 41          46          180472          288514                  1
# 42          47         1240851         1692049                  1
# 43          48         5148690         4746269                  0
# 44          49          384010          648731                  1
# 45          50          180784          121856                  0
# 46          51         1899056         1972977                  1
# 47          53         1903998         1322014                  0
# 48          54          272345          489903                  1
# 49          55         1206508         1490251                  1
# 50          56           70504          131363                  1

# %%
data_aggr_2020 = states_aggr.loc[states_aggr['YEAR'] == 2020]
data_aggr_2016 = states_aggr.loc[states_aggr['YEAR'] == 2016]
data_aggr_2012 = states_aggr.loc[states_aggr['YEAR'] == 2012]

# %%
join_df = None
if year == 2012:
    join_df = data_aggr_2012
elif year == 2016:
    join_df = data_aggr_2016
else:
    join_df = data_aggr_2020

# %%
data_aggr_2020
# Out:
#      YEAR  STATE_FIPS                 STATE TOTAL_DEM_VOTES TOTAL_REP_VOTES  \
# 255  2020           1               Alabama             NaN             NaN
# 256  2020           2                Alaska             NaN             NaN
# 257  2020           4               Arizona             NaN             NaN
# 258  2020           5              Arkansas             NaN             NaN
# 259  2020           6            California             NaN             NaN
# 260  2020           8              Colorado             NaN             NaN
# 261  2020           9           Connecticut             NaN             NaN
# 262  2020           1               Alabama             NaN             NaN
# 263  2020           2                Alaska             NaN             NaN
# 264  2020           4               Arizona             NaN             NaN
# 265  2020           5              Arkansas             NaN             NaN
# 266  2020           6            California             NaN             NaN
# 267  2020           8              Colorado             NaN             NaN
# 268  2020           9           Connecticut             NaN             NaN
# 269  2020          10              Delaware             NaN             NaN
# 270  2020          11  District of Columbia             NaN             NaN
# 271  2020          12               Florida             NaN             NaN
# 272  2020          13               Georgia             NaN             NaN
# 273  2020          15                Hawaii             NaN             NaN
# 274  2020          16                 Idaho             NaN             NaN
# 275  2020          17              Illinois             NaN             NaN
# 276  2020          18               Indiana             NaN             NaN
# 277  2020          19                  Iowa             NaN             NaN
# 278  2020          20                Kansas             NaN             NaN
# 279  2020          21              Kentucky             NaN             NaN
# 280  2020          22             Louisiana             NaN             NaN
# 281  2020          23                 Maine             NaN             NaN
# 282  2020          24              Maryland             NaN             NaN
# 283  2020          25         Massachusetts             NaN             NaN
# 284  2020          26              Michigan             NaN             NaN
# 285  2020          27             Minnesota             NaN             NaN
# 286  2020          28           Mississippi             NaN             NaN
# 287  2020          29              Missouri             NaN             NaN
# 288  2020          30               Montana             NaN             NaN
# 289  2020          31              Nebraska             NaN             NaN
# 290  2020          32                Nevada             NaN             NaN
# 291  2020          33         New Hampshire             NaN             NaN
# 292  2020          34            New Jersey             NaN             NaN
# 293  2020          35            New Mexico             NaN             NaN
# 294  2020          36              New York             NaN             NaN
# 295  2020          37        North Carolina             NaN             NaN
# 296  2020          38          North Dakota             NaN             NaN
# 297  2020          39                  Ohio             NaN             NaN
# 298  2020          40              Oklahoma             NaN             NaN
# 299  2020          41                Oregon             NaN             NaN
# 300  2020          42          Pennsylvania             NaN             NaN
# 301  2020          44          Rhode Island             NaN             NaN
# 302  2020          45        South Carolina             NaN             NaN
# 303  2020          46          South Dakota             NaN             NaN
# 304  2020          47             Tennessee             NaN             NaN
# 305  2020          48                 Texas             NaN             NaN
# 306  2020          49                  Utah             NaN             NaN
# 307  2020          50               Vermont             NaN             NaN
# 308  2020          51              Virginia             NaN             NaN
# 309  2020          53            Washington             NaN             NaN
# 310  2020          54         West Virginia             NaN             NaN
# 311  2020          55             Wisconsin             NaN             NaN
# 312  2020          56               Wyoming             NaN             NaN
#
#     TOTAL_VOTES  MARGIN_VICTORY  ABS_MARGIN_VICTORY  WINNING_PARTY  \
# 255         NaN             NaN                 NaN            NaN
# 256         NaN             NaN                 NaN            NaN
# 257         NaN             NaN                 NaN            NaN
# 258         NaN             NaN                 NaN            NaN
# 259         NaN             NaN                 NaN            NaN
# 260         NaN             NaN                 NaN            NaN
# 261         NaN             NaN                 NaN            NaN
# 262         NaN             NaN                 NaN            NaN
# 263         NaN             NaN                 NaN            NaN
# 264         NaN             NaN                 NaN            NaN
# 265         NaN             NaN                 NaN            NaN
# 266         NaN             NaN                 NaN            NaN
# 267         NaN             NaN                 NaN            NaN
# 268         NaN             NaN                 NaN            NaN
# 269         NaN             NaN                 NaN            NaN
# 270         NaN             NaN                 NaN            NaN
# 271         NaN             NaN                 NaN            NaN
# 272         NaN             NaN                 NaN            NaN
# 273         NaN             NaN                 NaN            NaN
# 274         NaN             NaN                 NaN            NaN
# 275         NaN             NaN                 NaN            NaN
# 276         NaN             NaN                 NaN            NaN
# 277         NaN             NaN                 NaN            NaN
# 278         NaN             NaN                 NaN            NaN
# 279         NaN             NaN                 NaN            NaN
# 280         NaN             NaN                 NaN            NaN
# 281         NaN             NaN                 NaN            NaN
# 282         NaN             NaN                 NaN            NaN
# 283         NaN             NaN                 NaN            NaN
# 284         NaN             NaN                 NaN            NaN
# 285         NaN             NaN                 NaN            NaN
# 286         NaN             NaN                 NaN            NaN
# 287         NaN             NaN                 NaN            NaN
# 288         NaN             NaN                 NaN            NaN
# 289         NaN             NaN                 NaN            NaN
# 290         NaN             NaN                 NaN            NaN
# 291         NaN             NaN                 NaN            NaN
# 292         NaN             NaN                 NaN            NaN
# 293         NaN             NaN                 NaN            NaN
# 294         NaN             NaN                 NaN            NaN
# 295         NaN             NaN                 NaN            NaN
# 296         NaN             NaN                 NaN            NaN
# 297         NaN             NaN                 NaN            NaN
# 298         NaN             NaN                 NaN            NaN
# 299         NaN             NaN                 NaN            NaN
# 300         NaN             NaN                 NaN            NaN
# 301         NaN             NaN                 NaN            NaN
# 302         NaN             NaN                 NaN            NaN
# 303         NaN             NaN                 NaN            NaN
# 304         NaN             NaN                 NaN            NaN
# 305         NaN             NaN                 NaN            NaN
# 306         NaN             NaN                 NaN            NaN
# 307         NaN             NaN                 NaN            NaN
# 308         NaN             NaN                 NaN            NaN
# 309         NaN             NaN                 NaN            NaN
# 310         NaN             NaN                 NaN            NaN
# 311         NaN             NaN                 NaN            NaN
# 312         NaN             NaN                 NaN            NaN
#
#      ELECTORAL_VOTES       TOP_TOPIC
# 255                9         Economy
# 256                3         Economy
# 257               11         Economy
# 258                6         Economy
# 259               55         Economy
# 260                9  Climate Change
# 261                7         Economy
# 262                9         Economy
# 263                3         Economy
# 264               11         Economy
# 265                6         Economy
# 266               55         Economy
# 267                9  Climate Change
# 268                7         Economy
# 269                3         Economy
# 270                3         Economy
# 271               29         Economy
# 272               16         Economy
# 273                4         Economy
# 274                4         Economy
# 275               20         Economy
# 276               11         Economy
# 277                6      Healthcare
# 278                6         Economy
# 279                8         Economy
# 280                8         Economy
# 281                4         Economy
# 282               10         Economy
# 283               11         Economy
# 284               16      Healthcare
# 285               10      Healthcare
# 286                6         Economy
# 287               10         Economy
# 288                3         Economy
# 289                5         Economy
# 290                6      Healthcare
# 291                4      Healthcare
# 292               14         Economy
# 293                5         Economy
# 294               29         Economy
# 295               15      Healthcare
# 296                3         Economy
# 297               18         Economy
# 298                7         Economy
# 299                7         Economy
# 300               20         Economy
# 301                4         Economy
# 302                9         Economy
# 303                3         Economy
# 304               11         Economy
# 305               38         Economy
# 306                6         Economy
# 307                3         Economy
# 308               13         Economy
# 309               12         Economy
# 310                5         Economy
# 311               10     Immigration
# 312                3         Economy

# %%
pred_actual_df = pd.merge(votes_pred_df, join_df, on='STATE_FIPS')

# %%
pred_actual_df
# Out:
#     STATE_FIPS  PRED_DEM_VOTES  PRED_REP_VOTES PRED_WINNING_PARTY  YEAR  \
# 0            1         1037054         1083735                  1  2020
# 1            1         1037054         1083735                  1  2020
# 2            2          242744          223455                  0  2020
# 3            2          242744          223455                  0  2020
# 4            4         1779734          820395                  0  2020
# 5            4         1779734          820395                  0  2020
# 6            5          504135          715696                  1  2020
# 7            5          504135          715696                  1  2020
# 8            6        10310902         3766648                  0  2020
# 9            6        10310902         3766648                  0  2020
# 10           8         1438440         1081870                  0  2020
# 11           8         1438440         1081870                  0  2020
# 12           9         1009105          628031                  0  2020
# 13           9         1009105          628031                  0  2020
# 14          10          254355          191128                  0  2020
# 15          11          175106           99503                  0  2020
# 16          12         4778981         4164215                  0  2020
# 17          13         2481183         2176821                  0  2020
# 18          15          275174          161201                  0  2020
# 19          16          352606          453046                  1  2020
# 20          17         3407080         1997317                  0  2020
# 21          18         1280069         1624800                  1  2020
# 22          19          687180          885855                  1  2020
# 23          20          678273          783093                  1  2020
# 24          21          909870         1136565                  1  2020
# 25          22          928694          957437                  1  2020
# 26          23          339919          346877                  1  2020
# 27          24         1542211         1104639                  0  2020
# 28          25         1839449         1338228                  0  2020
# 29          26         2347027         2328821                  0  2020
# 30          27         1348395         1299551                  0  2020
# 31          28          499957          683966                  1  2020
# 32          29         1312314         1429981                  1  2020
# 33          30          193386          338412                  1  2020
# 34          31          404417          471848                  1  2020
# 35          32          778449          442180                  0  2020
# 36          33          360671          350917                  0  2020
# 37          34         2093826         1704839                  0  2020
# 38          35          358547          341786                  0  2020
# 39          36         4748238         3295141                  0  2020
# 40          37         2265045         2332583                  1  2020
# 41          38          137653          240314                  1  2020
# 42          39         2411058         2887223                  1  2020
# 43          40          539277          870006                  1  2020
# 44          41          985283          860764                  0  2020
# 45          42         2783074         3037659                  1  2020
# 46          44          291387          192688                  0  2020
# 47          45         1105509         1105988                  1  2020
# 48          46          180472          288514                  1  2020
# 49          47         1240851         1692049                  1  2020
# 50          48         5148690         4746269                  0  2020
# 51          49          384010          648731                  1  2020
# 52          50          180784          121856                  0  2020
# 53          51         1899056         1972977                  1  2020
# 54          53         1903998         1322014                  0  2020
# 55          54          272345          489903                  1  2020
# 56          55         1206508         1490251                  1  2020
# 57          56           70504          131363                  1  2020
#
#                    STATE TOTAL_DEM_VOTES TOTAL_REP_VOTES TOTAL_VOTES  \
# 0                Alabama             NaN             NaN         NaN
# 1                Alabama             NaN             NaN         NaN
# 2                 Alaska             NaN             NaN         NaN
# 3                 Alaska             NaN             NaN         NaN
# 4                Arizona             NaN             NaN         NaN
# 5                Arizona             NaN             NaN         NaN
# 6               Arkansas             NaN             NaN         NaN
# 7               Arkansas             NaN             NaN         NaN
# 8             California             NaN             NaN         NaN
# 9             California             NaN             NaN         NaN
# 10              Colorado             NaN             NaN         NaN
# 11              Colorado             NaN             NaN         NaN
# 12           Connecticut             NaN             NaN         NaN
# 13           Connecticut             NaN             NaN         NaN
# 14              Delaware             NaN             NaN         NaN
# 15  District of Columbia             NaN             NaN         NaN
# 16               Florida             NaN             NaN         NaN
# 17               Georgia             NaN             NaN         NaN
# 18                Hawaii             NaN             NaN         NaN
# 19                 Idaho             NaN             NaN         NaN
# 20              Illinois             NaN             NaN         NaN
# 21               Indiana             NaN             NaN         NaN
# 22                  Iowa             NaN             NaN         NaN
# 23                Kansas             NaN             NaN         NaN
# 24              Kentucky             NaN             NaN         NaN
# 25             Louisiana             NaN             NaN         NaN
# 26                 Maine             NaN             NaN         NaN
# 27              Maryland             NaN             NaN         NaN
# 28         Massachusetts             NaN             NaN         NaN
# 29              Michigan             NaN             NaN         NaN
# 30             Minnesota             NaN             NaN         NaN
# 31           Mississippi             NaN             NaN         NaN
# 32              Missouri             NaN             NaN         NaN
# 33               Montana             NaN             NaN         NaN
# 34              Nebraska             NaN             NaN         NaN
# 35                Nevada             NaN             NaN         NaN
# 36         New Hampshire             NaN             NaN         NaN
# 37            New Jersey             NaN             NaN         NaN
# 38            New Mexico             NaN             NaN         NaN
# 39              New York             NaN             NaN         NaN
# 40        North Carolina             NaN             NaN         NaN
# 41          North Dakota             NaN             NaN         NaN
# 42                  Ohio             NaN             NaN         NaN
# 43              Oklahoma             NaN             NaN         NaN
# 44                Oregon             NaN             NaN         NaN
# 45          Pennsylvania             NaN             NaN         NaN
# 46          Rhode Island             NaN             NaN         NaN
# 47        South Carolina             NaN             NaN         NaN
# 48          South Dakota             NaN             NaN         NaN
# 49             Tennessee             NaN             NaN         NaN
# 50                 Texas             NaN             NaN         NaN
# 51                  Utah             NaN             NaN         NaN
# 52               Vermont             NaN             NaN         NaN
# 53              Virginia             NaN             NaN         NaN
# 54            Washington             NaN             NaN         NaN
# 55         West Virginia             NaN             NaN         NaN
# 56             Wisconsin             NaN             NaN         NaN
# 57               Wyoming             NaN             NaN         NaN
#
#     MARGIN_VICTORY  ABS_MARGIN_VICTORY  WINNING_PARTY  ELECTORAL_VOTES  \
# 0              NaN                 NaN            NaN                9
# 1              NaN                 NaN            NaN                9
# 2              NaN                 NaN            NaN                3
# 3              NaN                 NaN            NaN                3
# 4              NaN                 NaN            NaN               11
# 5              NaN                 NaN            NaN               11
# 6              NaN                 NaN            NaN                6
# 7              NaN                 NaN            NaN                6
# 8              NaN                 NaN            NaN               55
# 9              NaN                 NaN            NaN               55
# 10             NaN                 NaN            NaN                9
# 11             NaN                 NaN            NaN                9
# 12             NaN                 NaN            NaN                7
# 13             NaN                 NaN            NaN                7
# 14             NaN                 NaN            NaN                3
# 15             NaN                 NaN            NaN                3
# 16             NaN                 NaN            NaN               29
# 17             NaN                 NaN            NaN               16
# 18             NaN                 NaN            NaN                4
# 19             NaN                 NaN            NaN                4
# 20             NaN                 NaN            NaN               20
# 21             NaN                 NaN            NaN               11
# 22             NaN                 NaN            NaN                6
# 23             NaN                 NaN            NaN                6
# 24             NaN                 NaN            NaN                8
# 25             NaN                 NaN            NaN                8
# 26             NaN                 NaN            NaN                4
# 27             NaN                 NaN            NaN               10
# 28             NaN                 NaN            NaN               11
# 29             NaN                 NaN            NaN               16
# 30             NaN                 NaN            NaN               10
# 31             NaN                 NaN            NaN                6
# 32             NaN                 NaN            NaN               10
# 33             NaN                 NaN            NaN                3
# 34             NaN                 NaN            NaN                5
# 35             NaN                 NaN            NaN                6
# 36             NaN                 NaN            NaN                4
# 37             NaN                 NaN            NaN               14
# 38             NaN                 NaN            NaN                5
# 39             NaN                 NaN            NaN               29
# 40             NaN                 NaN            NaN               15
# 41             NaN                 NaN            NaN                3
# 42             NaN                 NaN            NaN               18
# 43             NaN                 NaN            NaN                7
# 44             NaN                 NaN            NaN                7
# 45             NaN                 NaN            NaN               20
# 46             NaN                 NaN            NaN                4
# 47             NaN                 NaN            NaN                9
# 48             NaN                 NaN            NaN                3
# 49             NaN                 NaN            NaN               11
# 50             NaN                 NaN            NaN               38
# 51             NaN                 NaN            NaN                6
# 52             NaN                 NaN            NaN                3
# 53             NaN                 NaN            NaN               13
# 54             NaN                 NaN            NaN               12
# 55             NaN                 NaN            NaN                5
# 56             NaN                 NaN            NaN               10
# 57             NaN                 NaN            NaN                3
#
#          TOP_TOPIC
# 0          Economy
# 1          Economy
# 2          Economy
# 3          Economy
# 4          Economy
# 5          Economy
# 6          Economy
# 7          Economy
# 8          Economy
# 9          Economy
# 10  Climate Change
# 11  Climate Change
# 12         Economy
# 13         Economy
# 14         Economy
# 15         Economy
# 16         Economy
# 17         Economy
# 18         Economy
# 19         Economy
# 20         Economy
# 21         Economy
# 22      Healthcare
# 23         Economy
# 24         Economy
# 25         Economy
# 26         Economy
# 27         Economy
# 28         Economy
# 29      Healthcare
# 30      Healthcare
# 31         Economy
# 32         Economy
# 33         Economy
# 34         Economy
# 35      Healthcare
# 36      Healthcare
# 37         Economy
# 38         Economy
# 39         Economy
# 40      Healthcare
# 41         Economy
# 42         Economy
# 43         Economy
# 44         Economy
# 45         Economy
# 46         Economy
# 47         Economy
# 48         Economy
# 49         Economy
# 50         Economy
# 51         Economy
# 52         Economy
# 53         Economy
# 54         Economy
# 55         Economy
# 56     Immigration
# 57         Economy

# %%
pred_actual_df.drop('YEAR', inplace=True, axis=1)

# %%
pred_actual_df.columns
# Out:
# Index(['STATE_FIPS', 'PRED_DEM_VOTES', 'PRED_REP_VOTES', 'PRED_WINNING_PARTY',
#        'STATE', 'TOTAL_DEM_VOTES', 'TOTAL_REP_VOTES', 'TOTAL_VOTES',
#        'MARGIN_VICTORY', 'ABS_MARGIN_VICTORY', 'WINNING_PARTY',
#        'ELECTORAL_VOTES', 'TOP_TOPIC'],
#       dtype='object')

# %%
pred_actual_df.head()
# Out:
#    STATE_FIPS  PRED_DEM_VOTES  PRED_REP_VOTES PRED_WINNING_PARTY    STATE  \
# 0           1         1037054         1083735                  1  Alabama
# 1           1         1037054         1083735                  1  Alabama
# 2           2          242744          223455                  0   Alaska
# 3           2          242744          223455                  0   Alaska
# 4           4         1779734          820395                  0  Arizona
#
#   TOTAL_DEM_VOTES TOTAL_REP_VOTES TOTAL_VOTES  MARGIN_VICTORY  \
# 0             NaN             NaN         NaN             NaN
# 1             NaN             NaN         NaN             NaN
# 2             NaN             NaN         NaN             NaN
# 3             NaN             NaN         NaN             NaN
# 4             NaN             NaN         NaN             NaN
#
#    ABS_MARGIN_VICTORY  WINNING_PARTY  ELECTORAL_VOTES TOP_TOPIC
# 0                 NaN            NaN                9   Economy
# 1                 NaN            NaN                9   Economy
# 2                 NaN            NaN                3   Economy
# 3                 NaN            NaN                3   Economy
# 4                 NaN            NaN               11   Economy

# %%
file_name = 'actuals_predictions_state_' + str(year) + '.csv'
pred_actual_df.to_csv(file_name)
