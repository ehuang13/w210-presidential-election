# %%
import pandas as pd

# %%
electoral_ref = pd.read_excel('../../data/Electoral College Votes.xlsx')
data_2020 = pd.read_csv('../../data/F20_predictions_0703_new.csv')
data_historical = pd.read_csv("../../data/combined_jun22_train.csv", encoding = "ISO-8859-1")

# %%
### 1) create a new df with StateFips/Count

# %%
state_fips_map = {}
for index, row in data_historical.iterrows():
    #print(row)
    state = row['STATE']
    #print(type(state))
    if (state_fips_map.get(state) == None):
        state_fips_map[state] = row['STATE_FIPS']
    
print(state_fips_map)
# Out:
# {'Alabama': 1, 'Alaska': 2, 'Arizona': 4, 'Arkansas': 5, 'California': 6, 'Colorado': 8, 'Connecticut': 9, 'Delaware': 10, 'District of Columbia': 11, 'Florida': 12, 'Georgia': 13, 'Hawaii': 15, 'Idaho': 16, 'Illinois': 17, 'Indiana': 18, 'Iowa': 19, 'Kansas': 20, 'Kentucky': 21, 'Louisiana': 22, 'Maine': 23, 'Maryland': 24, 'Massachusetts': 25, 'Michigan': 26, 'Minnesota': 27, 'Mississippi': 28, 'Missouri': 29, 'Montana': 30, 'Nebraska': 31, 'Nevada': 32, 'New Hampshire': 33, 'New Jersey': 34, 'New Mexico': 35, 'New York': 36, 'North Carolina': 37, 'North Dakota': 38, 'Ohio': 39, 'Oklahoma': 40, 'Oregon': 41, 'Pennsylvania': 42, 'Rhode Island': 44, 'South Carolina': 45, 'South Dakota': 46, 'Tennessee': 47, 'Texas': 48, 'Utah': 49, 'Vermont': 50, 'Virginia': 51, 'Washington': 53, 'West Virginia': 54, 'Wisconsin': 55, 'Wyoming': 56}

# %%
state_fips_df = pd.DataFrame(list(state_fips_map.items()), columns=['STATE','STATE_FIPS'])

# %%
state_fips_df.head()
# Out:
#         STATE  STATE_FIPS
# 0     Alabama           1
# 1      Alaska           2
# 2     Arizona           4
# 3    Arkansas           5
# 4  California           6

# %%
df = electoral_ref.merge(state_fips_df, left_on='STATE', right_on='STATE')

# %%
df.head()
# Out:
#         STATE  COUNT  STATE_FIPS
# 0     Alabama      9           1
# 1      Alaska      3           2
# 2     Arizona     11           4
# 3    Arkansas      6           5
# 4  California     55           6

# %%
data_2020.loc[data_2020['STATE_FIPS'] == 13]
# Out:
#      YEAR  STATE_FIPS  COUNTY_FIPS  HOUSE_WINNING_BINARY  \
# 387  2020          13            1                     0
# 388  2020          13            3                     0
# 389  2020          13            5                     0
# 390  2020          13            7                     0
# 391  2020          13            9                     0
# ..    ...         ...          ...                   ...
# 541  2020          13          313                     0
# 542  2020          13          315                     0
# 543  2020          13          317                     0
# 544  2020          13          319                     0
# 545  2020          13          321                     0
#
#      SENATE_WINNING_BINARY  UNEMPLOYMENT_RATE  AVG_WAGE_SALARY  AA_FEMALE  \
# 387                     -1                6.3            34006         58
# 388                     -1                4.3                0         27
# 389                     -1                5.5                0         43
# 390                     -1               10.4                0         15
# 391                     -1                6.6           109924        381
# ..                     ...                ...              ...        ...
# 541                     -1                7.3            74584        872
# 542                     -1                5.1                0         25
# 543                     -1                4.1                0         42
# 544                     -1                3.1                0         23
# 545                     -1                3.4            34933         84
#
#      AA_MALE  BA_FEMALE  ...  TOT_FEMALE%  TOT_MALE%  TOT_POP_LESS19%  \
# 387       97       1781  ...     0.500729   0.499271         0.269898
# 388       47        730  ...     0.495239   0.504761         0.286971
# 389       32        947  ...     0.511131   0.488869         0.276531
# 390       19        729  ...     0.505498   0.494502         0.211837
# 391      375       9445  ...     0.492627   0.507373         0.250474
# ..       ...        ...  ...          ...        ...              ...
# 541      779       2161  ...     0.501759   0.498241         0.284773
# 542       41       1010  ...     0.402633   0.597367         0.210395
# 543       43       2201  ...     0.519947   0.480053         0.233900
# 544       18       1854  ...     0.521580   0.478420         0.249668
# 545       52       3108  ...     0.519582   0.480418         0.244692
#
#      TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%  COUNTY_TOTALVOTES  \
# 387         0.238288         0.252067          0.239747               9351
# 388         0.257684         0.258166          0.197180               2171
# 389         0.246848         0.251140          0.225481               6113
# 390         0.216041         0.266494          0.305627               3462
# 391         0.294626         0.232068          0.222832              23312
# ..               ...              ...               ...                ...
# 541         0.264025         0.257154          0.194048              39316
# 542         0.286995         0.262823          0.239787               4314
# 543         0.207270         0.250101          0.308728               8566
# 544         0.223882         0.252767          0.273683               7966
# 545         0.232819         0.261885          0.260604              13515
#
#      WINNING_PARTY_BINARY  REP_VOTES  DEM_VOTES
# 387                     1       8883        468
# 388                     0        594       1577
# 389                     0       2020       4093
# 390                     0       1065       2397
# 391                     1      13937       9375
# ..                    ...        ...        ...
# 541                     1      20057      19259
# 542                     0       1714       2600
# 543                     0       3253       5313
# 544                     0       3039       4927
# 545                     1      10743       2772
#
# [159 rows x 56 columns]

# %%
data_2020.drop('Unnamed: 0', inplace=True, axis=1)

# %%
## 2) 

# create map of visited county_state
# create map of D electoral votes, R electoral votes
# loop over data_2020
# updaste the two maps accordingly.

# %%
def sum_of(x):
    d = 0
    r = 0
    
    for c in x:
        if (c == 'D'):
            d += 1
        else:
            r += 1
    return d, r

# %%
"""extract how counties prediction for every state"""
visited = {}
electoral_votes = {'D':0, 'R':0 }
for idnex, row in data_2020.iterrows():
    state = int(row['STATE_FIPS'])
    
    rep_votes = int(row['REP_VOTES'])
    dem_votes = int(row['DEM_VOTES'])

    if (visited.get(state) == None):
        electoral_votes = {'D': dem_votes, 'R': rep_votes }
        visited[state] = electoral_votes
    else:
        #update existing map
        current_votes = visited.get(state)
        current_r = current_votes.get('R')
        current_d = current_votes.get('D')
        electoral_votes = {'D': current_d + dem_votes, 'R': current_r + rep_votes }
        visited[state] = electoral_votes

# %%
visited
# Out:
# {1: {'D': 1032203, 'R': 1140259},
#  2: {'D': 141872, 'R': 270896},
#  4: {'D': 1591644, 'R': 1010371},
#  5: {'D': 458490, 'R': 791268},
#  6: {'D': 8702337, 'R': 5351881},
#  8: {'D': 1275469, 'R': 1239926},
#  9: {'D': 1026266, 'R': 613515},
#  10: {'D': 281556, 'R': 167186},
#  11: {'D': 172375, 'R': 97189},
#  12: {'D': 5465851, 'R': 3453504},
#  13: {'D': 2507275, 'R': 2244430},
#  15: {'D': 167903, 'R': 93652},
#  16: {'D': 309009, 'R': 514537},
#  17: {'D': 3138791, 'R': 2285791},
#  18: {'D': 1529257, 'R': 1438059},
#  19: {'D': 643648, 'R': 1019360},
#  20: {'D': 464207, 'R': 1044967},
#  21: {'D': 945233, 'R': 1169834},
#  22: {'D': 1027311, 'R': 906800},
#  23: {'D': 380525, 'R': 302253},
#  24: {'D': 1641800, 'R': 1034058},
#  25: {'D': 2008592, 'R': 1170386},
#  26: {'D': 2654955, 'R': 2011981},
#  27: {'D': 1340306, 'R': 1368240},
#  28: {'D': 656558, 'R': 589139},
#  29: {'D': 1390522, 'R': 1424871},
#  30: {'D': 156593, 'R': 420119},
#  31: {'D': 204461, 'R': 758725},
#  32: {'D': 697679, 'R': 511267},
#  33: {'D': 424749, 'R': 275846},
#  34: {'D': 2414371, 'R': 1419816},
#  35: {'D': 285217, 'R': 448447},
#  36: {'D': 4962505, 'R': 3109165},
#  37: {'D': 2634228, 'R': 2018565},
#  38: {'D': 85029, 'R': 340465},
#  39: {'D': 3112784, 'R': 2225049},
#  40: {'D': 691431, 'R': 807932},
#  41: {'D': 1044605, 'R': 783396},
#  42: {'D': 3533327, 'R': 2307302},
#  44: {'D': 301669, 'R': 189148},
#  45: {'D': 1337241, 'R': 900153},
#  46: {'D': 79240, 'R': 437021},
#  47: {'D': 1665354, 'R': 1329957},
#  48: {'D': 5076600, 'R': 4901940},
#  49: {'D': 501930, 'R': 549585},
#  50: {'D': 165239, 'R': 141251},
#  51: {'D': 2270390, 'R': 1704257},
#  53: {'D': 1910268, 'R': 1271231},
#  54: {'D': 383453, 'R': 414725},
#  55: {'D': 1449000, 'R': 1276313},
#  56: {'D': 23076, 'R': 198925}}

# %%
"""determine the winner of every state"""
state_predictions = {}

for key, val in visited.items():
    total_r = val.get('R')
    total_d = val.get('D')
    winner = 'D' if total_d > total_r else 'R'
    state_predictions[key] = winner

# %%
state_predictions
# Out:
# {1: 'R',
#  2: 'R',
#  4: 'D',
#  5: 'R',
#  6: 'D',
#  8: 'D',
#  9: 'D',
#  10: 'D',
#  11: 'D',
#  12: 'D',
#  13: 'D',
#  15: 'D',
#  16: 'R',
#  17: 'D',
#  18: 'D',
#  19: 'R',
#  20: 'R',
#  21: 'R',
#  22: 'D',
#  23: 'D',
#  24: 'D',
#  25: 'D',
#  26: 'D',
#  27: 'R',
#  28: 'D',
#  29: 'R',
#  30: 'R',
#  31: 'R',
#  32: 'D',
#  33: 'D',
#  34: 'D',
#  35: 'R',
#  36: 'D',
#  37: 'D',
#  38: 'R',
#  39: 'D',
#  40: 'R',
#  41: 'D',
#  42: 'D',
#  44: 'D',
#  45: 'D',
#  46: 'R',
#  47: 'D',
#  48: 'D',
#  49: 'R',
#  50: 'D',
#  51: 'D',
#  53: 'D',
#  54: 'R',
#  55: 'D',
#  56: 'R'}

# %%
party_electoral = {}
for index, row in df.iterrows():
    state = int(row['STATE_FIPS'])
    votes = int(row['COUNT'])
    party = state_predictions.get(state)
    
    if (party_electoral.get(party) == None):
        party_electoral[party] = votes
    else:
        party_electoral[party] = party_electoral.get(party) + votes

# %%
party_electoral
# Out:
# {'R': 102, 'D': 436}
