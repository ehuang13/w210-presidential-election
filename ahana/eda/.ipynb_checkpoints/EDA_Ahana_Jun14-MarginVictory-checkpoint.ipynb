# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# load in final merged dataset
total_data = "combined_jun13.csv"
df = pd.read_csv(total_data, encoding = "ISO-8859-1" )

# %%
print("Shape of full dataset: {}".format(df))
# Out:
# Shape of full dataset:        Unnamed: 0     ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS  \
# 0               0      0   20121001  2012           1            1
# 1               1      1   20121003  2012           1            3
# 2               2      2   20121005  2012           1            5
# 3               3      3   20121007  2012           1            7
# 4               4      4   20121009  2012           1            9
# 5               5      5   20121011  2012           1           11
# 6               6      6   20121013  2012           1           13
# 7               7      7   20121015  2012           1           15
# 8               8      8   20121017  2012           1           17
# 9               9      9   20121019  2012           1           19
# 10             10     10   20121021  2012           1           21
# 11             11     11   20121023  2012           1           23
# 12             12     12   20121025  2012           1           25
# 13             13     13   20121027  2012           1           27
# 14             14     14   20121029  2012           1           29
# 15             15     15   20121031  2012           1           31
# 16             16     16   20121033  2012           1           33
# 17             17     17   20121035  2012           1           35
# 18             18     18   20121037  2012           1           37
# 19             19     19   20121039  2012           1           39
# 20             20     20   20121041  2012           1           41
# 21             21     21   20121043  2012           1           43
# 22             22     22   20121045  2012           1           45
# 23             23     23   20121047  2012           1           47
# 24             24     24   20121049  2012           1           49
# 25             25     25   20121051  2012           1           51
# 26             26     26   20121053  2012           1           53
# 27             27     27   20121055  2012           1           55
# 28             28     28   20121057  2012           1           57
# 29             29     29   20121059  2012           1           59
# ...           ...    ...        ...   ...         ...          ...
# 15407       15407  18825   20088083  2008           8           83
# 15408       15408  18826   20088085  2008           8           85
# 15409       15409  18827   20088087  2008           8           87
# 15410       15410  18828   20088089  2008           8           89
# 15411       15411  18829   20088091  2008           8           91
# 15412       15412  18830   20088093  2008           8           93
# 15413       15413  18831   20088095  2008           8           95
# 15414       15414  18832   20088097  2008           8           97
# 15415       15415  18833   20088099  2008           8           99
# 15416       15416  18834   20088101  2008           8          101
# 15417       15417  18835   20088103  2008           8          103
# 15418       15418  18836   20088105  2008           8          105
# 15419       15419  18837   20088107  2008           8          107
# 15420       15420  18838   20088109  2008           8          109
# 15421       15421  18839   20088111  2008           8          111
# 15422       15422  18840   20088113  2008           8          113
# 15423       15423  18841   20088115  2008           8          115
# 15424       15424  18842   20088117  2008           8          117
# 15425       15425  18843   20088119  2008           8          119
# 15426       15426  18844   20088121  2008           8          121
# 15427       15427  18845   20088123  2008           8          123
# 15428       15428  18846   20088125  2008           8          125
# 15429       15429  18847   20089001  2008           9            1
# 15430       15430  18848   20089003  2008           9            3
# 15431       15431  18849   20089005  2008           9            5
# 15432       15432  18850   20089007  2008           9            7
# 15433       15433  18851   20089009  2008           9            9
# 15434       15434  18852   20089011  2008           9           11
# 15435       15435  18853   20089013  2008           9           13
# 15436       15436  18854   20089015  2008           9           15
#
#              STATE             COUNTY    FIPS REP_CANDIDATE        ...         \
# 0          Alabama     Autauga County  1001.0   Mitt Romney        ...
# 1          Alabama     Baldwin County  1003.0   Mitt Romney        ...
# 2          Alabama     Barbour County  1005.0   Mitt Romney        ...
# 3          Alabama        Bibb County  1007.0   Mitt Romney        ...
# 4          Alabama      Blount County  1009.0   Mitt Romney        ...
# 5          Alabama     Bullock County  1011.0   Mitt Romney        ...
# 6          Alabama      Butler County  1013.0   Mitt Romney        ...
# 7          Alabama     Calhoun County  1015.0   Mitt Romney        ...
# 8          Alabama    Chambers County  1017.0   Mitt Romney        ...
# 9          Alabama    Cherokee County  1019.0   Mitt Romney        ...
# 10         Alabama     Chilton County  1021.0   Mitt Romney        ...
# 11         Alabama     Choctaw County  1023.0   Mitt Romney        ...
# 12         Alabama      Clarke County  1025.0   Mitt Romney        ...
# 13         Alabama        Clay County  1027.0   Mitt Romney        ...
# 14         Alabama    Cleburne County  1029.0   Mitt Romney        ...
# 15         Alabama      Coffee County  1031.0   Mitt Romney        ...
# 16         Alabama     Colbert County  1033.0   Mitt Romney        ...
# 17         Alabama     Conecuh County  1035.0   Mitt Romney        ...
# 18         Alabama       Coosa County  1037.0   Mitt Romney        ...
# 19         Alabama   Covington County  1039.0   Mitt Romney        ...
# 20         Alabama    Crenshaw County  1041.0   Mitt Romney        ...
# 21         Alabama     Cullman County  1043.0   Mitt Romney        ...
# 22         Alabama        Dale County  1045.0   Mitt Romney        ...
# 23         Alabama      Dallas County  1047.0   Mitt Romney        ...
# 24         Alabama      DeKalb County  1049.0   Mitt Romney        ...
# 25         Alabama      Elmore County  1051.0   Mitt Romney        ...
# 26         Alabama    Escambia County  1053.0   Mitt Romney        ...
# 27         Alabama      Etowah County  1055.0   Mitt Romney        ...
# 28         Alabama     Fayette County  1057.0   Mitt Romney        ...
# 29         Alabama    Franklin County  1059.0   Mitt Romney        ...
# ...            ...                ...     ...           ...        ...
# 15407     Colorado   Montezuma County  8083.0   John McCain        ...
# 15408     Colorado    Montrose County  8085.0   John McCain        ...
# 15409     Colorado      Morgan County  8087.0   John McCain        ...
# 15410     Colorado       Otero County  8089.0   John McCain        ...
# 15411     Colorado       Ouray County  8091.0   John McCain        ...
# 15412     Colorado        Park County  8093.0   John McCain        ...
# 15413     Colorado    Phillips County  8095.0   John McCain        ...
# 15414     Colorado      Pitkin County  8097.0   John McCain        ...
# 15415     Colorado     Prowers County  8099.0   John McCain        ...
# 15416     Colorado      Pueblo County  8101.0   John McCain        ...
# 15417     Colorado  Rio Blanco County  8103.0   John McCain        ...
# 15418     Colorado  Rio Grande County  8105.0   John McCain        ...
# 15419     Colorado       Routt County  8107.0   John McCain        ...
# 15420     Colorado    Saguache County  8109.0   John McCain        ...
# 15421     Colorado    San Juan County  8111.0   John McCain        ...
# 15422     Colorado  San Miguel County  8113.0   John McCain        ...
# 15423     Colorado    Sedgwick County  8115.0   John McCain        ...
# 15424     Colorado      Summit County  8117.0   John McCain        ...
# 15425     Colorado      Teller County  8119.0   John McCain        ...
# 15426     Colorado  Washington County  8121.0   John McCain        ...
# 15427     Colorado        Weld County  8123.0   John McCain        ...
# 15428     Colorado        Yuma County  8125.0   John McCain        ...
# 15429  Connecticut   Fairfield County  9001.0   John McCain        ...
# 15430  Connecticut    Hartford County  9003.0   John McCain        ...
# 15431  Connecticut  Litchfield County  9005.0   John McCain        ...
# 15432  Connecticut   Middlesex County  9007.0   John McCain        ...
# 15433  Connecticut   New Haven County  9009.0   John McCain        ...
# 15434  Connecticut  New London County  9011.0   John McCain        ...
# 15435  Connecticut     Tolland County  9013.0   John McCain        ...
# 15436  Connecticut     Windham County  9015.0   John McCain        ...
#
#       NA_FEMALE%  NA_MALE%  WA_FEMALE%  WA_MALE% TOT_FEMALE% TOT_MALE%  \
# 0       0.000310  0.000511    0.402747  0.390054    0.512912  0.487088
# 1       0.000300  0.000399    0.446461  0.429892    0.510581  0.489419
# 2       0.000622  0.001061    0.237175  0.271277    0.469301  0.530699
# 3       0.000219  0.001137    0.371240  0.394981    0.463799  0.536201
# 4       0.000436  0.000627    0.487947  0.477838    0.505255  0.494745
# 5       0.003309  0.003953    0.102317  0.161335    0.459276  0.540724
# 6       0.000239  0.000143    0.283402  0.261866    0.529940  0.470060
# 7       0.000447  0.000523    0.391730  0.372714    0.517780  0.482220
# 8       0.000147  0.000293    0.302649  0.290253    0.521833  0.478167
# 9       0.000077  0.000154    0.471510  0.461230    0.503889  0.496111
# 10      0.000596  0.001260    0.445353  0.435480    0.505143  0.494857
# 11      0.000000  0.000000    0.285797  0.274893    0.518088  0.481912
# 12      0.000000  0.000155    0.279449  0.266175    0.527499  0.472501
# 13      0.000000  0.000000    0.422969  0.407642    0.510254  0.489746
# 14      0.000067  0.000666    0.476606  0.474140    0.502466  0.497534
# 15      0.001394  0.003048    0.387989  0.386595    0.505946  0.494054
# 16      0.000165  0.000202    0.418505  0.394186    0.519230  0.480770
# 17      0.000000  0.000076    0.255403  0.261599    0.516095  0.483905
# 18      0.000849  0.000594    0.328382  0.336700    0.494568  0.505432
# 19      0.000026  0.000000    0.437321  0.413758    0.515551  0.484449
# 20      0.000216  0.000360    0.375018  0.358296    0.517443  0.482557
# 21      0.000236  0.000174    0.489858  0.478012    0.506153  0.493847
# 22      0.000595  0.000476    0.376444  0.382060    0.506092  0.493908
# 23      0.000091  0.000160    0.152234  0.139330    0.537665  0.462335
# 24      0.004019  0.004525    0.469526  0.458073    0.506148  0.493852
# 25      0.000591  0.000490    0.397640  0.374618    0.511530  0.488470
# 26      0.000183  0.000339    0.311366  0.317468    0.484065  0.515935
# 27      0.001426  0.001714    0.418850  0.399033    0.515073  0.484927
# 28      0.000000  0.000000    0.440471  0.429674    0.506763  0.493237
# 29      0.000410  0.000725    0.466562  0.460765    0.500772  0.499228
# ...          ...       ...         ...       ...         ...       ...
# 15407   0.000398  0.000278    0.431848  0.420042    0.508288  0.491712
# 15408   0.000454  0.000403    0.485847  0.469438    0.507524  0.492476
# 15409   0.000901  0.001550    0.478789  0.469094    0.505424  0.494576
# 15410   0.000639  0.000532    0.474844  0.458606    0.507480  0.492520
# 15411   0.000235  0.000941    0.485882  0.488706    0.500235  0.499765
# 15412   0.000122  0.000061    0.457708  0.504287    0.477227  0.522773
# 15413   0.000457  0.000228    0.504340  0.470078    0.518045  0.481955
# 15414   0.000379  0.000253    0.453396  0.512773    0.471038  0.528962
# 15415   0.000079  0.000079    0.482805  0.482491    0.499607  0.500393
# 15416   0.000632  0.000567    0.470323  0.451899    0.508538  0.491462
# 15417   0.001255  0.000314    0.465872  0.494273    0.486427  0.513573
# 15418   0.000169  0.000084    0.476375  0.475532    0.500253  0.499747
# 15419   0.000311  0.000356    0.454938  0.516784    0.468854  0.531146
# 15420   0.000163  0.000000    0.466818  0.476903    0.495120  0.504880
# 15421   0.000000  0.000000    0.414523  0.547655    0.429652  0.570348
# 15422   0.000410  0.000137    0.435810  0.526086    0.455886  0.544114
# 15423   0.000000  0.000000    0.500833  0.467500    0.515417  0.484583
# 15424   0.000263  0.000338    0.432320  0.529715    0.448897  0.551103
# 15425   0.000308  0.000484    0.468666  0.488087    0.490245  0.509755
# 15426   0.000205  0.000410    0.484129  0.495187    0.492525  0.507475
# 15427   0.000480  0.000606    0.472645  0.473150    0.499049  0.500951
# 15428   0.000715  0.000919    0.497037  0.483245    0.506539  0.493461
# 15429   0.000478  0.000544    0.420651  0.402021    0.514643  0.485357
# 15430   0.000480  0.000532    0.412179  0.385528    0.516820  0.483180
# 15431   0.000190  0.000216    0.486554  0.468910    0.508827  0.491173
# 15432   0.000238  0.000219    0.465518  0.445223    0.511756  0.488244
# 15433   0.000398  0.000458    0.419644  0.391785    0.518593  0.481407
# 15434   0.000525  0.000580    0.434280  0.426007    0.502263  0.497737
# 15435   0.000147  0.000508    0.460626  0.458308    0.496066  0.503934
# 15436   0.000281  0.000358    0.474788  0.464024    0.503941  0.496059
#
#        TOT_POP_LESS19%  TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%
# 0             0.293056         0.252858         0.282427          0.171659
# 1             0.253453         0.230183         0.282293          0.234071
# 2             0.242225         0.270801         0.278741          0.208233
# 3             0.248820         0.283097         0.280955          0.187128
# 4             0.271033         0.241682         0.276594          0.210691
# 5             0.248759         0.273212         0.285255          0.192774
# 6             0.266068         0.232452         0.272467          0.229013
# 7             0.259882         0.262102         0.274019          0.203997
# 8             0.247641         0.230057         0.287088          0.235215
# 9             0.237545         0.210056         0.295026          0.257373
# 10            0.275582         0.258241         0.272765          0.193412
# 11            0.248899         0.209690         0.289840          0.251571
# 12            0.273588         0.221735         0.282166          0.222511
# 13            0.248111         0.225516         0.284594          0.241779
# 14            0.262530         0.228006         0.282525          0.226939
# 15            0.266009         0.265611         0.265213          0.203167
# 16            0.246089         0.228996         0.285887          0.239028
# 17            0.257065         0.204851         0.284117          0.253967
# 18            0.224834         0.218554         0.313190          0.243422
# 19            0.250212         0.221570         0.278562          0.249656
# 20            0.263442         0.227260         0.281462          0.227836
# 21            0.257625         0.242623         0.275971          0.223780
# 22            0.272395         0.275094         0.260786          0.191725
# 23            0.293183         0.233835         0.272139          0.200844
# 24            0.284054         0.249160         0.267092          0.199694
# 25            0.262262         0.271900         0.289317          0.176521
# 26            0.252086         0.260145         0.277201          0.210567
# 27            0.255325         0.240467         0.279460          0.224747
# 28            0.249840         0.216811         0.285076          0.248273
# 29            0.275256         0.254308         0.261490          0.208946
# ...                ...              ...              ...               ...
# 15407         0.263068         0.211869         0.302262          0.222801
# 15408         0.271545         0.210899         0.289618          0.227938
# 15409         0.309245         0.246567         0.261236          0.182952
# 15410         0.284087         0.207209         0.274504          0.234201
# 15411         0.205882         0.164000         0.384706          0.245412
# 15412         0.227729         0.191973         0.411189          0.169109
# 15413         0.281864         0.198264         0.260621          0.259251
# 15414         0.184267         0.285949         0.357342          0.172442
# 15415         0.314384         0.235788         0.258794          0.191033
# 15416         0.277906         0.245112         0.275140          0.201842
# 15417         0.271144         0.251216         0.306763          0.170877
# 15418         0.281387         0.210260         0.291765          0.216588
# 15419         0.232271         0.302254         0.344760          0.120715
# 15420         0.261711         0.197788         0.336207          0.204294
# 15421         0.187595         0.251135         0.373676          0.187595
# 15422         0.209232         0.337749         0.348812          0.104207
# 15423         0.208333         0.175417         0.300000          0.316250
# 15424         0.194715         0.390595         0.302410          0.112281
# 15425         0.241820         0.178403         0.400185          0.179592
# 15426         0.264182         0.190047         0.302683          0.243088
# 15427         0.315833         0.293855         0.260055          0.130257
# 15428         0.293318         0.224050         0.262566          0.220065
# 15429         0.277576         0.238548         0.302618          0.181258
# 15430         0.261674         0.246749         0.297530          0.194047
# 15431         0.249097         0.204523         0.336685          0.209695
# 15432         0.244606         0.228491         0.323946          0.202956
# 15433         0.261191         0.257549         0.290398          0.190863
# 15434         0.253542         0.252781         0.305432          0.188245
# 15435         0.264143         0.271978         0.302295          0.161584
# 15436         0.267826         0.259664         0.302045          0.170465
#
# [15437 rows x 66 columns]

# %%
#Negative Margin of victory implies larger win for republicans
df['MARGIN_VICTORY']=abs((df['DEM_VOTES']/df['COUNTY_TOTALVOTES'])-(df['REP_VOTES']/df['COUNTY_TOTALVOTES']))
df['TOT_WA%'] = df['WA_MALE%'] + df['WA_FEMALE%']
df['TOT_BA%'] = df['BA_MALE%'] + df['BA_FEMALE%']
df['TOT_H%'] = df['H_MALE%'] + df['H_FEMALE%']

# %%
df.head(10)
# Out:
#    Unnamed: 0  ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS    STATE  \
# 0           0   0   20121001  2012           1            1  Alabama
# 1           1   1   20121003  2012           1            3  Alabama
# 2           2   2   20121005  2012           1            5  Alabama
# 3           3   3   20121007  2012           1            7  Alabama
# 4           4   4   20121009  2012           1            9  Alabama
# 5           5   5   20121011  2012           1           11  Alabama
# 6           6   6   20121013  2012           1           13  Alabama
# 7           7   7   20121015  2012           1           15  Alabama
# 8           8   8   20121017  2012           1           17  Alabama
# 9           9   9   20121019  2012           1           19  Alabama
#
#             COUNTY    FIPS REP_CANDIDATE    ...    TOT_FEMALE%  TOT_MALE%  \
# 0   Autauga County  1001.0   Mitt Romney    ...       0.512912   0.487088
# 1   Baldwin County  1003.0   Mitt Romney    ...       0.510581   0.489419
# 2   Barbour County  1005.0   Mitt Romney    ...       0.469301   0.530699
# 3      Bibb County  1007.0   Mitt Romney    ...       0.463799   0.536201
# 4    Blount County  1009.0   Mitt Romney    ...       0.505255   0.494745
# 5   Bullock County  1011.0   Mitt Romney    ...       0.459276   0.540724
# 6    Butler County  1013.0   Mitt Romney    ...       0.529940   0.470060
# 7   Calhoun County  1015.0   Mitt Romney    ...       0.517780   0.482220
# 8  Chambers County  1017.0   Mitt Romney    ...       0.521833   0.478167
# 9  Cherokee County  1019.0   Mitt Romney    ...       0.503889   0.496111
#
#    TOT_POP_LESS19%  TOT_POP_20to39% TOT_POP_40to59% TOT_POP_Above60%  \
# 0         0.293056         0.252858        0.282427         0.171659
# 1         0.253453         0.230183        0.282293         0.234071
# 2         0.242225         0.270801        0.278741         0.208233
# 3         0.248820         0.283097        0.280955         0.187128
# 4         0.271033         0.241682        0.276594         0.210691
# 5         0.248759         0.273212        0.285255         0.192774
# 6         0.266068         0.232452        0.272467         0.229013
# 7         0.259882         0.262102        0.274019         0.203997
# 8         0.247641         0.230057        0.287088         0.235215
# 9         0.237545         0.210056        0.295026         0.257373
#
#    MARGIN_VICTORY   TOT_WA%   TOT_BA%    TOT_H%
# 0        0.460304  0.792801  0.177941  0.023889
# 1        0.557688  0.876354  0.094664  0.044039
# 2        0.031454  0.508452  0.471899  0.049250
# 3        0.466746  0.766221  0.220400  0.017926
# 4        0.740940  0.965785  0.014188  0.081275
# 5        0.527997  0.263651  0.710884  0.071429
# 6        0.075084  0.545268  0.435727  0.009407
# 7        0.319238  0.764444  0.206546  0.032935
# 8        0.051673  0.592902  0.389074  0.015796
# 9        0.549545  0.932740  0.046239  0.012551
#
# [10 rows x 70 columns]

# %%
# see all columns in merged dataframe
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'ID', 'YEAR_FIPS', 'YEAR', 'STATE_FIPS', 'COUNTY_FIPS',
#        'STATE', 'COUNTY', 'FIPS', 'REP_CANDIDATE', 'DEM_CANDIDATE',
#        'REP_VOTES', 'DEM_VOTES', 'COUNTY_TOTALVOTES', 'WINNING_CANDIDATE',
#        'WINNING_PARTY', 'WINNING_PARTY_BINARY', 'HOUSE_WINNING_BINARY',
#        'SENATE_WINNING_BINARY', 'UNEMPLOYMENT_RATE', 'AVG_WAGE_SALARY',
#        'AA_FEMALE', 'AA_MALE', 'BA_FEMALE', 'BA_MALE', 'H_FEMALE', 'H_MALE',
#        'IA_FEMALE', 'IA_MALE', 'NA_FEMALE', 'NA_MALE', 'TOT_FEMALE',
#        'TOT_MALE', 'TOT_POP', 'WA_FEMALE', 'WA_MALE', 'TOT_POP_LESS19',
#        'TOT_MALE_LESS19', 'TOT_FEMALE_LESS19', 'TOT_POP_20to39',
#        'TOT_MALE_20to39', 'TOT_FEMALE_20to39', 'TOT_POP_40to59',
#        'TOT_MALE_40to59', 'TOT_FEMALE_40to59', 'TOT_POP_Above60',
#        'TOT_MALE_Above60', 'TOT_FEMALE_Above60', 'AA_FEMALE%', 'AA_MALE%',
#        'BA_FEMALE%', 'BA_MALE%', 'H_FEMALE%', 'H_MALE%', 'IA_FEMALE%',
#        'IA_MALE%', 'NA_FEMALE%', 'NA_MALE%', 'WA_FEMALE%', 'WA_MALE%',
#        'TOT_FEMALE%', 'TOT_MALE%', 'TOT_POP_LESS19%', 'TOT_POP_20to39%',
#        'TOT_POP_40to59%', 'TOT_POP_Above60%', 'MARGIN_VICTORY', 'TOT_WA%',
#        'TOT_BA%', 'TOT_H%'],
#       dtype='object')

# %%
# see how many nulls there are within dataframe
df.isnull().sum()
# Out:
# Unnamed: 0                  0
# ID                          0
# YEAR_FIPS                   0
# YEAR                        0
# STATE_FIPS                  0
# COUNTY_FIPS                 0
# STATE                       0
# COUNTY                      0
# FIPS                        0
# REP_CANDIDATE               0
# DEM_CANDIDATE               0
# REP_VOTES                   0
# DEM_VOTES                   0
# COUNTY_TOTALVOTES           0
# WINNING_CANDIDATE           0
# WINNING_PARTY               0
# WINNING_PARTY_BINARY        0
# HOUSE_WINNING_BINARY       33
# SENATE_WINNING_BINARY    5261
# UNEMPLOYMENT_RATE           0
# AVG_WAGE_SALARY             0
# AA_FEMALE                   0
# AA_MALE                     0
# BA_FEMALE                   0
# BA_MALE                     0
# H_FEMALE                    0
# H_MALE                      0
# IA_FEMALE                   0
# IA_MALE                     0
# NA_FEMALE                   0
#                          ...
# TOT_MALE_20to39             0
# TOT_FEMALE_20to39           0
# TOT_POP_40to59              0
# TOT_MALE_40to59             0
# TOT_FEMALE_40to59           0
# TOT_POP_Above60             0
# TOT_MALE_Above60            0
# TOT_FEMALE_Above60          0
# AA_FEMALE%                  0
# AA_MALE%                    0
# BA_FEMALE%                  0
# BA_MALE%                    0
# H_FEMALE%                   0
# H_MALE%                     0
# IA_FEMALE%                  0
# IA_MALE%                    0
# NA_FEMALE%                  0
# NA_MALE%                    0
# WA_FEMALE%                  0
# WA_MALE%                    0
# TOT_FEMALE%                 0
# TOT_MALE%                   0
# TOT_POP_LESS19%             0
# TOT_POP_20to39%             0
# TOT_POP_40to59%             0
# TOT_POP_Above60%            0
# MARGIN_VICTORY              0
# TOT_WA%                     0
# TOT_BA%                     0
# TOT_H%                      0
# Length: 70, dtype: int64

# %%
# see how many nulls there are within dataframe
df.describe()
# Out:
#          Unnamed: 0            ID     YEAR_FIPS          YEAR    STATE_FIPS  \
# count  15437.000000  15437.000000  1.543700e+04  15437.000000  15437.000000
# mean    7718.000000   9842.295265  1.838708e+08   2008.034722     30.641640
# std     4456.422388   5780.402235  5.271925e+07      5.660778     14.984992
# min        0.000000      0.000000  2.000100e+07   2000.000000      1.000000
# 25%     3859.000000   4230.000000  2.000485e+08   2004.000000     19.000000
# 50%     7718.000000  10987.000000  2.008212e+08   2008.000000     29.000000
# 75%    11577.000000  14921.000000  2.012391e+08   2012.000000     46.000000
# max    15436.000000  18854.000000  2.016560e+08   2016.000000     56.000000
#
#         COUNTY_FIPS          FIPS     REP_VOTES     DEM_VOTES  \
# count  15437.000000  15437.000000  1.543700e+04  1.543700e+04
# mean     103.602902  30745.243117  1.912239e+04  2.017164e+04
# std      108.116249  15004.119529  4.417742e+04  7.185842e+04
# min        1.000000   1001.000000  5.400000e+01  4.000000e+00
# 25%       35.000000  19073.000000  2.909000e+03  1.600000e+03
# 50%       79.000000  29510.000000  6.339000e+03  3.961000e+03
# 75%      133.000000  46017.000000  1.603000e+04  1.080100e+04
# max      840.000000  56045.000000  1.076225e+06  2.464364e+06
#
#        COUNTY_TOTALVOTES      ...        TOT_FEMALE%     TOT_MALE%  \
# count       1.543700e+04      ...       15437.000000  15437.000000
# mean        4.019208e+04      ...           0.501840      0.498160
# std         1.148100e+05      ...           0.021356      0.021356
# min         6.400000e+01      ...           0.278792      0.425760
# 25%         4.856000e+03      ...           0.497669      0.487669
# 50%         1.068300e+04      ...           0.505558      0.494442
# 75%         2.770900e+04      ...           0.512331      0.502331
# max         3.434308e+06      ...           0.574240      0.721208
#
#        TOT_POP_LESS19%  TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%  \
# count     15437.000000     15437.000000     15437.000000      15437.000000
# mean          0.267314         0.242665         0.276653          0.213369
# std           0.034897         0.044546         0.026337          0.053222
# min           0.083033         0.118812         0.089292          0.027190
# 25%           0.246773         0.214722         0.262610          0.177398
# 50%           0.266625         0.239430         0.277704          0.208984
# 75%           0.286111         0.265578         0.291647          0.244484
# max           0.475359         0.548296         0.462687          0.632964
#
#        MARGIN_VICTORY       TOT_WA%       TOT_BA%        TOT_H%
# count    15437.000000  15437.000000  15437.000000  15437.000000
# mean         0.291992      0.864514      0.091433      0.076575
# std          0.196820      0.158742      0.146440      0.129256
# min          0.000012      0.091430      0.000000      0.000000
# 25%          0.127231      0.819706      0.005046      0.013608
# 50%          0.264285      0.933157      0.021527      0.027831
# 75%          0.432126      0.970204      0.106276      0.071946
# max          1.209800      1.000000      0.865371      0.975417
#
# [8 rows x 64 columns]

# %%
#Checking if data contains one hot encoded data
df['WINNING_PARTY_BINARY'].describe()
#df['WINNING_PARTY_BINARY'].head()
# Out:
# count    15437.000000
# mean         0.786034
# std          0.410117
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000
# Name: WINNING_PARTY_BINARY, dtype: float64

# %%
#Size of Dataset after dropping null values - 2020 data has been dropped in this dataset as we dont have election predictions
df.shape
# Out:
# (15437, 70)

# %% [markdown]
# ## EXPLORATORY DATA ANALYSIS

# %%
#EDA
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15437 entries, 0 to 15436
# Data columns (total 70 columns):
# Unnamed: 0               15437 non-null int64
# ID                       15437 non-null int64
# YEAR_FIPS                15437 non-null int64
# YEAR                     15437 non-null int64
# STATE_FIPS               15437 non-null int64
# COUNTY_FIPS              15437 non-null int64
# STATE                    15437 non-null object
# COUNTY                   15437 non-null object
# FIPS                     15437 non-null float64
# REP_CANDIDATE            15437 non-null object
# DEM_CANDIDATE            15437 non-null object
# REP_VOTES                15437 non-null float64
# DEM_VOTES                15437 non-null float64
# COUNTY_TOTALVOTES        15437 non-null float64
# WINNING_CANDIDATE        15437 non-null object
# WINNING_PARTY            15437 non-null object
# WINNING_PARTY_BINARY     15437 non-null int64
# HOUSE_WINNING_BINARY     15404 non-null float64
# SENATE_WINNING_BINARY    10176 non-null float64
# UNEMPLOYMENT_RATE        15437 non-null float64
# AVG_WAGE_SALARY          15437 non-null float64
# AA_FEMALE                15437 non-null int64
# AA_MALE                  15437 non-null int64
# BA_FEMALE                15437 non-null int64
# BA_MALE                  15437 non-null int64
# H_FEMALE                 15437 non-null int64
# H_MALE                   15437 non-null int64
# IA_FEMALE                15437 non-null int64
# IA_MALE                  15437 non-null int64
# NA_FEMALE                15437 non-null float64
# NA_MALE                  15437 non-null int64
# TOT_FEMALE               15437 non-null int64
# TOT_MALE                 15437 non-null int64
# TOT_POP                  15437 non-null int64
# WA_FEMALE                15437 non-null int64
# WA_MALE                  15437 non-null int64
# TOT_POP_LESS19           15437 non-null int64
# TOT_MALE_LESS19          15437 non-null int64
# TOT_FEMALE_LESS19        15437 non-null int64
# TOT_POP_20to39           15437 non-null int64
# TOT_MALE_20to39          15437 non-null int64
# TOT_FEMALE_20to39        15437 non-null int64
# TOT_POP_40to59           15437 non-null int64
# TOT_MALE_40to59          15437 non-null int64
# TOT_FEMALE_40to59        15437 non-null int64
# TOT_POP_Above60          15437 non-null int64
# TOT_MALE_Above60         15437 non-null int64
# TOT_FEMALE_Above60       15437 non-null int64
# AA_FEMALE%               15437 non-null float64
# AA_MALE%                 15437 non-null float64
# BA_FEMALE%               15437 non-null float64
# BA_MALE%                 15437 non-null float64
# H_FEMALE%                15437 non-null float64
# H_MALE%                  15437 non-null float64
# IA_FEMALE%               15437 non-null float64
# IA_MALE%                 15437 non-null float64
# NA_FEMALE%               15437 non-null float64
# NA_MALE%                 15437 non-null float64
# WA_FEMALE%               15437 non-null float64
# WA_MALE%                 15437 non-null float64
# TOT_FEMALE%              15437 non-null float64
# TOT_MALE%                15437 non-null float64
# TOT_POP_LESS19%          15437 non-null float64
# TOT_POP_20to39%          15437 non-null float64
# TOT_POP_40to59%          15437 non-null float64
# TOT_POP_Above60%         15437 non-null float64
# MARGIN_VICTORY           15437 non-null float64
# TOT_WA%                  15437 non-null float64
# TOT_BA%                  15437 non-null float64
# TOT_H%                   15437 non-null float64
# dtypes: float64(31), int64(33), object(6)
# memory usage: 8.2+ MB

# %%
#Determining Missing values
# No missing values
df[df.isnull().any(axis=1)]
# Out:
#        Unnamed: 0     ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS  \
# 0               0      0   20121001  2012           1            1
# 1               1      1   20121003  2012           1            3
# 2               2      2   20121005  2012           1            5
# 3               3      3   20121007  2012           1            7
# 4               4      4   20121009  2012           1            9
# 5               5      5   20121011  2012           1           11
# 6               6      6   20121013  2012           1           13
# 7               7      7   20121015  2012           1           15
# 8               8      8   20121017  2012           1           17
# 9               9      9   20121019  2012           1           19
# 10             10     10   20121021  2012           1           21
# 11             11     11   20121023  2012           1           23
# 12             12     12   20121025  2012           1           25
# 13             13     13   20121027  2012           1           27
# 14             14     14   20121029  2012           1           29
# 15             15     15   20121031  2012           1           31
# 16             16     16   20121033  2012           1           33
# 17             17     17   20121035  2012           1           35
# 18             18     18   20121037  2012           1           37
# 19             19     19   20121039  2012           1           39
# 20             20     20   20121041  2012           1           41
# 21             21     21   20121043  2012           1           43
# 22             22     22   20121045  2012           1           45
# 23             23     23   20121047  2012           1           47
# 24             24     24   20121049  2012           1           49
# 25             25     25   20121051  2012           1           51
# 26             26     26   20121053  2012           1           53
# 27             27     27   20121055  2012           1           55
# 28             28     28   20121057  2012           1           57
# 29             29     29   20121059  2012           1           59
# ...           ...    ...        ...   ...         ...          ...
# 15343       15343  18761   20086073  2008           6           73
# 15344       15344  18762   20086075  2008           6           75
# 15345       15345  18763   20086077  2008           6           77
# 15346       15346  18764   20086079  2008           6           79
# 15347       15347  18765   20086081  2008           6           81
# 15348       15348  18766   20086083  2008           6           83
# 15349       15349  18767   20086085  2008           6           85
# 15350       15350  18768   20086087  2008           6           87
# 15351       15351  18769   20086089  2008           6           89
# 15352       15352  18770   20086091  2008           6           91
# 15353       15353  18771   20086093  2008           6           93
# 15354       15354  18772   20086095  2008           6           95
# 15355       15355  18773   20086097  2008           6           97
# 15356       15356  18774   20086099  2008           6           99
# 15357       15357  18775   20086101  2008           6          101
# 15358       15358  18776   20086103  2008           6          103
# 15359       15359  18777   20086105  2008           6          105
# 15360       15360  18778   20086107  2008           6          107
# 15361       15361  18779   20086109  2008           6          109
# 15362       15362  18780   20086111  2008           6          111
# 15363       15363  18781   20086113  2008           6          113
# 15364       15364  18782   20086115  2008           6          115
# 15429       15429  18847   20089001  2008           9            1
# 15430       15430  18848   20089003  2008           9            3
# 15431       15431  18849   20089005  2008           9            5
# 15432       15432  18850   20089007  2008           9            7
# 15433       15433  18851   20089009  2008           9            9
# 15434       15434  18852   20089011  2008           9           11
# 15435       15435  18853   20089013  2008           9           13
# 15436       15436  18854   20089015  2008           9           15
#
#              STATE                  COUNTY    FIPS REP_CANDIDATE    ...     \
# 0          Alabama          Autauga County  1001.0   Mitt Romney    ...
# 1          Alabama          Baldwin County  1003.0   Mitt Romney    ...
# 2          Alabama          Barbour County  1005.0   Mitt Romney    ...
# 3          Alabama             Bibb County  1007.0   Mitt Romney    ...
# 4          Alabama           Blount County  1009.0   Mitt Romney    ...
# 5          Alabama          Bullock County  1011.0   Mitt Romney    ...
# 6          Alabama           Butler County  1013.0   Mitt Romney    ...
# 7          Alabama          Calhoun County  1015.0   Mitt Romney    ...
# 8          Alabama         Chambers County  1017.0   Mitt Romney    ...
# 9          Alabama         Cherokee County  1019.0   Mitt Romney    ...
# 10         Alabama          Chilton County  1021.0   Mitt Romney    ...
# 11         Alabama          Choctaw County  1023.0   Mitt Romney    ...
# 12         Alabama           Clarke County  1025.0   Mitt Romney    ...
# 13         Alabama             Clay County  1027.0   Mitt Romney    ...
# 14         Alabama         Cleburne County  1029.0   Mitt Romney    ...
# 15         Alabama           Coffee County  1031.0   Mitt Romney    ...
# 16         Alabama          Colbert County  1033.0   Mitt Romney    ...
# 17         Alabama          Conecuh County  1035.0   Mitt Romney    ...
# 18         Alabama            Coosa County  1037.0   Mitt Romney    ...
# 19         Alabama        Covington County  1039.0   Mitt Romney    ...
# 20         Alabama         Crenshaw County  1041.0   Mitt Romney    ...
# 21         Alabama          Cullman County  1043.0   Mitt Romney    ...
# 22         Alabama             Dale County  1045.0   Mitt Romney    ...
# 23         Alabama           Dallas County  1047.0   Mitt Romney    ...
# 24         Alabama           DeKalb County  1049.0   Mitt Romney    ...
# 25         Alabama           Elmore County  1051.0   Mitt Romney    ...
# 26         Alabama         Escambia County  1053.0   Mitt Romney    ...
# 27         Alabama           Etowah County  1055.0   Mitt Romney    ...
# 28         Alabama          Fayette County  1057.0   Mitt Romney    ...
# 29         Alabama         Franklin County  1059.0   Mitt Romney    ...
# ...            ...                     ...     ...           ...    ...
# 15343   California        San Diego County  6073.0   John McCain    ...
# 15344   California    San Francisco County  6075.0   John McCain    ...
# 15345   California      San Joaquin County  6077.0   John McCain    ...
# 15346   California  San Luis Obispo County  6079.0   John McCain    ...
# 15347   California        San Mateo County  6081.0   John McCain    ...
# 15348   California    Santa Barbara County  6083.0   John McCain    ...
# 15349   California      Santa Clara County  6085.0   John McCain    ...
# 15350   California       Santa Cruz County  6087.0   John McCain    ...
# 15351   California           Shasta County  6089.0   John McCain    ...
# 15352   California           Sierra County  6091.0   John McCain    ...
# 15353   California         Siskiyou County  6093.0   John McCain    ...
# 15354   California           Solano County  6095.0   John McCain    ...
# 15355   California           Sonoma County  6097.0   John McCain    ...
# 15356   California       Stanislaus County  6099.0   John McCain    ...
# 15357   California           Sutter County  6101.0   John McCain    ...
# 15358   California           Tehama County  6103.0   John McCain    ...
# 15359   California          Trinity County  6105.0   John McCain    ...
# 15360   California           Tulare County  6107.0   John McCain    ...
# 15361   California         Tuolumne County  6109.0   John McCain    ...
# 15362   California          Ventura County  6111.0   John McCain    ...
# 15363   California             Yolo County  6113.0   John McCain    ...
# 15364   California             Yuba County  6115.0   John McCain    ...
# 15429  Connecticut        Fairfield County  9001.0   John McCain    ...
# 15430  Connecticut         Hartford County  9003.0   John McCain    ...
# 15431  Connecticut       Litchfield County  9005.0   John McCain    ...
# 15432  Connecticut        Middlesex County  9007.0   John McCain    ...
# 15433  Connecticut        New Haven County  9009.0   John McCain    ...
# 15434  Connecticut       New London County  9011.0   John McCain    ...
# 15435  Connecticut          Tolland County  9013.0   John McCain    ...
# 15436  Connecticut          Windham County  9015.0   John McCain    ...
#
#       TOT_FEMALE%  TOT_MALE%  TOT_POP_LESS19%  TOT_POP_20to39%  \
# 0        0.512912   0.487088         0.293056         0.252858
# 1        0.510581   0.489419         0.253453         0.230183
# 2        0.469301   0.530699         0.242225         0.270801
# 3        0.463799   0.536201         0.248820         0.283097
# 4        0.505255   0.494745         0.271033         0.241682
# 5        0.459276   0.540724         0.248759         0.273212
# 6        0.529940   0.470060         0.266068         0.232452
# 7        0.517780   0.482220         0.259882         0.262102
# 8        0.521833   0.478167         0.247641         0.230057
# 9        0.503889   0.496111         0.237545         0.210056
# 10       0.505143   0.494857         0.275582         0.258241
# 11       0.518088   0.481912         0.248899         0.209690
# 12       0.527499   0.472501         0.273588         0.221735
# 13       0.510254   0.489746         0.248111         0.225516
# 14       0.502466   0.497534         0.262530         0.228006
# 15       0.505946   0.494054         0.266009         0.265611
# 16       0.519230   0.480770         0.246089         0.228996
# 17       0.516095   0.483905         0.257065         0.204851
# 18       0.494568   0.505432         0.224834         0.218554
# 19       0.515551   0.484449         0.250212         0.221570
# 20       0.517443   0.482557         0.263442         0.227260
# 21       0.506153   0.493847         0.257625         0.242623
# 22       0.506092   0.493908         0.272395         0.275094
# 23       0.537665   0.462335         0.293183         0.233835
# 24       0.506148   0.493852         0.284054         0.249160
# 25       0.511530   0.488470         0.262262         0.271900
# 26       0.484065   0.515935         0.252086         0.260145
# 27       0.515073   0.484927         0.255325         0.240467
# 28       0.506763   0.493237         0.249840         0.216811
# 29       0.500772   0.499228         0.275256         0.254308
# ...           ...        ...              ...              ...
# 15343    0.498550   0.501450         0.271015         0.309344
# 15344    0.493962   0.506038         0.156360         0.374338
# 15345    0.501159   0.498841         0.333577         0.272979
# 15346    0.487217   0.512783         0.241363         0.273041
# 15347    0.508779   0.491221         0.244778         0.273267
# 15348    0.498190   0.501810         0.281634         0.296895
# 15349    0.497174   0.502826         0.268140         0.303670
# 15350    0.501484   0.498516         0.262412         0.286079
# 15351    0.508173   0.491827         0.263118         0.224624
# 15352    0.490068   0.509932         0.204566         0.163060
# 15353    0.504779   0.495221         0.235669         0.186146
# 15354    0.498571   0.501429         0.285110         0.270307
# 15355    0.507418   0.492582         0.256002         0.253130
# 15356    0.504691   0.495309         0.326945         0.277337
# 15357    0.502867   0.497133         0.309696         0.270216
# 15358    0.503146   0.496854         0.288510         0.221491
# 15359    0.483880   0.516120         0.218494         0.168523
# 15360    0.499415   0.500585         0.361958         0.277642
# 15361    0.472355   0.527645         0.207529         0.214168
# 15362    0.502779   0.497221         0.296312         0.263066
# 15363    0.511843   0.488157         0.290760         0.336510
# 15364    0.495301   0.504699         0.326621         0.287673
# 15429    0.514643   0.485357         0.277576         0.238548
# 15430    0.516820   0.483180         0.261674         0.246749
# 15431    0.508827   0.491173         0.249097         0.204523
# 15432    0.511756   0.488244         0.244606         0.228491
# 15433    0.518593   0.481407         0.261191         0.257549
# 15434    0.502263   0.497737         0.253542         0.252781
# 15435    0.496066   0.503934         0.264143         0.271978
# 15436    0.503941   0.496059         0.267826         0.259664
#
#       TOT_POP_40to59% TOT_POP_Above60%  MARGIN_VICTORY   TOT_WA%   TOT_BA%  \
# 0            0.282427         0.171659        0.460304  0.792801  0.177941
# 1            0.282293         0.234071        0.557688  0.876354  0.094664
# 2            0.278741         0.208233        0.031454  0.508452  0.471899
# 3            0.280955         0.187128        0.466746  0.766221  0.220400
# 4            0.276594         0.210691        0.740940  0.965785  0.014188
# 5            0.285255         0.192774        0.527997  0.263651  0.710884
# 6            0.272467         0.229013        0.075084  0.545268  0.435727
# 7            0.274019         0.203997        0.319238  0.764444  0.206546
# 8            0.287088         0.235215        0.051673  0.592902  0.389074
# 9            0.295026         0.257373        0.549545  0.932740  0.046239
# 10           0.272765         0.193412        0.603310  0.880833  0.099466
# 11           0.289840         0.251571        0.045934  0.560690  0.432594
# 12           0.282166         0.222511        0.082016  0.545624  0.441102
# 13           0.284594         0.241779        0.456319  0.830611  0.147730
# 14           0.282525         0.226939        0.682157  0.950746  0.033724
# 15           0.265213         0.203167        0.492716  0.774584  0.169784
# 16           0.285887         0.239028        0.203977  0.812691  0.162348
# 17           0.284117         0.253967        0.016520  0.517002  0.468339
# 18           0.313190         0.243422        0.162839  0.665082  0.317518
# 19           0.278562         0.249656        0.583220  0.851079  0.125516
# 20           0.281462         0.227836        0.355407  0.733314  0.233026
# 21           0.275971         0.223780        0.694982  0.967870  0.011249
# 22           0.260786         0.191725        0.421512  0.758504  0.194007
# 23           0.272139         0.200844        0.397270  0.291564  0.696147
# 24           0.267092         0.199694        0.548632  0.927599  0.017637
# 25           0.289317         0.176521        0.487502  0.772258  0.202508
# 26           0.277201         0.210567        0.255431  0.628834  0.319737
# 27           0.279460         0.224747        0.383894  0.817883  0.152860
# 28           0.285076         0.248273        0.533224  0.870146  0.114820
# 29           0.261490         0.208946        0.404825  0.927327  0.040510
# ...               ...              ...             ...       ...       ...
# 15343        0.266939         0.152701        0.101986  0.783062  0.055824
# 15344        0.284320         0.184983        0.705021  0.547403  0.067516
# 15345        0.254676         0.138768        0.106841  0.701923  0.081263
# 15346        0.286627         0.198969        0.053681  0.903889  0.022518
# 15347        0.300121         0.181834        0.487217  0.663487  0.032677
# 15348        0.251885         0.169586        0.228852  0.874111  0.023689
# 15349        0.280257         0.147933        0.408964  0.605629  0.029001
# 15350        0.297204         0.154305        0.576555  0.893136  0.012787
# 15351        0.292827         0.219430        0.257756  0.900157  0.008712
# 15352        0.358138         0.274237        0.208438  0.959087  0.001779
# 15353        0.314315         0.263870        0.103773  0.887912  0.013179
# 15354        0.292762         0.151821        0.286135  0.618019  0.154516
# 15355        0.303813         0.187054        0.496013  0.889656  0.017284
# 15356        0.254483         0.141235        0.017278  0.857804  0.031605
# 15357        0.256199         0.163889        0.166935  0.775320  0.022462
# 15358        0.279016         0.210984        0.241365  0.922603  0.007128
# 15359        0.349575         0.263409        0.045968  0.895662  0.004689
# 15360        0.230485         0.129914        0.153328  0.894606  0.020254
# 15361        0.315803         0.262500        0.127148  0.918121  0.021797
# 15362        0.284838         0.155783        0.122861  0.864352  0.021383
# 15363        0.240734         0.131996        0.362337  0.782900  0.027534
# 15364        0.248710         0.136996        0.146769  0.804172  0.036659
# 15429        0.302618         0.181258        0.181162  0.822671  0.113007
# 15430        0.297530         0.194047        0.314691  0.797707  0.140532
# 15431        0.336685         0.209695        0.049166  0.955463  0.014721
# 15432        0.323946         0.202956        0.230153  0.910741  0.047469
# 15433        0.290398         0.190863        0.231454  0.811429  0.132198
# 15434        0.305432         0.188245        0.210676  0.860287  0.062456
# 15435        0.302295         0.161584        0.208299  0.918934  0.033102
# 15436        0.302045         0.170465        0.229665  0.938811  0.025357
#
#          TOT_H%
# 0      0.023889
# 1      0.044039
# 2      0.049250
# 3      0.017926
# 4      0.081275
# 5      0.071429
# 6      0.009407
# 7      0.032935
# 8      0.015796
# 9      0.012551
# 10     0.078551
# 11     0.005416
# 12     0.010635
# 13     0.028567
# 14     0.020794
# 15     0.063918
# 16     0.020394
# 17     0.012392
# 18     0.019436
# 19     0.013091
# 20     0.014848
# 21     0.042819
# 22     0.056519
# 23     0.007159
# 24     0.136118
# 25     0.026993
# 26     0.018986
# 27     0.032837
# 28     0.011958
# 29     0.149157
# ...         ...
# 15343  0.305981
# 15344  0.144890
# 15345  0.370758
# 15346  0.193816
# 15347  0.238442
# 15348  0.399331
# 15349  0.258452
# 15350  0.300710
# 15351  0.078041
# 15352  0.078862
# 15353  0.097178
# 15354  0.226571
# 15355  0.229829
# 15356  0.399894
# 15357  0.274013
# 15358  0.202858
# 15359  0.064258
# 15360  0.579985
# 15361  0.099665
# 15362  0.382825
# 15363  0.290549
# 15364  0.235652
# 15429  0.154332
# 15430  0.140619
# 15431  0.039960
# 15432  0.042253
# 15433  0.135312
# 15434  0.074663
# 15435  0.039514
# 15436  0.087697
#
# [5261 rows x 70 columns]

# %%
# generate preview of entries with null values
if len(df[df.isnull().any(axis=1)] != 0):
    print("\nPreview of data with null values:\nxxxxxxxxxxxxx")
    print(df[df.isnull().any(axis=1)].head(3))
    print(df[df.isnull().any(axis=1)].tail(3))
    plt.show()
# Out:
# Preview of data with null values:
# xxxxxxxxxxxxx
#    Unnamed: 0  ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS    STATE  \
# 0           0   0   20121001  2012           1            1  Alabama
# 1           1   1   20121003  2012           1            3  Alabama
# 2           2   2   20121005  2012           1            5  Alabama
#
#            COUNTY    FIPS REP_CANDIDATE    ...    TOT_FEMALE%  TOT_MALE%  \
# 0  Autauga County  1001.0   Mitt Romney    ...       0.512912   0.487088
# 1  Baldwin County  1003.0   Mitt Romney    ...       0.510581   0.489419
# 2  Barbour County  1005.0   Mitt Romney    ...       0.469301   0.530699
#
#    TOT_POP_LESS19%  TOT_POP_20to39% TOT_POP_40to59% TOT_POP_Above60%  \
# 0         0.293056         0.252858        0.282427         0.171659
# 1         0.253453         0.230183        0.282293         0.234071
# 2         0.242225         0.270801        0.278741         0.208233
#
#    MARGIN_VICTORY   TOT_WA%   TOT_BA%    TOT_H%
# 0        0.460304  0.792801  0.177941  0.023889
# 1        0.557688  0.876354  0.094664  0.044039
# 2        0.031454  0.508452  0.471899  0.049250
#
# [3 rows x 70 columns]
#        Unnamed: 0     ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS  \
# 15434       15434  18852   20089011  2008           9           11
# 15435       15435  18853   20089013  2008           9           13
# 15436       15436  18854   20089015  2008           9           15
#
#              STATE             COUNTY    FIPS REP_CANDIDATE    ...     \
# 15434  Connecticut  New London County  9011.0   John McCain    ...
# 15435  Connecticut     Tolland County  9013.0   John McCain    ...
# 15436  Connecticut     Windham County  9015.0   John McCain    ...
#
#       TOT_FEMALE%  TOT_MALE%  TOT_POP_LESS19%  TOT_POP_20to39%  \
# 15434    0.502263   0.497737         0.253542         0.252781
# 15435    0.496066   0.503934         0.264143         0.271978
# 15436    0.503941   0.496059         0.267826         0.259664
#
#       TOT_POP_40to59% TOT_POP_Above60%  MARGIN_VICTORY   TOT_WA%   TOT_BA%  \
# 15434        0.305432         0.188245        0.210676  0.860287  0.062456
# 15435        0.302295         0.161584        0.208299  0.918934  0.033102
# 15436        0.302045         0.170465        0.229665  0.938811  0.025357
#
#          TOT_H%
# 15434  0.074663
# 15435  0.039514
# 15436  0.087697
#
# [3 rows x 70 columns]

# %% [markdown]
# As it appears the missing values are primarily in the 2008 and 2012 data.

# %%
# generate count statistics of duplicate entries
if len(df[df.duplicated()]) > 0:
    print("No. of duplicated entries: ", len(df[df.duplicated()]))
    print(df[df.duplicated(keep=False)].sort_values(by=list(df.columns)).head())
else:
    print("No duplicated entries found")
# Out:
# No duplicated entries found

# %%
#number of counties in the consolidated dataset
df['FIPS'].nunique()
# Out:
# 3114

# %% [markdown]
# The Dataset does not contain all the counties.

# %% [markdown]
# ## MARGIN OF VICTORY

# %%
#Margin of victory analysis by Year
def histPlot(first_feature,col):
    sns.distplot(first_feature,color=col);

f = plt.figure(figsize=(15,10))
f.add_subplot(231)
histPlot(df[df.YEAR==2000]['MARGIN_VICTORY'],'olivedrab')
f.add_subplot(232)
histPlot(df[df.YEAR==2004]['MARGIN_VICTORY'],'c')
f.add_subplot(233)
histPlot(df[df.YEAR==2008]['MARGIN_VICTORY'],'darkorange')
f.add_subplot(234)
histPlot(df[df.YEAR==2012]['MARGIN_VICTORY'],'olive')
f.add_subplot(235)
histPlot(df[df.YEAR==2016]['MARGIN_VICTORY'],'greenyellow')

#We observe below that in 2016 more counties were won with a larger margin of victory

# %% [markdown]
# ## ECONOMIC VARIABLES BY WINNING PARTY

# %%
#Analyzing the Economic Variables
colors = ['red','blue']
cmap = sns.color_palette(colors)

def boxPlot(first_feature, sec_feature):
    sns.boxplot(x=first_feature, y=sec_feature, data=df, palette=cmap, width=0.5,hue="WINNING_PARTY");

f = plt.figure(figsize=(20,25))
f.add_subplot(211)
boxPlot('YEAR','AVG_WAGE_SALARY')
f.add_subplot(212)
boxPlot('YEAR','UNEMPLOYMENT_RATE')

# %% [markdown]
# ## ECONOMIC VARIABLES BY WINNING PARTY AND YEAR

# %%
colors = ['red','blue']
cmap = sns.color_palette(colors)
year=[2008,2012,2016]
df_year = df[df.YEAR.isin(year)]

sns.lmplot(x="UNEMPLOYMENT_RATE", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");
sns.lmplot(x="AVG_WAGE_SALARY", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");

# %% [markdown]
# ## RACIAL MIX BY WINNING PARTY AND YEAR

# %%
#Analyzing the Economic Variables
colors = ['red','blue']
cmap = sns.color_palette(colors)

def boxPlot(first_feature, sec_feature):
    sns.boxplot(x=first_feature, y=sec_feature, data=df, palette=cmap, width=0.5,hue="WINNING_PARTY");

f = plt.figure(figsize=(20,25))
f.add_subplot(311)
boxPlot('YEAR','TOT_WA%')
f.add_subplot(312)
boxPlot('YEAR','TOT_BA%')
f.add_subplot(313)
boxPlot('YEAR','TOT_H%')

# %%
#Analyzing White Population Mix and Winning Party
sns.set(style="darkgrid")
d = {'color': ['r', 'b']}
g = sns.FacetGrid(df, row="WINNING_PARTY", col="YEAR", margin_titles=True,hue_kws=d,hue="WINNING_PARTY")
bins = np.linspace(0, 1, 20)
g.map(plt.hist, "TOT_WA%", bins=bins)

# %%
#Analyzing BLack Population Mix and Winning Party
sns.set(style="darkgrid")
d = {'color': ['r', 'b']}
g = sns.FacetGrid(df, row="WINNING_PARTY", col="YEAR", margin_titles=True,hue_kws=d,hue="WINNING_PARTY")
bins = np.linspace(0, 1, 20)
g.map(plt.hist, "TOT_BA%", bins=bins)

# %%
#Analyzing Hispanic Population Mix and Winning Party
sns.set(style="darkgrid")
d = {'color': ['r', 'b']}
g = sns.FacetGrid(df, row="WINNING_PARTY", col="YEAR", margin_titles=True,hue_kws=d,hue="WINNING_PARTY")
bins = np.linspace(0, 1, 20)
g.map(plt.hist, "TOT_H%", bins=bins)

# %%
#Analyzing Racial Mix with Year and Winning Party
colors = ['red','blue']
cmap = sns.color_palette(colors)
year=[2008,2012,2016]
df_year = df[df.YEAR.isin(year)]

sns.lmplot(x="TOT_WA%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");
sns.lmplot(x="TOT_BA%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");
sns.lmplot(x="TOT_H%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap,  col="YEAR");

# %% [markdown]
# ## AGE GROUP BY WINNING PARTY AND YEAR

# %%
#Analyzing Age group incluence on the results
colors = ['red','blue']
cmap = sns.color_palette(colors)

def boxPlot(first_feature, sec_feature):
    sns.boxplot(x=first_feature, y=sec_feature, data=df, palette=cmap, width=0.5,hue="WINNING_PARTY");

f = plt.figure(figsize=(20,25))
f.add_subplot(311)
boxPlot('YEAR','TOT_POP_Above60%')
f.add_subplot(312)
boxPlot('YEAR','TOT_POP_40to59%')
f.add_subplot(313)
boxPlot('YEAR','TOT_POP_20to39%')

# %%
#Analyzing Racial Mix with Year and Winning Party
colors = ['red','blue']
cmap = sns.color_palette(colors)
year=[2008,2012,2016]
df_year = df[df.YEAR.isin(year)]

sns.lmplot(x="TOT_POP_Above60%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");
sns.lmplot(x="TOT_POP_40to59%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap, col="YEAR");
sns.lmplot(x="TOT_POP_20to39%", y="MARGIN_VICTORY",hue="WINNING_PARTY",data=df_year, palette=cmap,  col="YEAR");

# %% [markdown]
# # ANALYZING NUMBER OF SWING STATES

# %%
#Margin of Victory Analysis
df['MARGIN_VICTORY'].describe()
# Out:
# count    15437.000000
# mean         0.291992
# std          0.196820
# min          0.000012
# 25%          0.127231
# 50%          0.264285
# 75%          0.432126
# max          1.209800
# Name: MARGIN_VICTORY, dtype: float64

# %%
#Filtering for Margin of Victory less than 1%
df_swing_1 = df[(df.MARGIN_VICTORY < 0.01)]

# %%
df_swing_1['MARGIN_VICTORY'].describe()
# Out:
# count    308.000000
# mean       0.004955
# std        0.002899
# min        0.000012
# 25%        0.002260
# 50%        0.004963
# 75%        0.007515
# max        0.009928
# Name: MARGIN_VICTORY, dtype: float64

# %%
#Number of counties with Margin of Victory less than 1%
df_swing_1.groupby('YEAR').count()
# Out:
#       Unnamed: 0  ID  YEAR_FIPS  STATE_FIPS  COUNTY_FIPS  STATE  COUNTY  FIPS  \
# YEAR
# 2000          77  77         77          77           77     77      77    77
# 2004          63  63         63          63           63     63      63    63
# 2008          76  76         76          76           76     76      76    76
# 2012          61  61         61          61           61     61      61    61
# 2016          31  31         31          31           31     31      31    31
#
#       REP_CANDIDATE  DEM_CANDIDATE   ...    TOT_FEMALE%  TOT_MALE%  \
# YEAR                                 ...
# 2000             77             77   ...             77         77
# 2004             63             63   ...             63         63
# 2008             76             76   ...             76         76
# 2012             61             61   ...             61         61
# 2016             31             31   ...             31         31
#
#       TOT_POP_LESS19%  TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%  \
# YEAR
# 2000               77               77               77                77
# 2004               63               63               63                63
# 2008               76               76               76                76
# 2012               61               61               61                61
# 2016               31               31               31                31
#
#       MARGIN_VICTORY  TOT_WA%  TOT_BA%  TOT_H%
# YEAR
# 2000              77       77       77      77
# 2004              63       63       63      63
# 2008              76       76       76      76
# 2012              61       61       61      61
# 2016              31       31       31      31
#
# [5 rows x 69 columns]

# %%
#Filtering for Margin of Victory less than 2%
df_swing_2 = df[(df.MARGIN_VICTORY < 0.02)]

# %%
df_swing_2['MARGIN_VICTORY'].describe()
# Out:
# count    613.000000
# mean       0.009845
# std        0.005707
# min        0.000012
# 25%        0.004959
# 50%        0.009899
# 75%        0.014606
# max        0.019963
# Name: MARGIN_VICTORY, dtype: float64

# %%
#Number of counties with Margin of Victory less than 5%
df_swing_2.groupby('YEAR').count()
# Out:
#       Unnamed: 0   ID  YEAR_FIPS  STATE_FIPS  COUNTY_FIPS  STATE  COUNTY  \
# YEAR
# 2000         161  161        161         161          161    161     161
# 2004         124  124        124         124          124    124     124
# 2008         152  152        152         152          152    152     152
# 2012         114  114        114         114          114    114     114
# 2016          62   62         62          62           62     62      62
#
#       FIPS  REP_CANDIDATE  DEM_CANDIDATE   ...    TOT_FEMALE%  TOT_MALE%  \
# YEAR                                       ...
# 2000   161            161            161   ...            161        161
# 2004   124            124            124   ...            124        124
# 2008   152            152            152   ...            152        152
# 2012   114            114            114   ...            114        114
# 2016    62             62             62   ...             62         62
#
#       TOT_POP_LESS19%  TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%  \
# YEAR
# 2000              161              161              161               161
# 2004              124              124              124               124
# 2008              152              152              152               152
# 2012              114              114              114               114
# 2016               62               62               62                62
#
#       MARGIN_VICTORY  TOT_WA%  TOT_BA%  TOT_H%
# YEAR
# 2000             161      161      161     161
# 2004             124      124      124     124
# 2008             152      152      152     152
# 2012             114      114      114     114
# 2016              62       62       62      62
#
# [5 rows x 69 columns]

# %% [markdown]
# # EXPLORING INCORPORATING PRESIDENT APPROVAL RATINGS DATA

# %%
# read in president approval rating dataset
potus_ratings = "https://raw.githubusercontent.com/ehuang13/w210-presidential-election/master/data/potus_approval_rating.csv"
ratings_df = pd.read_csv(potus_ratings)

# %%
# check out ratings dataframe
print("POTUS ratings data dimensions: {}".format(ratings_df.shape))
ratings_df.sample(5)
# Out:
# POTUS ratings data dimensions: (4264, 7)
#      start_date   end_date  approve  disapprove  unsure          president  \
# 4097  7/12/2009  7/14/2009       59          33       8       Barack Obama
# 1462   5/1/2017   5/7/2017       42          53       5       Donald Trump
# 1658   7/6/2016   7/8/2016       51          45       4       Barack Obama
# 304   6/25/1964  6/30/1964       73          14      11  Lyndon B. Johnson
# 983   8/23/1996  8/25/1996       52          39       8       Bill Clinton
#
#       reelection_year
# 4097           2012.0
# 1462              NaN
# 1658              NaN
# 304               NaN
# 983            1997.0

# %%
# filter dataframe to re-election years only
reelection_df = ratings_df[ratings_df["reelection_year"].notna()]

# %%
# summarize avg approval rating by president during reelection years
reelection_df = reelection_df.groupby("president").mean()

# %%
# create a column to indicate presidents who were not reelected
lost_reelection = ["Gerald R. Ford", "Jimmy Carter", "George H.W. Bush"]
reelected = [0 if president in lost_reelection else 1 for president in reelection_df.index]
reelection_df["reelected"] = reelected

# %%
# check out reelection dataframe
reelection_df.head(5)
# Out:
#                          approve  disapprove     unsure  reelection_year  \
# president
# Barack Obama           48.937785   43.327769   7.727618           2012.0
# Bill Clinton           49.810345   40.620690   8.215517           1997.0
# Dwight D. Eisenhower   68.461538   17.057692  12.538462           1956.0
# Franklin D. Roosevelt  72.300000   18.600000   7.300000           1944.0
# George H.W. Bush       60.126582   28.202532  10.259494           1992.0
#
#                        reelected
# president
# Barack Obama                   1
# Bill Clinton                   1
# Dwight D. Eisenhower           1
# Franklin D. Roosevelt          1
# George H.W. Bush               0

# %%
# understand distribution and relationship of approval ratings during reelection years
ax1 = sns.pairplot(reelection_df, vars=["approve", "disapprove", "unsure"], hue = "reelected")

# %%
# scatter plot of presidents approval rating in the years
# leading up to the reelection
ax2 = sns.scatterplot(x="reelection_year", y="approve", data=reelection_df, hue="reelected")

# %%
# correlation matrix for reelection against approval ratings
corr = reelection_df.corr()
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# generate custom diverging colormap
cmap = sns.diverging_palette(220, 10, as_cmap=True)

# draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})
