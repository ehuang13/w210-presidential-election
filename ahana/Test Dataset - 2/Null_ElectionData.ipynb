# %%
import pandas as pd

# %%
# load in final merged dataset
df = pd.read_csv('Totaldata_Jul_05.csv', encoding = "ISO-8859-1" )

# %%
df.shape
# Out:
# (18864, 64)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'AGEGRP', 'FIPS_x', 'YEAR', 'STATE', 'COUNTY',
#        'STNAME', 'CTYNAME', 'AA_FEMALE', 'AA_MALE', 'BA_FEMALE', 'BA_MALE',
#        'H_FEMALE', 'H_MALE', 'IA_FEMALE', 'IA_MALE', 'NA_FEMALE', 'NA_MALE',
#        'SUMLEV', 'TOT_FEMALE', 'TOT_MALE', 'TOT_POP', 'WA_FEMALE', 'WA_MALE',
#        'TOT_POP_LESS19', 'TOT_MALE_LESS19', 'TOT_FEMALE_LESS19',
#        'TOT_POP_20to39', 'TOT_MALE_20to39', 'TOT_FEMALE_20to39',
#        'TOT_POP_40to59', 'TOT_MALE_40to59', 'TOT_FEMALE_40to59',
#        'TOT_POP_Above60', 'TOT_MALE_Above60', 'TOT_FEMALE_Above60',
#        'republican_candidate', 'democrat_candidate', 'republican_votes',
#        'democrat_votes', 'county_totalvotes', 'winning candidate',
#        'winning party', 'avg_wage_salary', 'AA_FEMALE%', 'AA_MALE%',
#        'BA_FEMALE%', 'BA_MALE%', 'H_FEMALE%', 'H_MALE%', 'IA_FEMALE%',
#        'IA_MALE%', 'NA_FEMALE%', 'NA_MALE%', 'WA_FEMALE%', 'WA_MALE%',
# ...

# %%
df.isnull().sum(axis = 0)
# Out:
# Unnamed: 0                 0
# ID                         0
# AGEGRP                     0
# FIPS_x                     0
# YEAR                       0
# STATE                      0
# COUNTY                     0
# STNAME                     0
# CTYNAME                    0
# AA_FEMALE                  0
# AA_MALE                    0
# BA_FEMALE                  0
# BA_MALE                    0
# H_FEMALE                   0
# H_MALE                     0
# IA_FEMALE                  0
# IA_MALE                    0
# NA_FEMALE                  0
# NA_MALE                    0
# SUMLEV                     0
# TOT_FEMALE                 0
# TOT_MALE                   0
# TOT_POP                    0
# WA_FEMALE                  0
# WA_MALE                    0
# TOT_POP_LESS19             0
# TOT_MALE_LESS19            0
# TOT_FEMALE_LESS19          0
# TOT_POP_20to39             0
# TOT_MALE_20to39            0
#                         ...
# TOT_POP_Above60            0
# ...

# %%
#Removing 2020 Data as it has null values
df = df[df.YEAR != 2020]
df.isnull().sum(axis = 0)
# Out:
# Unnamed: 0                0
# ID                        0
# AGEGRP                    0
# FIPS_x                    0
# YEAR                      0
# STATE                     0
# COUNTY                    0
# STNAME                    0
# CTYNAME                   0
# AA_FEMALE                 0
# AA_MALE                   0
# BA_FEMALE                 0
# BA_MALE                   0
# H_FEMALE                  0
# H_MALE                    0
# IA_FEMALE                 0
# IA_MALE                   0
# NA_FEMALE                 0
# NA_MALE                   0
# SUMLEV                    0
# TOT_FEMALE                0
# TOT_MALE                  0
# TOT_POP                   0
# WA_FEMALE                 0
# WA_MALE                   0
# TOT_POP_LESS19            0
# TOT_MALE_LESS19           0
# TOT_FEMALE_LESS19         0
# TOT_POP_20to39            0
# TOT_MALE_20to39           0
#                        ...
# TOT_POP_Above60           0
# TOT_MALE_Above60          0
# ...

# %%
df_2000 = df[df.YEAR == 2000]
df_2000.isnull().sum(axis = 0)
# Out:
# Unnamed: 0               0
# ID                       0
# AGEGRP                   0
# FIPS_x                   0
# YEAR                     0
# STATE                    0
# COUNTY                   0
# STNAME                   0
# CTYNAME                  0
# AA_FEMALE                0
# AA_MALE                  0
# BA_FEMALE                0
# BA_MALE                  0
# H_FEMALE                 0
# H_MALE                   0
# IA_FEMALE                0
# IA_MALE                  0
# NA_FEMALE                0
# NA_MALE                  0
# SUMLEV                   0
# TOT_FEMALE               0
# TOT_MALE                 0
# TOT_POP                  0
# WA_FEMALE                0
# WA_MALE                  0
# TOT_POP_LESS19           0
# TOT_MALE_LESS19          0
# TOT_FEMALE_LESS19        0
# TOT_POP_20to39           0
# TOT_MALE_20to39          0
#                         ..
# TOT_POP_Above60          0
# TOT_MALE_Above60         0
# TOT_FEMALE_Above60       0
# ...

# %%
data_null = df_2000[df_2000.isnull().any(axis=1)]
data_null
# Out:
#        Unnamed: 0         ID AGEGRP  FIPS_x  YEAR  STATE  COUNTY  \
# 9731         9731  200015005  Total   15005  2000     15       5
# 10179       10179   20002050  Total    2050  2000      2      50
# 10180       10180   20002060  Total    2060  2000      2      60
# 10181       10181   20002068  Total    2068  2000      2      68
# 10182       10182   20002070  Total    2070  2000      2      70
# 10183       10183   20002090  Total    2090  2000      2      90
# 10184       10184   20002100  Total    2100  2000      2     100
# 10210       10210   20002105  Total    2105  2000      2     105
# 10236       10236   20002110  Total    2110  2000      2     110
# 10297       10297   20002122  Total    2122  2000      2     122
# 10308       10308   20002130  Total    2130  2000      2     130
# 10309       10309   20002150  Total    2150  2000      2     150
# 10310       10310   20002164  Total    2164  2000      2     164
# ...
