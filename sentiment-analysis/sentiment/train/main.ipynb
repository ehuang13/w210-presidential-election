# %%
#Reference - https://github.com/NLPWM-WHU/TransCap/tree/master/TransCap

# %%
from model import *
from utils import *
from generate_tf_flags import *
import tensorflow as tf

print(tf.__version__)

import numpy as np
import time
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

import warnings
warnings.filterwarnings('ignore')

tf.logging.set_verbosity(tf.logging.ERROR)
# Out:
# 1.15.0

# %%
FLAGS = assign_flag_values(tf)

# %%
def main(_):
    start_time = time.time()
    info = ''
    index = 0
    
    for name, value in FLAGS.__flags.items():
        value = value.value
        if index < 19:
            info += '{}:{}  '.format(name, value)
        if index in [5, 11]:
            info += '\n'
        index += 1
    print('\n{:-^80}'.format('Parameters'))
    print(info + '\n')
    
    print('---------')
    print(FLAGS.ASC)
    
    data_path = '../data/{}/'.format(FLAGS.ASC)
    
    if not FLAGS.reuse_embedding :
        print('Initialize Word Dictionary & Embedding')
        word_dict = data_init(data_path, FLAGS.DSC)
        w2v = init_word_embeddings(data_path, word_dict, FLAGS.DSC)
    else:
        print('Reuse Word Dictionary & Embedding')
        with open(data_path + FLAGS.DSC + '_word2id.txt', 'r', encoding='utf-8') as f:
            word_dict = eval(f.read())
        w2v = np.load(data_path + FLAGS.DSC + '_word_embedding.npy')
    
    for i in range(15):
        model = MODEL(FLAGS, w2v, word_dict, data_path)
        model.run()
    
    end_time = time.time()
    print('Running Time: {:.0f}m {:.0f}s'.format((end_time-start_time) // 60, (end_time-start_time) % 60))

# %%
if __name__ == '__main__':
    tf.app.run()
# Out:
# -----------------------------------Parameters-----------------------------------
# logtostderr:False  alsologtostderr:False  log_dir:  v:0  verbosity:0  stderrthreshold:fatal
# showprefixforinfo:True  run_with_pdb:False  pdb_post_mortem:False  run_with_profiling:False  profile_file:None  use_cprofile_for_profiling:True
# only_check_args:False  op_conversion_fallback_to_while_loop:False  test_random_seed:301  test_srcdir:  test_tmpdir:/var/folders/_f/xmxvhvvx4l30w65tqszbv16n9vplqf/T/absl_testing  test_randomize_ordering_seed:  xml_output_file:
#
# ---------
# qb
# Initialize Word Dictionary & Embedding
# Processing train/review.txt...
# Processing train/yelp_review.txt...
# Processing dev/review.txt...
# Processing test/review.txt...
# Processing news/immigration/fox-news/trump/review.txt...
# Processing news/immigration/fox-news/biden/review.txt...
# max_sentence_length 116
# path ../data/qb/
# I0722 23:47:42.983051 4506928576 utils.py:129] Note: NumExpr detected 12 cores but "NUMEXPR_MAX_THREADS" not set, so enforcing safe limit of 8.
# I0722 23:47:42.983797 4506928576 utils.py:141] NumExpr defaulting to 8 threads.
# An exception occurred
# An exception occurred
# An exception occurred
# An exception occurred
#
# -------------------------------------Iter0--------------------------------------
# train loss=18.931881, dev loss=19.402497, dev acc=0.5076, step=53
# test acc=0.5093, test precision=0.1698, test recall=0.3333, test f1=0.2250
# max step:0, early stop step:0
#
# -------------------------------------Iter1--------------------------------------
# train loss=17.136962, dev loss=19.248522, dev acc=0.5076, step=106
# test acc=0.5093, test precision=0.1698, test recall=0.3333, test f1=0.2250
# max step:0, early stop step:0
#
# -------------------------------------Iter2--------------------------------------
# train loss=17.032564, dev loss=19.036216, dev acc=0.5086, step=159
# test acc=0.5110, test precision=0.1964, test recall=0.3388, test f1=0.2376
# max step:0, early stop step:0
#
# -------------------------------------Iter3--------------------------------------
# train loss=16.781011, dev loss=18.207150, dev acc=0.4502, step=212
# test acc=0.4536, test precision=0.3021, test recall=0.4747, test f1=0.3301
# max step:0, early stop step:0
#
# -------------------------------------Iter4--------------------------------------
# train loss=15.553082, dev loss=15.730206, dev acc=0.5795, step=265
# test acc=0.5831, test precision=0.6604, test recall=0.5695, test f1=0.4895
# max step:0, early stop step:0
#
# -------------------------------------Iter5--------------------------------------
# train loss=13.970937, dev loss=14.767592, dev acc=0.5282, step=318
# test acc=0.5352, test precision=0.6828, test recall=0.5325, test f1=0.3882
# max step:0, early stop step:0
#
# -------------------------------------Iter6--------------------------------------
# train loss=13.516692, dev loss=14.580472, dev acc=0.5302, step=371
# test acc=0.5400, test precision=0.6913, test recall=0.5448, test f1=0.3977
# max step:0, early stop step:0
#
# -------------------------------------Iter7--------------------------------------
# train loss=13.250261, dev loss=14.296272, dev acc=0.5555, step=424
# test acc=0.5663, test precision=0.6675, test recall=0.5470, test f1=0.4249
# max step:0, early stop step:0
#
# -------------------------------------Iter8--------------------------------------
# train loss=13.034522, dev loss=14.186853, dev acc=0.5670, step=477
# test acc=0.5774, test precision=0.6734, test recall=0.5668, test f1=0.4503
# max step:0, early stop step:0
#
# -------------------------------------Iter9--------------------------------------
# train loss=12.905029, dev loss=14.166928, dev acc=0.5737, step=530
# test acc=0.5872, test precision=0.6753, test recall=0.5731, test f1=0.4629
# max step:0, early stop step:0
#
# -------------------------------------Iter10-------------------------------------
# train loss=12.794750, dev loss=14.030078, dev acc=0.6146, step=583
# test acc=0.6347, test precision=0.6718, test recall=0.6000, test f1=0.5222
# max step:0, early stop step:0
#
# -------------------------------------Iter11-------------------------------------
# train loss=12.657330, dev loss=14.015814, dev acc=0.6058, step=636
# test acc=0.6280, test precision=0.6741, test recall=0.6032, test f1=0.5140
# max step:0, early stop step:0
#
# -------------------------------------Iter12-------------------------------------
# train loss=12.572798, dev loss=14.032229, dev acc=0.6146, step=689
# test acc=0.6358, test precision=0.6746, test recall=0.6100, test f1=0.5249
# max step:1, early stop step:1
#
# -------------------------------------Iter13-------------------------------------
# train loss=12.489728, dev loss=13.980332, dev acc=0.6527, step=742
# test acc=0.6712, test precision=0.6824, test recall=0.6408, test f1=0.5685
# max step:1, early stop step:0
#
# -------------------------------------Iter14-------------------------------------
# train loss=12.389094, dev loss=13.958660, dev acc=0.6470, step=795
# test acc=0.6661, test precision=0.6798, test recall=0.6335, test f1=0.5602
# max step:1, early stop step:0
#
# -------------------------------------Iter15-------------------------------------
# train loss=12.362870, dev loss=13.952988, dev acc=0.6389, step=848
# test acc=0.6614, test precision=0.6848, test recall=0.6388, test f1=0.5571
# max step:1, early stop step:0
#
# -------------------------------------Iter16-------------------------------------
# train loss=12.256971, dev loss=13.939942, dev acc=0.6507, step=901
# test acc=0.6786, test precision=0.6896, test recall=0.6566, test f1=0.5802
# max step:1, early stop step:0
#
# -------------------------------------Iter17-------------------------------------
# train loss=12.198656, dev loss=14.034596, dev acc=0.6618, step=954
# test acc=0.6857, test precision=0.6874, test recall=0.6537, test f1=0.5824
# max step:1, early stop step:0
#
# -------------------------------------Iter18-------------------------------------
# train loss=12.136805, dev loss=14.022344, dev acc=0.6524, step=1007
# test acc=0.6766, test precision=0.6868, test recall=0.6481, test f1=0.5709
# max step:1, early stop step:1
#
# -------------------------------------Iter19-------------------------------------
# train loss=12.079619, dev loss=13.961232, dev acc=0.6517, step=1060
# test acc=0.6806, test precision=0.6944, test recall=0.6650, test f1=0.5819
# max step:2, early stop step:2
#
# -------------------------------------Iter20-------------------------------------
# train loss=12.032533, dev loss=14.028439, dev acc=0.6652, step=1113
# test acc=0.6968, test precision=0.6932, test recall=0.6674, test f1=0.5943
# max step:2, early stop step:0
#
# -------------------------------------Iter21-------------------------------------
# train loss=11.978378, dev loss=13.989870, dev acc=0.6669, step=1166
# test acc=0.6968, test precision=0.6978, test recall=0.6777, test f1=0.5998
# max step:2, early stop step:0
#
# -------------------------------------Iter22-------------------------------------
# train loss=11.940386, dev loss=13.997495, dev acc=0.6723, step=1219
# test acc=0.7049, test precision=0.6998, test recall=0.6823, test f1=0.6071
# max step:2, early stop step:0
#
# -------------------------------------Iter23-------------------------------------
# train loss=11.894183, dev loss=13.957582, dev acc=0.6736, step=1272
# test acc=0.7079, test precision=0.7039, test recall=0.6932, test f1=0.6125
# max step:2, early stop step:0
#
# -------------------------------------Iter24-------------------------------------
# train loss=11.828693, dev loss=14.030506, dev acc=0.6841, step=1325
# test acc=0.7153, test precision=0.7014, test recall=0.6901, test f1=0.6179
# max step:2, early stop step:0
#
# -------------------------------------Iter25-------------------------------------
# train loss=11.809679, dev loss=14.018383, dev acc=0.6851, step=1378
# test acc=0.7160, test precision=0.7034, test recall=0.6957, test f1=0.6199
# max step:2, early stop step:0
#
# -------------------------------------Iter26-------------------------------------
# train loss=11.748193, dev loss=14.030554, dev acc=0.6875, step=1431
# test acc=0.7194, test precision=0.7050, test recall=0.6984, test f1=0.6233
# max step:2, early stop step:0
#
# -------------------------------------Iter27-------------------------------------
# train loss=11.717546, dev loss=14.036779, dev acc=0.6915, step=1484
# test acc=0.7224, test precision=0.7050, test recall=0.6982, test f1=0.6254
# max step:2, early stop step:0
#
# -------------------------------------Iter28-------------------------------------
# train loss=11.678908, dev loss=14.112964, dev acc=0.6936, step=1537
# test acc=0.7231, test precision=0.7053, test recall=0.6986, test f1=0.6257
# max step:2, early stop step:0
#
# -------------------------------------Iter29-------------------------------------
# train loss=11.637044, dev loss=14.159801, dev acc=0.7000, step=1590
# test acc=0.7298, test precision=0.7074, test recall=0.7023, test f1=0.6318
# max step:2, early stop step:0
#
# -------------------------------------Iter30-------------------------------------
# train loss=11.594883, dev loss=14.023088, dev acc=0.7229, step=1643
# test acc=0.7504, test precision=0.7143, test recall=0.7192, test f1=0.6550
# max step:2, early stop step:0
#
# -------------------------------------Iter31-------------------------------------
# train loss=11.598045, dev loss=13.946319, dev acc=0.7371, step=1696
# test acc=0.7680, test precision=0.7187, test recall=0.7300, test f1=0.6728
# max step:2, early stop step:0
# -------------------------------------Iter32-------------------------------------
# train loss=11.534367, dev loss=14.069396, dev acc=0.7347, step=1749
# test acc=0.7616, test precision=0.7182, test recall=0.7256, test f1=0.6653
# max step:2, early stop step:1
#
# -------------------------------------Iter33-------------------------------------
# train loss=11.512620, dev loss=13.956261, dev acc=0.7425, step=1802
# test acc=0.7771, test precision=0.7236, test recall=0.7389, test f1=0.6835
# max step:2, early stop step:0
#
# -------------------------------------Iter34-------------------------------------
# train loss=11.471966, dev loss=14.065653, dev acc=0.7516, step=1855
# test acc=0.7841, test precision=0.7225, test recall=0.7395, test f1=0.6887
# max step:2, early stop step:0
#
# --------------------------------Mission Complete--------------------------------
# max acc_index: 34
# test_acc: 0.7841,test_f1:0.6887
# min loss_index: 16
# test_acc: 0.6786,test_f1:0.5802
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-cf34dbe789c1> in <module>
#       1 if __name__ == '__main__':
# ----> 2     tf.app.run()
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/platform/app.py in run(main, argv)
#      38   main = main or _sys.modules['__main__'].main
#      39
# ---> 40   _run(main=main, argv=argv, flags_parser=_parse_flags_tolerate_undef)
#
# /opt/anaconda3/lib/python3.7/site-packages/absl/app.py in run(main, argv, flags_parser)
#     297       callback()
#     298     try:
# --> 299       _run_main(main, args)
#     300     except UsageError as error:
#     301       usage(shorthelp=True, detailed_error=error, exitcode=error.exitcode)
#
# /opt/anaconda3/lib/python3.7/site-packages/absl/app.py in _run_main(main, argv)
#     248     sys.exit(retval)
#     249   else:
# --> 250     sys.exit(main(argv))
#     251
#     252
#
# <ipython-input-3-c801d6c176f2> in main(_)
#      31     for i in range(15):
#      32         model = MODEL(FLAGS, w2v, word_dict, data_path)
# ---> 33         model.run()
#      34
#      35     end_time = time.time()
#
# ~/Documents/personalproj/copy266NLPproj/sentiment/model.py in run(self)
#     120         aspect = tf.matmul(tf.expand_dims(self.mode, 1), aspect_all)  # [b,1,300]
#     121
# --> 122         sprob = self.TransCap(inputs, aspect)
#     123
#     124         with tf.name_scope('loss'):
#
# ~/Documents/personalproj/copy266NLPproj/sentiment/model.py in TransCap(self, inputs, target)
#      80                                  iter_routing=self.iter_routing, with_routing=False, layer_type='CONV')
#      81             caps1 = SemanCap(input=x_embedding, mode=self.mode, kernel_size=self.filter_size, stride=1,
# ---> 82                              embedding_dim=self.embedding_dim+self.position_dim)
#      83
#      84         #Use learned features from CNN capsule network output and
#
# ~/Documents/personalproj/copy266NLPproj/sentiment/capsule.py in __call__(self, input, mode, kernel_size, stride, embedding_dim)
#     128                 aspect_info = tf.contrib.layers.fully_connected(self.aspect, 1, weights_initializer=
#     129                                                                 tf.contrib.layers.xavier_initializer(),
# --> 130                                                                 activation_fn=None)
#     131
#     132                 aspect_conv = tf.nn.conv2d(
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     180       current_args = current_scope[key_func].copy()
#     181       current_args.update(kwargs)
# --> 182     return func(*args, **current_args)
#     183
#     184   _add_op(func)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py in fully_connected(inputs, num_outputs, activation_fn, normalizer_fn, normalizer_params, weights_initializer, weights_regularizer, biases_initializer, biases_regularizer, reuse, variables_collections, outputs_collections, trainable, scope)
#    1864         _scope=sc,
#    1865         _reuse=reuse)
# -> 1866     outputs = layer.apply(inputs)
#    1867
#    1868     # Add variables to collections.
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py in new_func(*args, **kwargs)
#     322               'in a future version' if date is None else ('after %s' % date),
#     323               instructions)
# --> 324       return func(*args, **kwargs)
#     325     return tf_decorator.make_decorator(
#     326         func, new_func, 'deprecated',
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in apply(self, inputs, *args, **kwargs)
#    1698       Output tensor(s).
#    1699     """
# -> 1700     return self.__call__(inputs, *args, **kwargs)
#    1701
#    1702   @deprecation.deprecated(
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/base.py in __call__(self, inputs, *args, **kwargs)
#     546
#     547       # Actually call layer
# --> 548       outputs = super(Layer, self).__call__(inputs, *args, **kwargs)
#     549
#     550     if not context.executing_eagerly():
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     822           # Build layer if applicable (if the `build` method has been
#     823           # overridden).
# --> 824           self._maybe_build(inputs)
#     825           cast_inputs = self._maybe_cast_inputs(inputs)
#     826
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in _maybe_build(self, inputs)
#    2144         # operations.
#    2145         with tf_utils.maybe_init_scope(self):
# -> 2146           self.build(input_shapes)
#    2147       # We must set self.built since user defined build functions are not
#    2148       # constrained to set self.built.
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/layers/core.py in build(self, input_shape)
#    1019         constraint=self.kernel_constraint,
#    1020         dtype=self.dtype,
# -> 1021         trainable=True)
#    1022     if self.use_bias:
#    1023       self.bias = self.add_weight(
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/layers/base.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, use_resource, synchronization, aggregation, partitioner, **kwargs)
#     459             aggregation=aggregation,
#     460             getter=vs.get_variable,
# --> 461             **kwargs)
#     462
#     463         if regularizer:
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/keras/engine/base_layer.py in add_weight(self, name, shape, dtype, initializer, regularizer, trainable, constraint, partitioner, use_resource, synchronization, aggregation, **kwargs)
#     527         collections=collections_arg,
#     528         synchronization=synchronization,
# --> 529         aggregation=aggregation)
#     530     backend.track_variable(variable)
#     531
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/training/tracking/base.py in _add_variable_with_custom_getter(self, name, shape, dtype, initializer, getter, overwrite, **kwargs_for_getter)
#     710         dtype=dtype,
#     711         initializer=initializer,
# --> 712         **kwargs_for_getter)
#     713
#     714     # If we set an initializer and the variable processed it, tracking will not
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in get_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1498       constraint=constraint,
#    1499       synchronization=synchronization,
# -> 1500       aggregation=aggregation)
#    1501
#    1502
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in get_variable(self, var_store, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#    1241           constraint=constraint,
#    1242           synchronization=synchronization,
# -> 1243           aggregation=aggregation)
#    1244
#    1245   def _get_partitioned_variable(self,
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in get_variable(self, name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, custom_getter, constraint, synchronization, aggregation)
#     548           function_utils.has_kwargs(custom_getter)):
#     549         custom_getter_kwargs["constraint"] = constraint
# --> 550       return custom_getter(**custom_getter_kwargs)
#     551     else:
#     552       return _true_getter(
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py in layer_variable_getter(getter, *args, **kwargs)
#    1759   def layer_variable_getter(getter, *args, **kwargs):
#    1760     kwargs['rename'] = rename
# -> 1761     return _model_variable_getter(getter, *args, **kwargs)
#    1762
#    1763   return layer_variable_getter
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/layers/python/layers/layers.py in _model_variable_getter(getter, name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, partitioner, rename, use_resource, synchronization, aggregation, **_)
#    1750       use_resource=use_resource,
#    1751       synchronization=synchronization,
# -> 1752       aggregation=aggregation)
#    1753
#    1754
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     180       current_args = current_scope[key_func].copy()
#     181       current_args.update(kwargs)
# --> 182     return func(*args, **current_args)
#     183
#     184   _add_op(func)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/framework/python/ops/variables.py in model_variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, device, partitioner, custom_getter, use_resource, synchronization, aggregation)
#     349       use_resource=use_resource,
#     350       synchronization=synchronization,
# --> 351       aggregation=aggregation)
#     352   return var
#     353
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/framework/python/ops/arg_scope.py in func_with_args(*args, **kwargs)
#     180       current_args = current_scope[key_func].copy()
#     181       current_args.update(kwargs)
# --> 182     return func(*args, **current_args)
#     183
#     184   _add_op(func)
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/contrib/framework/python/ops/variables.py in variable(name, shape, dtype, initializer, regularizer, trainable, collections, caching_device, device, partitioner, custom_getter, use_resource, synchronization, aggregation)
#     279         use_resource=use_resource,
#     280         synchronization=synchronization,
# --> 281         aggregation=aggregation)
#     282
#     283
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in _true_getter(name, shape, dtype, initializer, regularizer, reuse, trainable, collections, caching_device, partitioner, validate_shape, use_resource, constraint, synchronization, aggregation)
#     517           constraint=constraint,
#     518           synchronization=synchronization,
# --> 519           aggregation=aggregation)
#     520
#     521     synchronization, aggregation, trainable = (
#
# /opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/ops/variable_scope.py in _get_single_variable(self, name, shape, dtype, initializer, regularizer, partition_info, reuse, trainable, collections, caching_device, validate_shape, use_resource, constraint, synchronization, aggregation)
#     866         tb = [x for x in tb if "tensorflow/python" not in x[0]][:5]
#     867         raise ValueError("%s Originally defined at:\n\n%s" %
# --> 868                          (err_msg, "".join(traceback.format_list(tb))))
#     869       found_var = self._vars[name]
#     870       if not shape.is_compatible_with(found_var.get_shape()):
#
# ValueError: Variable FeatCap_SemanCap/fully_connected/weights already exists, disallowed. Did you mean to set reuse=True or reuse=tf.AUTO_REUSE in VarScope? Originally defined at:
#
#   File "/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 1748, in __init__
#     self._traceback = tf_stack.extract_stack()
#   File "/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3426, in _create_op_internal
#     op_def=op_def)
#   File "/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/ops.py", line 3357, in create_op
#     attrs, op_def, compute_device)
#   File "/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/util/deprecation.py", line 507, in new_func
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/lib/python3.7/site-packages/tensorflow_core/python/framework/op_def_library.py", line 794, in _apply_op_helper
#     op_def=op_def)
