# %% [markdown]
# ### Creating Bar Charts for Bokeh Visualization
# Historical Trend Comparison for Significant Variables

# %%
# imports
import geopandas as gpd
import pandas as pd
import numpy as np
import json
from bokeh.io import output_notebook
from bokeh.models import (CDSView, ColorBar, ColumnDataSource,
                          CustomJS, CustomJSFilter, 
                          GeoJSONDataSource, HoverTool,
                          LinearColorMapper, Slider, LabelSet)
from bokeh.layouts import column, row, widgetbox
from bokeh.palettes import brewer, Spectral5
from bokeh.plotting import figure, show

# %%
# set pandas to display all columns in dataframe
pd.set_option("display.max_columns", None)

# %%
# read in data
data = "https://raw.githubusercontent.com/ehuang13/w210-presidential-election/master/data/Data-Jul07/combined_jul05.csv"
df = pd.read_csv(data, encoding = "ISO-8859-1")

# %%
# checkout data
df.sample(5)
# Out:
#        YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS        STATE          COUNTY  \
# 14414  200839013  2008          39           13         Ohio  Belmont County
# 1767   201228089  2012          28           89  Mississippi  Madison County
# 5379   201641047  2016          41           47       Oregon   Marion County
# 5681   201648021  2016          48           21        Texas  Bastrop County
# 11812  200448111  2004          48          111        Texas   Dallam County
#
#         REP_CANDIDATE    DEM_CANDIDATE  REP_VOTES  DEM_VOTES  \
# 14414     John McCain     Barack Obama      15422      16302
# 1767      Mitt Romney     Barack Obama      28507      20722
# 5379     Donald Trump  Hillary Clinton      63377      57788
# 5681     Donald Trump  Hillary Clinton      16328      10569
# 11812  George W. Bush       John Kerry       1473        305
#
#        COUNTY_TOTALVOTES WINNING_CANDIDATE WINNING_PARTY  \
# 14414            32411.0      Barack Obama      democrat
# 1767             49571.0       Mitt Romney    republican
# 5379            136840.0      Donald Trump    republican
# 5681             28454.0      Donald Trump    republican
# 11812             1782.0    George W. Bush    republican
#
#        WINNING_PARTY_BINARY  HOUSE_WINNING_BINARY  SENATE_WINNING_BINARY  \
# 14414                     0                     0                      0
# 1767                      1                     1                     -1
# 5379                      1                     0                      0
# 5681                      1                     1                      1
# 11812                     1                     1                      1
#
#        UNEMPLOYMENT_RATE  AVG_WAGE_SALARY  AA_FEMALE  AA_MALE  BA_FEMALE  \
# 14414                6.1            30784        136      121        627
# 1767                 6.2                0       1070     1062      19759
# 5379                 5.1                0       4008     3311       1826
# 5681                 3.7            36689        379      340       2940
# 11812                3.8            29666         13       10         49
#
#        BA_MALE  H_FEMALE  H_MALE  IA_FEMALE  IA_MALE  NA_FEMALE  NA_MALE  \
# 14414     2290       157     245         42       42          1        7
# 1767     16970      1254    1548        179      230         41       55
# 5379      2794     39836   43419       3995     4257       1551     1428
# 5681      3249     12954   14254        654      735         51       60
# 11812       58       947    1009         40       38          0        0
#
#        TOT_FEMALE  TOT_MALE  TOT_POP  WA_FEMALE  WA_MALE  TOT_POP_LESS19  \
# 14414       35051     35379    70430      33856    32584           15824
# 1767        49784     45754    95538      28377    27140           28177
# 5379       162946    161632   324578     146317   144669           91766
# 5681        38226     39768    77994      33393    34588           21856
# 11812        2992      3156     6148       2863     3017            2043
#
#        TOT_MALE_LESS19  TOT_FEMALE_LESS19  TOT_POP_20to39  TOT_MALE_20to39  \
# 14414             8228               7596           16847             9495
# 1767             14409              13768           24939            11720
# 5379             47085              44681           87140            44754
# 5681             11213              10643           18277             9667
# 11812             1071                972            1724              911
#
#        TOT_FEMALE_20to39  TOT_POP_40to59  TOT_MALE_40to59  TOT_FEMALE_40to59  \
# 14414               7352           21315            10693              10622
# 1767               13219           27486            13071              14415
# 5379               42386           80326            40294              40032
# 5681                8610           22096            11304              10792
# 11812                813            1517              787                730
#
#        TOT_POP_Above60  TOT_MALE_Above60  TOT_FEMALE_Above60  AA_FEMALE%  \
# 14414            16444              6963                9481    0.001931
# 1767             14936              6554                8382    0.011200
# 5379             65346             29499               35847    0.012348
# 5681             15765              7584                8181    0.004859
# 11812              864               387                 477    0.002115
#
#        AA_MALE%  BA_FEMALE%  BA_MALE%  H_FEMALE%   H_MALE%  IA_FEMALE%  \
# 14414  0.001718    0.008902  0.032515   0.002229  0.003479    0.000596
# 1767   0.011116    0.206818  0.177626   0.013126  0.016203    0.001874
# 5379   0.010201    0.005626  0.008608   0.122732  0.133771    0.012308
# 5681   0.004359    0.037695  0.041657   0.166090  0.182758    0.008385
# 11812  0.001627    0.007970  0.009434   0.154034  0.164118    0.006506
#
#        IA_MALE%  NA_FEMALE%  NA_MALE%  WA_FEMALE%  WA_MALE%  TOT_FEMALE%  \
# 14414  0.000596    0.000014  0.000099    0.480704  0.462644     0.497671
# 1767   0.002407    0.000429  0.000576    0.297023  0.284075     0.521091
# 5379   0.013115    0.004779  0.004400    0.450791  0.445714     0.502024
# 5681   0.009424    0.000654  0.000769    0.428148  0.443470     0.490115
# 11812  0.006181    0.000000  0.000000    0.465680  0.490729     0.486662
#
#        TOT_MALE%  TOT_POP_LESS19%  TOT_POP_20to39%  TOT_POP_40to59%  \
# 14414   0.502329         0.224677         0.239202         0.302641
# 1767    0.478909         0.294930         0.261037         0.287697
# 5379    0.497976         0.282724         0.268472         0.247478
# 5681    0.509885         0.280227         0.234339         0.283304
# 11812   0.513338         0.332303         0.280416         0.246747
#
#        TOT_POP_Above60%  MARGIN_VICTORY
# 14414          0.233480        0.027151
# 1767           0.156336       -0.157047
# 5379           0.201326       -0.040843
# 5681           0.202131       -0.202397
# 11812          0.140534       -0.655443

# %% [markdown]
# ### Create Static Bar Chart
# * x-axis: any feature selected, such as unemployment rate
# * y-axis: all the election years
#
# **Steps Required:**
# * aggregate the selected feature by year
# * plot bar chart
#
# **Reference Sources:**
# * https://docs.bokeh.org/en/latest/docs/user_guide/categorical.html
# * https://towardsdatascience.com/interactive-bar-charts-with-bokeh-7230e5653ba3

# %%
# set visualization to display inline within jupyter notebook
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2479">Loading BokehJS ...</span>
#     </div>

# %%
# pick any random selected feature
feature = "UNEMPLOYMENT_RATE"

# aggregate selected feature by year
grouped_feature = df[["YEAR", feature]].groupby(df["YEAR"]).mean()

# %%
# checkout grouped feature dataframe
grouped_feature
# Out:
#       YEAR  UNEMPLOYMENT_RATE
# YEAR
# 2000  2000           4.381991
# 2004  2004           5.694162
# 2008  2008           5.828448
# 2012  2012           7.855599
# 2016  2016           5.243806

# %%
# bokeh visualization
years = list(grouped_feature["YEAR"])
plot_feature = list(grouped_feature[feature])

# initialize the plot
p = figure(plot_height=400, 
           title="Average Unemployment Rate by Year")

# plot bar chart
p.vbar(years, top = plot_feature, width=3, fill_color = Spectral5)

# label axis and ticks
p.xaxis.axis_label="Years"
p.yaxis.axis_label="Average Unemployment Rate"
p.xaxis.ticker = years

# display plot
show(p)
# Out:
#   <div class="bk-root" id="a5c6b172-f2d1-4f3c-81a3-4ed7361e6d34" data-root-id="8356"></div>

# %% [markdown]
# ### Package Bar Chart Plot into a Function

# %%
def bar_plot(feature = "UNEMPLOYMENT_RATE"):
    
    # set default feature is unemployment rate

    # aggregate selected feature by year
    grouped_feature = df[["YEAR", feature]].groupby(df["YEAR"]).mean()
    
    # bokeh visualization
    years = [2000, 2004, 2008, 2012, 2016]
    plot_feature = list(grouped_feature[feature])

    # initialize the plot
    p = figure(plot_height=400, 
               title="Selected Feature Summary Statistics by Year")

    # plot bar chart
    p.vbar(years, top = plot_feature, width=3, fill_color = Spectral5)

    # label axis and ticks
    p.xaxis.axis_label="Years"
    p.yaxis.axis_label="Average Selected Feature"
    p.xaxis.ticker = years

    return show(p)

# %% [markdown]
# Test plotting other selected features

# %%
# see all available features for selection
df.columns[16:]
# Out:
# Index(['UNEMPLOYMENT_RATE', 'AVG_WAGE_SALARY', 'AA_FEMALE', 'AA_MALE',
#        'BA_FEMALE', 'BA_MALE', 'H_FEMALE', 'H_MALE', 'IA_FEMALE', 'IA_MALE',
#        'NA_FEMALE', 'NA_MALE', 'TOT_FEMALE', 'TOT_MALE', 'TOT_POP',
#        'WA_FEMALE', 'WA_MALE', 'TOT_POP_LESS19', 'TOT_MALE_LESS19',
#        'TOT_FEMALE_LESS19', 'TOT_POP_20to39', 'TOT_MALE_20to39',
#        'TOT_FEMALE_20to39', 'TOT_POP_40to59', 'TOT_MALE_40to59',
#        'TOT_FEMALE_40to59', 'TOT_POP_Above60', 'TOT_MALE_Above60',
#        'TOT_FEMALE_Above60', 'AA_FEMALE%', 'AA_MALE%', 'BA_FEMALE%',
#        'BA_MALE%', 'H_FEMALE%', 'H_MALE%', 'IA_FEMALE%', 'IA_MALE%',
#        'NA_FEMALE%', 'NA_MALE%', 'WA_FEMALE%', 'WA_MALE%', 'TOT_FEMALE%',
#        'TOT_MALE%', 'TOT_POP_LESS19%', 'TOT_POP_20to39%', 'TOT_POP_40to59%',
#        'TOT_POP_Above60%', 'MARGIN_VICTORY'],
#       dtype='object')

# %%
test1 = bar_plot("MARGIN_VICTORY")
# Out:
#   <div class="bk-root" id="5517e5e1-cd44-45bb-862a-3adc26d21daf" data-root-id="11713"></div>

# %%
# aggregate selected feature by year
test1_grouped = df[["YEAR", "MARGIN_VICTORY"]].groupby(df["YEAR"]).mean()
test1_grouped
# Out:
#       YEAR  MARGIN_VICTORY
# YEAR
# 2000  2000       -0.171779
# 2004  2004       -0.215300
# 2008  2008       -0.152396
# 2012  2012       -0.208777
# 2016  2016       -0.314008

# %%
test2 = bar_plot("TOT_POP_LESS19%")
# Out:
#   <div class="bk-root" id="efba4fcb-a7d2-4b8b-8f6d-14454482bfc9" data-root-id="10531"></div>

# %%
# aggregate selected feature by year
test2_grouped = df[["YEAR", "TOT_POP_LESS19%"]].groupby(df["YEAR"]).mean()
test2_grouped
# Out:
#       YEAR  TOT_POP_LESS19%
# YEAR
# 2000  2000         0.284323
# 2004  2004         0.275984
# 2008  2008         0.267129
# 2012  2012         0.261081
# 2016  2016         0.251323
