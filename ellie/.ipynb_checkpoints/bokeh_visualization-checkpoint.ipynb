# %% [markdown]
# # Helpful Resources
# * Example Tutorial: https://towardsdatascience.com/walkthrough-mapping-basics-with-bokeh-and-geopandas-in-python-43f40aa5b7e9
# * Bokeh Visualization Documentation: https://docs.bokeh.org/en/latest/docs/user_guide/geo.html
# * Bokeh Documentation for Jupyter: https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html
# * Bokeh Palettes Documentation: https://docs.bokeh.org/en/latest/docs/reference/palettes.html

# %%
# imports
import geopandas as gpd
import pandas as pd
import json
from bokeh.io import show
from bokeh.models import (CDSView, ColorBar, ColumnDataSource,
                          CustomJS, CustomJSFilter, 
                          GeoJSONDataSource, HoverTool,
                          LinearColorMapper, Slider)
from bokeh.layouts import column, row, widgetbox
from bokeh.palettes import brewer
from bokeh.plotting import figure

# %%
# read in combined dataset
combined_df = pd.read_csv("https://raw.githubusercontent.com/ehuang13/w210-presidential-election/master/data/combined_jun13.csv")

# %%
combined_df.head()

# %% [markdown]
# # Plotting States With Bokeh

# %%
# read in states shapefile from US Census Bureau
states_usa = gpd.read_file("bokeh/cb_2018_us_state_20m.shp")
print("States shapefile dimension: {}".format(states_usa.shape))
states_usa.head()

# %%
# try to visualizae Maryland
states_usa.iloc[0]["geometry"]

# %%
# merge combined dataset with state shapefile
merged_states = states_usa.merge(combined_df, left_on="NAME", right_on="STATE")
print("Merged States Dataframe Dimensions: {}".format(merged_states.shape))
merged_states.head()

# %%
# drop Alaska and Hawaii
merged_states = merged_states.loc[~merged_states["NAME"].isin(["Alaska", "Hawaii"])]

# %%
# input GeoJSON source that contains features for plotting
geosource_states = GeoJSONDataSource(geojson = merged_states.to_json())

# %%
# plot states map

# create figure object.
plot = figure(title = 'Test Bokeh Map', 
           plot_height = 600 ,
           plot_width = 950, 
           toolbar_location = 'below',
           tools = "pan, wheel_zoom, box_zoom, reset")
plot.xgrid.grid_line_color = None
plot.ygrid.grid_line_color = None

# add patch renderer to figure.
states = plot.patches('xs','ys', source = geosource_states,
                   fill_color = None,
                   line_color = "gray", 
                   line_width = 0.25, 
                   fill_alpha = 1)
# create hover tool
plot.add_tools(HoverTool(renderers = [states],
                      tooltips = [('State','@NAME'),
                                ('Votes','@COUNTY_TOTALVOTES')]))

# generates a map on separate tab in browser
show(plot)

# %% [markdown]
# # Plotting Counties With Bokeh

# %%
# read in counties shapefile from US Census Bureau
counties_usa = gpd.read_file("bokeh/cb_2018_us_county_20m.shp")
counties_usa.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID      NAME LSAD  \
# 0      37      017  01026336  0500000US37017  37017    Bladen   06
# 1      37      167  01025844  0500000US37167  37167    Stanly   06
# 2      39      153  01074088  0500000US39153  39153    Summit   06
# 3      42      113  01213687  0500000US42113  42113  Sullivan   06
# 4      48      459  01384015  0500000US48459  48459    Upshur   06
#
#         ALAND    AWATER                                           geometry
# 0  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 1  1023370459  25242751  POLYGON ((-80.49737499999999 35.202104, -80.29...
# 2  1069181981  18958267  POLYGON ((-81.68698999999999 41.135956, -81.68...
# 3  1165338428   6617028  POLYGON ((-76.81373099999999 41.590034, -76.22...
# 4  1509910100  24878888  POLYGON ((-95.15273999999999 32.660949, -95.15...

# %%
# cast GEOID data type to float64 instead of str for merging
counties_usa["GEOID"] = counties_usa["GEOID"].astype("float64")

# %%
# set pandas to display all columns in dataframe
pd.set_option("display.max_columns", None)

# %%
# merge counties shapefile with combined_df
merged_counties = counties_usa.merge(combined_df, left_on="GEOID", right_on="FIPS")
print("Merged Counties Dataframe Dimensions: {}".format(merged_counties.shape))
merged_counties.head()
# Out:
# Merged Counties Dataframe Dimensions: (15437, 76)
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID    GEOID    NAME LSAD  \
# 0      37      017  01026336  0500000US37017  37017.0  Bladen   06
# 1      37      017  01026336  0500000US37017  37017.0  Bladen   06
# 2      37      017  01026336  0500000US37017  37017.0  Bladen   06
# 3      37      017  01026336  0500000US37017  37017.0  Bladen   06
# 4      37      017  01026336  0500000US37017  37017.0  Bladen   06
#
#         ALAND    AWATER                                           geometry  \
# 0  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 1  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 2  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 3  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 4  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
#
#    Unnamed: 0     ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS  \
# 0        2161   2530  201237017  2012          37           17
# 1        4985   5356  201637017  2016          37           17
# 2        7835  11104  200037017  2000          37           17
# 3       10904  14247  200437017  2004          37           17
# 4       13974  17390  200837017  2008          37           17
#
#             STATE         COUNTY     FIPS   REP_CANDIDATE    DEM_CANDIDATE  \
# 0  North Carolina  Bladen County  37017.0     Mitt Romney     Barack Obama
# 1  North Carolina  Bladen County  37017.0    Donald Trump  Hillary Clinton
# 2  North Carolina  Bladen County  37017.0  George W. Bush          Al Gore
# 3  North Carolina  Bladen County  37017.0  George W. Bush       John Kerry
# 4  North Carolina  Bladen County  37017.0     John McCain     Barack Obama
#
#    REP_VOTES  DEM_VOTES  COUNTY_TOTALVOTES WINNING_CANDIDATE WINNING_PARTY  \
# 0     7748.0     8062.0            15957.0      Barack Obama      democrat
# 1     8550.0     7058.0            15897.0      Donald Trump    republican
# 2     4977.0     5889.0            10908.0           Al Gore      democrat
# 3     6174.0     6109.0            12313.0    George W. Bush    republican
# 4     7532.0     7853.0            15480.0      Barack Obama      democrat
#
#    WINNING_PARTY_BINARY  HOUSE_WINNING_BINARY  SENATE_WINNING_BINARY  \
# 0                     0                   0.0                    NaN
# 1                     1                   0.0                    1.0
# 2                     0                   0.0                    NaN
# 3                     1                   0.0                    1.0
# 4                     0                   0.0                    0.0
#
#    UNEMPLOYMENT_RATE  AVG_WAGE_SALARY  AA_FEMALE  AA_MALE  BA_FEMALE  BA_MALE  \
# 0               12.7          32450.0         42       35       6703     5699
# 1                6.9          35168.0         56       53       6511     5480
# 2                6.0          22852.0         20       18       6623     5659
# 3                7.1          24844.0         24       19       6653     5644
# 4                7.7          28876.0         36       31       6760     5620
#
#    H_FEMALE  H_MALE  IA_FEMALE  IA_MALE  NA_FEMALE  NA_MALE  TOT_FEMALE  \
# 0      1123    1402        445      451        3.0        5       18294
# 1      1085    1383        493      468        6.0        6       17925
# 2       430     764        356      316        9.0        8       16749
# 3       719     922        403      381        9.0        6       17248
# 4       870    1181        415      398        3.0        6       17900
#
#    TOT_MALE  TOT_POP  WA_FEMALE  WA_MALE  TOT_POP_LESS19  TOT_MALE_LESS19  \
# 0     16898    35192      10831    10502            8938             4544
# 1     16461    34386      10572    10205            8163             4173
# 2     15503    32252       9643     9425            8777             4524
# 3     15881    33129      10009     9724            9193             4702
# 4     16385    34285      10472    10154            9197             4676
#
#    TOT_FEMALE_LESS19  TOT_POP_20to39  TOT_MALE_20to39  TOT_FEMALE_20to39  \
# 0               4394            8078             3964               4114
# 1               3990            7587             3715               3872
# 2               4253            8312             4119               4193
# 3               4491            8248             4010               4238
# 4               4521            7945             3825               4120
#
#    TOT_POP_40to59  TOT_MALE_40to59  TOT_FEMALE_40to59  TOT_POP_Above60  \
# 0           10209             4904               5305             7967
# 1            9502             4490               5012             9134
# 2            9014             4349               4665             6149
# 3            9363             4552               4811             6325
# 4            9999             4796               5203             7144
#
#    TOT_MALE_Above60  TOT_FEMALE_Above60  AA_FEMALE%  AA_MALE%  BA_FEMALE%  \
# 0              3486                4481    0.001193  0.000995    0.190469
# 1              4083                5051    0.001629  0.001541    0.189350
# 2              2511                3638    0.000620  0.000558    0.205352
# 3              2617                3708    0.000724  0.000574    0.200821
# 4              3088                4056    0.001050  0.000904    0.197171
#
#    BA_MALE%  H_FEMALE%   H_MALE%  IA_FEMALE%  IA_MALE%  NA_FEMALE%  NA_MALE%  \
# 0  0.161940   0.031911  0.039839    0.012645  0.012815    0.000085  0.000142
# 1  0.159367   0.031554  0.040220    0.014337  0.013610    0.000174  0.000174
# 2  0.175462   0.013333  0.023688    0.011038  0.009798    0.000279  0.000248
# 3  0.170364   0.021703  0.027831    0.012165  0.011500    0.000272  0.000181
# 4  0.163920   0.025376  0.034447    0.012104  0.011609    0.000088  0.000175
#
#    WA_FEMALE%  WA_MALE%  TOT_FEMALE%  TOT_MALE%  TOT_POP_LESS19%  \
# 0    0.307769  0.298420     0.519834   0.480166         0.253978
# 1    0.307451  0.296778     0.521288   0.478712         0.237393
# 2    0.298989  0.292230     0.519317   0.480683         0.272138
# 3    0.302122  0.293519     0.520631   0.479369         0.277491
# 4    0.305440  0.296165     0.522094   0.477906         0.268251
#
#    TOT_POP_20to39%  TOT_POP_40to59%  TOT_POP_Above60%
# 0         0.229541         0.290094          0.226387
# 1         0.220642         0.276333          0.265631
# 2         0.257720         0.279487          0.190655
# 3         0.248966         0.282622          0.190920
# 4         0.231734         0.291644          0.208371

# %%
# try to visualize Bladen county
merged_counties.iloc[0]["geometry"]

# %%
# drop Alaska and Hawaii
merged_counties = merged_counties.loc[~merged_counties["STATE"].isin(["Alaska", "Hawaii"])]

# %%
# input GeoJSON source that contains features for plotting
geosource_counties = GeoJSONDataSource(geojson = merged_counties.to_json())

# %%
# plot county map

# create figure object.
plot = figure(title = 'Test Bokeh Map', 
           plot_height = 600 ,
           plot_width = 950, 
           toolbar_location = 'below',
           tools = "pan, wheel_zoom, reset")
plot.xgrid.grid_line_color = None
plot.ygrid.grid_line_color = None

# add patch renderer to figure.
states = plot.patches('xs','ys', source = geosource_counties,
                   fill_color = None,
                   line_color = "gray", 
                   line_width = 0.25, 
                   fill_alpha = 1)
# create hover tool
plot.add_tools(HoverTool(renderers = [states],
                      tooltips = [('County','@NAME'),
                                ('Votes','@COUNTY_TOTALVOTES')]))

# generates a map on separate tab in browser
show(plot)

# %% [markdown]
# # Plot Counties and County Votes With Color Slider Bar for Election Year 2000

# %%
# create 2000 election year data frame
yr2000 = merged_counties["YEAR"] == 2000
merged_2000 = merged_counties[yr2000]

# input GeoJSON source that contains features for plotting
geosource_2000 = GeoJSONDataSource(geojson = merged_2000.to_json())

# %%
# define color palettes
palette = brewer["GnBu"][8]

# use reverse order so higher values are darker
palette = palette[::-1]

# %%
# find min and max of total # of votes cast by counties
print("Min & Max of Total Votes: {} - {}".format(
    merged_df["COUNTY_TOTALVOTES"].min(),
    merged_df["COUNTY_TOTALVOTES"].max()))
# Out:
# Min & Max of Total Votes: 64.0 - 3434308.0

# %%
# instantiate LineraColorMapper that maps number of votes in a range
# into a sequence of colors
color_mapper = LinearColorMapper(palette = palette, low = 64, high = 3434308)

# %%
# create color slider bar at the bottom of chart
color_bar = ColorBar(color_mapper = color_mapper, 
                     label_standoff = 8,
                     width = 500, height = 20,
                     border_line_color = None,
                     location = (0,0), 
                     orientation = "horizontal")

# %%
# create figure object.
plot = figure(title = "Total # of Votes Cast by County in 2000 Presidential Election", 
           plot_height = 600, plot_width = 950, 
           toolbar_location = "below",
           tools = "pan, wheel_zoom, reset")

plot.xgrid.grid_line_color = None
plot.ygrid.grid_line_color = None

# add patch renderer to figure
counties = plot.patches("xs","ys", source = geosource_2000,
                   fill_color = {"field": "COUNTY_TOTALVOTES",
                                 "transform": color_mapper},
                   line_color = "gray", 
                   line_width = 0.25, 
                   fill_alpha = 1)
# create hover tool
plot.add_tools(HoverTool(renderers = [states],
                      tooltips = [("County","@NAME"),
                               ("Votes", "@COUNTY_TOTALVOTES")]))
# specify colorbar layout
# p.add_layout(color_bar, ‘below’)
show(plot)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-149-b56c516ae681> in <module>
#      21 # specify colorbar layout
#      22 # p.add_layout(color_bar, ‘below’)
# ---> 23 show(plot)
#
# ~\Anaconda3\lib\site-packages\bokeh\io\showing.py in show(obj, browser, new, notebook_handle, notebook_url, **kw)
#     137         return run_notebook_hook(state.notebook_type, 'app', obj, state, notebook_url, **kw)
#     138
# --> 139     return _show_with_state(obj, state, browser, new, notebook_handle=notebook_handle)
#     140
#     141 #-----------------------------------------------------------------------------
#
# ~\Anaconda3\lib\site-packages\bokeh\io\showing.py in _show_with_state(obj, state, browser, new, notebook_handle)
#     175
#     176     if state.file or not shown:
# --> 177         _show_file_with_state(obj, state, new, controller)
#     178
#     179     return comms_handle
#
# ~\Anaconda3\lib\site-packages\bokeh\io\showing.py in _show_file_with_state(obj, state, new, controller)
#     158
#     159     '''
# --> 160     filename = save(obj, state=state)
#     161     controller.open("file://" + filename, new=NEW_PARAM[new])
#     162
#
# ~\Anaconda3\lib\site-packages\bokeh\io\saving.py in save(obj, filename, resources, title, template, state, **kwargs)
#      85
#      86     filename, resources, title = _get_save_args(state, filename, resources, title)
# ---> 87     _save_helper(obj, filename, resources, title, template, theme)
#      88     return abspath(filename)
#      89
#
# ~\Anaconda3\lib\site-packages\bokeh\io\saving.py in _save_helper(obj, filename, resources, title, template, theme)
#     147     '''
#     148     from ..embed import file_html
# --> 149     html = file_html(obj, resources, title=title, template=template, theme=theme)
#     150
#     151     with io.open(filename, mode="w", encoding="utf-8") as f:
#
# ~\Anaconda3\lib\site-packages\bokeh\embed\standalone.py in file_html(models, resources, title, template, template_variables, theme, suppress_callback_warning, _always_new)
#     301         models_seq = models
#     302
# --> 303     with OutputDocumentFor(models_seq, apply_theme=theme, always_new=_always_new) as doc:
#     304         (docs_json, render_items) = standalone_docs_json_and_render_items(models_seq, suppress_callback_warning=suppress_callback_warning)
#     305         title = _title_from_models(models_seq, title)
#
# ~\Anaconda3\lib\contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# ~\Anaconda3\lib\site-packages\bokeh\embed\util.py in OutputDocumentFor(objs, apply_theme, always_new)
#     132             doc = Document()
#     133             for model in objs:
# --> 134                 doc.add_root(model)
#     135
#     136         # handle a single shared document
#
# ~\Anaconda3\lib\site-packages\bokeh\document\document.py in add_root(self, model, setter)
#     317             self._roots.append(model)
#     318         finally:
# --> 319             self._pop_all_models_freeze()
#     320         self._trigger_on_change(RootAddedEvent(self, model, setter))
#     321
#
# ~\Anaconda3\lib\site-packages\bokeh\document\document.py in _pop_all_models_freeze(self)
#    1054         self._all_models_freeze_count -= 1
#    1055         if self._all_models_freeze_count == 0:
# -> 1056             self._recompute_all_models()
#    1057
#    1058     def _recompute_all_models(self):
#
# ~\Anaconda3\lib\site-packages\bokeh\document\document.py in _recompute_all_models(self)
#    1077             d._detach_document()
#    1078         for a in to_attach:
# -> 1079             a._attach_document(self)
#    1080         self._all_models = recomputed
#    1081         self._all_models_by_name = recomputed_by_name
#
# ~\Anaconda3\lib\site-packages\bokeh\model.py in _attach_document(self, doc)
#     669         '''
#     670         if self._document is not None and self._document is not doc:
# --> 671             raise RuntimeError("Models must be owned by only a single document, %r is already in a doc" % (self))
#     672         doc.theme.apply_to_model(self)
#     673         self._document = doc
#
# RuntimeError: Models must be owned by only a single document, GeoJSONDataSource(id='1567', ...) is already in a doc
