# %% [markdown]
# # Helpful Resources
# * https://towardsdatascience.com/walkthrough-mapping-basics-with-bokeh-and-geopandas-in-python-43f40aa5b7e9
# * https://docs.bokeh.org/en/latest/docs/user_guide/geo.html
# * https://docs.bokeh.org/en/latest/docs/user_guide/jupyter.html

# %%
# imports
import geopandas as gpd
import pandas as pd
import json
from bokeh.io import show
from bokeh.models import (CDSView, ColorBar, ColumnDataSource,
                          CustomJS, CustomJSFilter, 
                          GeoJSONDataSource, HoverTool,
                          LinearColorMapper, Slider)
from bokeh.layouts import column, row, widgetbox
from bokeh.palettes import brewer
from bokeh.plotting import figure

# %% [markdown]
# # Plotting States With Bokeh

# %%
# read in states shapefile from US Census Bureau
states_usa = gpd.read_file("bokeh/cb_2018_us_state_20m.shp")
states_usa.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS          NAME LSAD  \
# 0      24  01714934  0400000US24    24     MD      Maryland   00
# 1      19  01779785  0400000US19    19     IA          Iowa   00
# 2      10  01779781  0400000US10    10     DE      Delaware   00
# 3      39  01085497  0400000US39    39     OH          Ohio   00
# 4      42  01779798  0400000US42    42     PA  Pennsylvania   00
#
#           ALAND       AWATER  \
# 0   25151100280   6979966958
# 1  144661267977   1084180812
# 2    5045925646   1399985648
# 3  105828882568  10268850702
# 4  115884442321   3394589990
#
#                                             geometry
# 0  (POLYGON ((-76.04621299999999 38.025533, -76.0...
# 1  POLYGON ((-96.62187499999999 42.779255, -96.57...
# 2  POLYGON ((-75.773786 39.7222, -75.753227999999...
# 3  (POLYGON ((-82.863342 41.693693, -82.825719999...
# 4  POLYGON ((-80.519891 40.906661, -80.5196437725...

# %%
states_usa.shape
# Out:
# (52, 10)

# %%
# try to visualizae Maryland
states_usa.iloc[0]["geometry"]

# %%
# read in combined dataset
combined_df = pd.read_csv("https://raw.githubusercontent.com/ehuang13/w210-presidential-election/master/data/combined_jun13.csv")

# %%
combined_df.head()
# Out:
#    Unnamed: 0  ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS    STATE  \
# 0           0   0   20121001  2012           1            1  Alabama
# 1           1   1   20121003  2012           1            3  Alabama
# 2           2   2   20121005  2012           1            5  Alabama
# 3           3   3   20121007  2012           1            7  Alabama
# 4           4   4   20121009  2012           1            9  Alabama
#
#            COUNTY    FIPS REP_CANDIDATE DEM_CANDIDATE  REP_VOTES  DEM_VOTES  \
# 0  Autauga County  1001.0   Mitt Romney  Barack Obama    17379.0     6363.0
# 1  Baldwin County  1003.0   Mitt Romney  Barack Obama    66016.0    18424.0
# 2  Barbour County  1005.0   Mitt Romney  Barack Obama     5550.0     5912.0
# 3     Bibb County  1007.0   Mitt Romney  Barack Obama     6132.0     2202.0
# 4   Blount County  1009.0   Mitt Romney  Barack Obama    20757.0     2970.0
#
#    COUNTY_TOTALVOTES WINNING_CANDIDATE WINNING_PARTY  WINNING_PARTY_BINARY  \
# ...

# %%
# merge combined dataset with state shapefile
merged_df = states_usa.merge(combined_df, left_on="NAME", right_on="STATE")
merged_df.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID STUSPS      NAME LSAD        ALAND  \
# 0      24  01714934  0400000US24    24     MD  Maryland   00  25151100280
# 1      24  01714934  0400000US24    24     MD  Maryland   00  25151100280
# 2      24  01714934  0400000US24    24     MD  Maryland   00  25151100280
# 3      24  01714934  0400000US24    24     MD  Maryland   00  25151100280
# 4      24  01714934  0400000US24    24     MD  Maryland   00  25151100280
#
#        AWATER                                           geometry  Unnamed: 0  \
# 0  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1456
# 1  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1457
# 2  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1458
# 3  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1459
# 4  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1460
#
# ...

# %%
# drop Alaska and Hawaii
merged_df = merged_df.loc[~merged_df["NAME"].isin(["Alaska", "Hawaii"])]

# %% [markdown]
# # Plotting Counties With Bokeh

# %%
# read in counties shapefile from US Census Bureau
counties_usa = gpd.read_file("bokeh/cb_2018_us_county_20m.shp")
counties_usa.head()
# Out:
#   STATEFP COUNTYFP  COUNTYNS        AFFGEOID  GEOID      NAME LSAD  \
# 0      37      017  01026336  0500000US37017  37017    Bladen   06
# 1      37      167  01025844  0500000US37167  37167    Stanly   06
# 2      39      153  01074088  0500000US39153  39153    Summit   06
# 3      42      113  01213687  0500000US42113  42113  Sullivan   06
# 4      48      459  01384015  0500000US48459  48459    Upshur   06
#
#         ALAND    AWATER                                           geometry
# 0  2265887723  33010866  POLYGON ((-78.90199799999999 34.835268, -78.79...
# 1  1023370459  25242751  POLYGON ((-80.49737499999999 35.202104, -80.29...
# 2  1069181981  18958267  POLYGON ((-81.68698999999999 41.135956, -81.68...
# 3  1165338428   6617028  POLYGON ((-76.81373099999999 41.590034, -76.22...
# 4  1509910100  24878888  POLYGON ((-95.15273999999999 32.660949, -95.15...

# %%
# cast GEOID data type to float64 instead of str for merging
counties_usa["GEOID"] = counties_usa["GEOID"].astype("float64")
# counties_usa.head()

# %%
# set pandas to display all columns in dataframe
pd.set_option("display.max_columns", None)

# merge counties shape file with merged_df on FIPS
merged_df = merged_df.merge(counties_usa[["NAME", "GEOID", "geometry"]], left_on="FIPS", right_on="GEOID")
print("Merged dataframe dimensions: {}".format(merged_df.shape))
merged_df.head()
# Out:
# Merged dataframe dimensions: (15402, 79)
#   STATEFP   STATENS     AFFGEOID GEOID_x STUSPS    NAME_x LSAD        ALAND  \
# 0      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 1      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 2      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 3      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 4      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
#
#        AWATER                                         geometry_x  Unnamed: 0  \
# 0  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1456
# 1  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        4280
# 2  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        7130
# 3  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...       10199
# 4  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...       13269
#
# ...

# %%
# try to visualize a county
merged_df.iloc[0]["geometry_y"]

# %% [markdown]
# # Clean Up Merged Dataframe

# %%
merged_df.head()
# Out:
#   STATEFP   STATENS     AFFGEOID GEOID_x STUSPS    NAME_x LSAD        ALAND  \
# 0      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 1      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 2      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 3      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
# 4      24  01714934  0400000US24      24     MD  Maryland   00  25151100280
#
#        AWATER                                         geometry_x  Unnamed: 0  \
# 0  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        1456
# 1  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        4280
# 2  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...        7130
# 3  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...       10199
# 4  6979966958  (POLYGON ((-76.04621299999999 38.025533, -76.0...       13269
#
# ...

# %%
# drop unnecessary columns
dropMergedCols = ["STATEFP", "STATENS", "GEOID_x", "NAME_x", "LSAD", 
                  "ALAND", "AWATER"]
merged_df = merged_df.drop(columns = dropMergedCols)

# %%
# reorder columns
merged_df = merged_df[['Unnamed: 0', 'ID', 'YEAR_FIPS',
       'YEAR', 'STATE_FIPS', 'COUNTY_FIPS', 'STATE', 'COUNTY', 'FIPS',
       'REP_CANDIDATE', 'DEM_CANDIDATE', 'REP_VOTES', 'DEM_VOTES',
       'COUNTY_TOTALVOTES', 'WINNING_CANDIDATE', 'WINNING_PARTY',
       'WINNING_PARTY_BINARY', 'HOUSE_WINNING_BINARY', 'SENATE_WINNING_BINARY',
       'UNEMPLOYMENT_RATE', 'AVG_WAGE_SALARY', 'AA_FEMALE', 'AA_MALE',
       'BA_FEMALE', 'BA_MALE', 'H_FEMALE', 'H_MALE', 'IA_FEMALE', 'IA_MALE',
       'NA_FEMALE', 'NA_MALE', 'TOT_FEMALE', 'TOT_MALE', 'TOT_POP',
       'WA_FEMALE', 'WA_MALE', 'TOT_POP_LESS19', 'TOT_MALE_LESS19',
       'TOT_FEMALE_LESS19', 'TOT_POP_20to39', 'TOT_MALE_20to39',
       'TOT_FEMALE_20to39', 'TOT_POP_40to59', 'TOT_MALE_40to59',
       'TOT_FEMALE_40to59', 'TOT_POP_Above60', 'TOT_MALE_Above60',
       'TOT_FEMALE_Above60', 'AA_FEMALE%', 'AA_MALE%', 'BA_FEMALE%',
       'BA_MALE%', 'H_FEMALE%', 'H_MALE%', 'IA_FEMALE%', 'IA_MALE%',
       'NA_FEMALE%', 'NA_MALE%', 'WA_FEMALE%', 'WA_MALE%', 'TOT_FEMALE%',
       'TOT_MALE%', 'TOT_POP_LESS19%', 'TOT_POP_20to39%', 'TOT_POP_40to59%',
       'TOT_POP_Above60%','AFFGEOID', 'STUSPS', 'geometry_x','NAME_y', 
        'GEOID_y', 'geometry_y']]

# rename columns
merged_df.columns = ['Unnamed: 0', 'ID', 'YEAR_FIPS', 'YEAR', 'STATE_FIPS', 'COUNTY_FIPS',
       'STATE', 'COUNTY', 'FIPS', 'REP_CANDIDATE', 'DEM_CANDIDATE',
       'REP_VOTES', 'DEM_VOTES', 'COUNTY_TOTALVOTES', 'WINNING_CANDIDATE',
       'WINNING_PARTY', 'WINNING_PARTY_BINARY', 'HOUSE_WINNING_BINARY',
       'SENATE_WINNING_BINARY', 'UNEMPLOYMENT_RATE', 'AVG_WAGE_SALARY',
       'AA_FEMALE', 'AA_MALE', 'BA_FEMALE', 'BA_MALE', 'H_FEMALE', 'H_MALE',
       'IA_FEMALE', 'IA_MALE', 'NA_FEMALE', 'NA_MALE', 'TOT_FEMALE',
       'TOT_MALE', 'TOT_POP', 'WA_FEMALE', 'WA_MALE', 'TOT_POP_LESS19',
       'TOT_MALE_LESS19', 'TOT_FEMALE_LESS19', 'TOT_POP_20to39',
       'TOT_MALE_20to39', 'TOT_FEMALE_20to39', 'TOT_POP_40to59',
       'TOT_MALE_40to59', 'TOT_FEMALE_40to59', 'TOT_POP_Above60',
       'TOT_MALE_Above60', 'TOT_FEMALE_Above60', 'AA_FEMALE%', 'AA_MALE%',
       'BA_FEMALE%', 'BA_MALE%', 'H_FEMALE%', 'H_MALE%', 'IA_FEMALE%',
       'IA_MALE%', 'NA_FEMALE%', 'NA_MALE%', 'WA_FEMALE%', 'WA_MALE%',
       'TOT_FEMALE%', 'TOT_MALE%', 'TOT_POP_LESS19%', 'TOT_POP_20to39%',
       'TOT_POP_40to59%', 'TOT_POP_Above60%', 'AFFGEOID', 'STUSPS',
       'STATE_GEOMETRY', 'COUNTY_ABBRV', 'GEOID', 'COUNTY_GEOMETRY']

# %%
merged_df.head()
# Out:
#    Unnamed: 0     ID  YEAR_FIPS  YEAR  STATE_FIPS  COUNTY_FIPS     STATE  \
# 0        1456   1825  201224001  2012          24            1  Maryland
# 1        4280   4651  201624001  2016          24            1  Maryland
# 2        7130  10399  200024001  2000          24            1  Maryland
# 3       10199  13542  200424001  2004          24            1  Maryland
# 4       13269  16685  200824001  2008          24            1  Maryland
#
#             COUNTY     FIPS   REP_CANDIDATE    DEM_CANDIDATE  REP_VOTES  \
# 0  Allegany County  24001.0     Mitt Romney     Barack Obama    19230.0
# 1  Allegany County  24001.0    Donald Trump  Hillary Clinton    21270.0
# 2  Allegany County  24001.0  George W. Bush          Al Gore    14656.0
# 3  Allegany County  24001.0  George W. Bush       John Kerry    18980.0
# 4  Allegany County  24001.0     John McCain     Barack Obama    18405.0
#
#    DEM_VOTES  COUNTY_TOTALVOTES WINNING_CANDIDATE WINNING_PARTY  \
# ...

# %% [markdown]
# # Plot Bokeh Visualization

# %%
# input GeoJSON source that contains features for plotting
geosource = GeoJSONDataSource(geojson = merged_df.to_json())
# Out:
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# IllegalArgumentException: Operation not supported by GeometryCollection
#
# ...

# %%
# plot state map

# create figure object.
plot = figure(title = 'Test Bokeh Map', 
           plot_height = 600 ,
           plot_width = 950, 
           toolbar_location = 'below',
           tools = "pan, wheel_zoom, box_zoom, reset")
plot.xgrid.grid_line_color = None
plot.ygrid.grid_line_color = None

# add patch renderer to figure.
states = plot.patches('xs','ys', source = geosource,
                   fill_color = None,
                   line_color = "gray", 
                   line_width = 0.25, 
                   fill_alpha = 1)
# create hover tool
plot.add_tools(HoverTool(renderers = [states],
                      tooltips = [('State','@NAME'),
                                ('Votes','@COUNTY_TOTALVOTES')]))

# generates a map on separate tab in browser
show(plot)
