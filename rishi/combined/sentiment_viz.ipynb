# %%
import numpy as np # we will use this later, so import it now
import pandas as pd
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="86220">Loading BokehJS ...</span>
#     </div>

# %%
def plot_chart(rep_df, dem_df, rep_cand, dem_cand, title):
    
    rep_df['date'] = pd.to_datetime(rep_df['date'].astype(str), errors='coerce')
    dem_df['date'] = pd.to_datetime(dem_df['date'].astype(str), errors='coerce')
    
    title = title + '| ' + rep_cand + ': ' + str(round(rep_df["final_score"].mean(), 4)) + ' & ' + \
    dem_cand + ': ' + str(round(dem_df["final_score"].mean(), 4))
    
    p = figure(x_axis_type="datetime", title=title, plot_height=200, plot_width=310)
    p.xgrid.grid_line_color=None
    p.ygrid.grid_line_alpha=0.5
    p.xaxis.axis_label = 'Date'
    p.yaxis.axis_label = 'Sentiment Score'
    
    p.line(rep_df.date, rep_df.final_score, line_color="red", 
           line_width=1, line_alpha=0.6)
    p.circle(rep_df.date, rep_df.final_score, fill_color="red", size=5, color="red")

    p.line(dem_df.date, dem_df.final_score, line_color="blue", 
           line_width=1, line_alpha=0.6)
    p.circle(dem_df.date, dem_df.final_score, fill_color="blue", size=5, color="blue")

    #p.legend.location = "bottom_left"
    #p.legend.label_text_font_size = '8pt'

    p.toolbar.logo = None
    p.toolbar_location = None
    
    return p

# %%
df_trump = pd.read_csv('data2/candidate/2020/trump_combined.csv')
df_biden = pd.read_csv('data2/candidate/2020/biden_combined.csv')

print(df_trump.head())

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data2/candidate/2016/trump_combined.csv')
df_hillary = pd.read_csv('data2/candidate/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data2/candidate/2012/obama_combined.csv')
df_romney = pd.read_csv('data2/candidate/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#          date  final_score
# 0  2020-05-27    52.203955
# 1  2020-05-28    61.544636
# 2  2020-05-29    86.911511
# 3  2020-05-30    74.234574
# 4  2020-05-31    90.373892
#   <div class="bk-root" id="36cd7b99-0570-4b1a-8c73-ecbcde1e015e" data-root-id="130680"></div>

# %%
df_trump_econ = pd.read_csv('data2/economy/trump_combined.csv')
df_biden_econ = pd.read_csv('data2/economy/biden_combined.csv')

plot_econ = plot_chart(df_trump_econ, df_biden_econ, 'Trump', 'Biden', "Economy ")

df_trump_party = pd.read_csv('data2/party/trump_combined.csv')
df_biden_party = pd.read_csv('data2/party/biden_combined.csv')

plot_party = plot_chart(df_trump_party, df_biden_party, 'Trump', 'Biden', "Party ")

df_trump_env = pd.read_csv('data2/environment/trump_combined.csv')
df_biden_env = pd.read_csv('data2/environment/biden_combined.csv')

plot_env = plot_chart(df_trump_env, df_biden_env, 'Trump', 'Biden', "Environ ")

# put all the plots in an HBox
p = row(plot_econ, plot_party, plot_env)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="f98bb418-be2c-42eb-a052-3a88c16f2dde" data-root-id="135185"></div>

# %%
df_trump_health = pd.read_csv('data2/health/trump_combined.csv')
df_biden_health = pd.read_csv('data2/health/biden_combined.csv')

plot_health = plot_chart(df_trump_health, df_biden_health, 'Trump', 'Biden', "Health ")

df_trump_imm = pd.read_csv('data2/immigration/trump_combined.csv')
df_biden_imm = pd.read_csv('data2/immigration/biden_combined.csv')

plot_imm = plot_chart(df_trump_imm, df_biden_imm, 'Trump', 'Biden', "Immi ")

#df_trump_job = pd.read_csv('data2/job/trump_combined.csv')
#df_biden_job = pd.read_csv('data2/job/biden_combined.csv')

#plot_job = plot_chart(df_trump_job, df_biden_job, 'Trump', 'Biden', "Job ")

# put all the plots in an HBox
#p = row(plot_health, plot_imm, plot_job)
p = row(plot_health, plot_imm)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="e3824181-bcd3-448a-96e9-9b874cfe701d" data-root-id="139714"></div>
