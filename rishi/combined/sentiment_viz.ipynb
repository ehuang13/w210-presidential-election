# %%
import numpy as np # we will use this later, so import it now
import pandas as pd
from bokeh.io import output_notebook, show
from bokeh.plotting import figure, output_file, show
from bokeh.layouts import row

# %%
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
def plot_chart(rep_df, dem_df, rep_cand, dem_cand, title):
    
    rep_df['date'] = pd.to_datetime(rep_df['date'].astype(str), errors='coerce')
    dem_df['date'] = pd.to_datetime(dem_df['date'].astype(str), errors='coerce')
    
    title = title + '| ' + rep_cand + ': ' + str(round(rep_df["final_score"].mean(), 4)) + ' & ' + \
    dem_cand + ': ' + str(round(dem_df["final_score"].mean(), 4))
    
    p = figure(x_axis_type="datetime", title=title, plot_height=200, plot_width=310)
    p.xgrid.grid_line_color=None
    p.ygrid.grid_line_alpha=0.5
    p.xaxis.axis_label = 'Date'
    p.yaxis.axis_label = 'Sentiment Score'
    
    p.line(rep_df.date, rep_df.final_score, line_color="red", 
           line_width=1, line_alpha=0.6)
    p.circle(rep_df.date, rep_df.final_score, fill_color="red", size=5, color="red")

    p.line(dem_df.date, dem_df.final_score, line_color="blue", 
           line_width=1, line_alpha=0.6)
    p.circle(dem_df.date, dem_df.final_score, fill_color="blue", size=5, color="blue")

    #p.legend.location = "bottom_left"
    #p.legend.label_text_font_size = '8pt'

    p.toolbar.logo = None
    p.toolbar_location = None
    
    return p

# %%
df_trump = pd.read_csv('data23/candidate/2020/trump_combined.csv')
df_biden = pd.read_csv('data23/candidate/2020/biden_combined.csv')

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data23/candidate/2016/trump_combined.csv')
df_hillary = pd.read_csv('data23/candidate/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data23/candidate/2012/obama_combined.csv')
df_romney = pd.read_csv('data23/candidate/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="b27669a6-d3af-40b6-8553-c528b0b99929" data-root-id="1167"></div>

# %%
df_trump = pd.read_csv('data23/economy/2020/trump_combined.csv')
df_biden = pd.read_csv('data23/economy/2020/biden_combined.csv')

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data23/economy/2016/trump_combined.csv')
df_hillary = pd.read_csv('data23/economy/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data23/economy/2012/obama_combined.csv')
df_romney = pd.read_csv('data23/economy/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="f78c6950-2c64-455a-b69a-e5a1b15feb3a" data-root-id="1879"></div>

# %%
df_trump = pd.read_csv('data23/health/2020/trump_combined.csv')
df_biden = pd.read_csv('data23/health/2020/biden_combined.csv')

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data23/health/2016/trump_combined.csv')
df_hillary = pd.read_csv('data23/health/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data23/health/2012/obama_combined.csv')
df_romney = pd.read_csv('data23/health/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="6fc83728-1180-45a1-8894-a735de5cb71f" data-root-id="2669"></div>

# %%
df_trump = pd.read_csv('data23/environment/2020/trump_combined.csv')
df_biden = pd.read_csv('data23/environment/2020/biden_combined.csv')

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data23/environment/2016/trump_combined.csv')
df_hillary = pd.read_csv('data23/environment/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data23/environment/2012/obama_combined.csv')
df_romney = pd.read_csv('data23/environment/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="87116d1a-ad4a-4d5e-bb67-9136b8ec9e45" data-root-id="3537"></div>

# %%
df_trump = pd.read_csv('data23/immigration/2020/trump_combined.csv')
df_biden = pd.read_csv('data23/immigration/2020/biden_combined.csv')

p_2020_cand = plot_chart(df_trump, df_biden, 'Trump', 'Biden', "2020 ")

df_trump_16 = pd.read_csv('data23/immigration/2016/trump_combined.csv')
df_hillary = pd.read_csv('data23/immigration/2016/hillary_combined.csv')

p_2016_cand = plot_chart(df_trump_16, df_hillary, 'Trump', 'Hillary', "2016 ")

df_obama = pd.read_csv('data23/immigration/2012/obama_combined.csv')
df_romney = pd.read_csv('data23/immigration/2012/romney_combined.csv')

p_2012_cand = plot_chart(df_obama, df_romney, 'Romney', 'Obama', "2012 ")

# put all the plots in an HBox
p = row(p_2020_cand, p_2016_cand, p_2012_cand)

# show the results
show(p)
# Out:
#   <div class="bk-root" id="83e8dd6e-b2a0-4d5f-8155-81499590f2cb" data-root-id="4483"></div>
