# %%
from pandas import DataFrame
import glob
import os
import json
import re

# %%
path = 'data/guardian/2016'

headlines = []

for filename in glob.glob(os.path.join(path, '*.json')):
    with open(filename, 'r') as f: 
        for hd in json.load(f):
            headlines.append(hd)

# %%
df = DataFrame (headlines, columns=['headlines'])
print (df)
# Out:
#                                               headlines
# 0     The Observer view on Congo and the failure of ...
# 1     Trump uses Gettysburg address to threaten to s...
# 2     WikiLeaks praised by Sean Hannity and David Du...
# 3     Houston, we've got a problem: Trump could cost...
# 4     Could Trump really win the election despite po...
# 5     Canadians 4 Trump: tiny but determined group f...
# 6     'I feel used and betrayed': readers affected b...
# 7     Election diary: Trump as Stalin, the future of...
# 8     Trump says countries are turning on US because...
# 9     Jill Stein tweets memorial for gorilla, intern...
# 10    Reince Priebus on Trump campaign hires: 'I go ...
# 11    Libertarian Gary Johnson: crazy election cycle...
# 12    Trump surrogates: Republican's position on imm...
# 13    Welcome to Iowa, where Trump's purple patch co...
# 14    'History will be kind to him': Obama biopic bo...
# 15    Swing states: how changes in the political lan...
# 16    Obama calls Trump's 'rigged' election claims i...
# 17    Poor families hit as UK inflation rises to 1% ...
# 18    What would the Trump TV network actually look ...
# 19    Clinton and Trump virtually tied in Nevada, No...
# 20    There's a reason Trump's rigged election claim...
# 21    Voter intimidation fears follow Trump's call f...
# 22    Why do people dislike Hillary Clinton? The sto...
# 23             Iraqi forces make swift advance on Mosul
# 24    The view from Middletown: a typical US city th...
# 25    Donald Trump's dark warning that dead will ris...
# 26    The view from Middletown: a typical US city th...
# 27    How has Muncie changed over time? Share your p...
# 28    Political unrest in Gabon casts shadow over 20...
# 29    Arabic billboard mocks Donald Trump's fear of ...
# ...                                                 ...
# 1187  Trump predicts demographics make 2016 'last el...
# 1188  Trump interview broadcast on Russian propagand...
# 1189  Macron: block UK financial firms from selling ...
# 1190  Trump's been paying politicians for years. Now...
# 1191  Beware the walking dead: the San Diego Charger...
# 1192  Giuliani falsely claims Trump disavowed birthe...
# 1193  'Stand up to hate': Clinton makes urgent appea...
# 1194  On terrorism, cooler heads have better policy....
# 1195  Chris Christie got Bridgegate updates as it ha...
# 1196  Donald Trump upsets Les Misérables creators by...
# 1197  Hillary Clinton: Trump's rhetoric about terror...
# 1198             Suspect named in New York City bombing
# 1199  As Trump slips into red with Latinos, Democrat...
# 1200  Russia stays loyal to Kremlin in election with...
# 1201  Malcolm Turnbull urges US Congress to ratify T...
# 1202  Trump campaign doubles spending but staff is a...
# 1203  Third parties aren't 'spoilers'. They're at th...
# 1204  'If you fight fire with fire, everyone burns':...
# 1205  Billy Bragg and Joe Henry review – just the ti...
# 1206  If US national parks are to continue to thrive...
# 1207  Jessica Alba: ‘With this new film I wanted to ...
# 1208  The death of neoliberalism and the crisis in w...
# 1209  Rather than offer clarity, Brexit has sown con...
# 1210  Donald Trump tours flood-ravaged Louisiana wit...
# 1211  Trump campaign chairman Paul Manafort resigns ...
# 1212  Pat Hickey allegations remind world that IOC i...
# 1213  US voters largely uninfluenced by meet-and-gre...
# 1214  Ukrainians saw Paul Manafort's political impac...
# 1215  Le comeback kid? Sarkozy shapes up for preside...
# 1216  Donald Trump tries out a new campaign tactic: ...
#
# [1217 rows x 1 columns]

# %%
# Remove punctuation
df['headlines_processed'] = df['headlines'].map(lambda x: re.sub('[,\.!?]', '', x))
# Convert the titles to lowercase
df['headlines_processed'] = df['headlines_processed'].map(lambda x: x.lower())
# Print out the first rows of papers
df['headlines_processed'].head()
# Out:
# 0    the observer view on congo and the failure of ...
# 1    trump uses gettysburg address to threaten to s...
# 2    wikileaks praised by sean hannity and david du...
# 3    houston we've got a problem: trump could cost ...
# 4    could trump really win the election despite po...
# Name: headlines_processed, dtype: object

# %%
# Import the wordcloud library
from wordcloud import WordCloud
# Join the different processed titles together.
long_string = ','.join(list(df['headlines_processed'].values))
# Create a WordCloud object
wordcloud = WordCloud(background_color="white", max_words=5000, contour_width=3, contour_color='steelblue')
# Generate a word cloud
wordcloud.generate(long_string)
# Visualize the word cloud
wordcloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x200 at 0x7F1C74F80E48>

# %% [markdown]
# ### Prepare text for LDA Analysis

# %%
# Load the library with the CountVectorizer method
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline
# Helper function
def plot_20_most_common_words(count_data, count_vectorizer):
    import matplotlib.pyplot as plt
    words = count_vectorizer.get_feature_names()
    total_counts = np.zeros(len(words))
    for t in count_data:
        total_counts+=t.toarray()[0]
    
    count_dict = (zip(words, total_counts))
    count_dict = sorted(count_dict, key=lambda x:x[1], reverse=True)[0:20]
    words = [w[0] for w in count_dict]
    counts = [w[1] for w in count_dict]
    x_pos = np.arange(len(words)) 
    
    plt.figure(2, figsize=(15, 15/1.6180))
    plt.subplot(title='20 most common words')
    sns.set_context("notebook", font_scale=1.25, rc={"lines.linewidth": 2.5})
    sns.barplot(x_pos, counts, palette='husl')
    plt.xticks(x_pos, words, rotation=90) 
    plt.xlabel('words')
    plt.ylabel('counts')
    plt.show()
# Initialise the count vectorizer with the English stop words
count_vectorizer = CountVectorizer(stop_words='english')
# Fit and transform the processed titles
count_data = count_vectorizer.fit_transform(df['headlines_processed'])
# Visualise the 10 most common words
plot_20_most_common_words(count_data, count_vectorizer)

# %%
import warnings
warnings.simplefilter("ignore", DeprecationWarning)
# Load the LDA model from sk-learn
from sklearn.decomposition import LatentDirichletAllocation as LDA
 
# Helper function
def print_topics(model, count_vectorizer, n_top_words):
    words = count_vectorizer.get_feature_names()
    for topic_idx, topic in enumerate(model.components_):
        print("\nTopic #%d:" % topic_idx)
        print(" ".join([words[i]
                        for i in topic.argsort()[:-n_top_words - 1:-1]]))
        
# Tweak the two parameters below
number_topics = 5
number_words = 10
# Create and fit the LDA model
lda = LDA(n_components=number_topics, n_jobs=-1)
lda.fit(count_data)
# Print the topics found by the LDA model
print("Topics found via LDA:")
print_topics(lda, count_vectorizer, number_words)
# Out:
# Topics found via LDA:
#
# Topic #0:
# trump election donald clinton says happened new campaign view time
#
# Topic #1:
# trump president happened clinton says vote brexit claims like sexual
#
# Topic #2:
# clinton trump happened debate election hillary presidential 2016 vote donald
#
# Topic #3:
# trump clinton hillary donald debate presidential election voters campaign obama
#
# Topic #4:
# trump election clinton presidential vote donald view state time debate

# %%
# %%time
from pyLDAvis import sklearn as sklearn_lda
import pickle 
import pyLDAvis
LDAvis_data_filepath = os.path.join('./ldavis_prepared_'+str(number_topics))
# # this is a bit time consuming - make the if statement True
# # if you want to execute visualization prep yourself
if 1 == 1:
    LDAvis_prepared = sklearn_lda.prepare(lda, count_data, count_vectorizer)
    with open(LDAvis_data_filepath, 'w') as f:
        pickle.dump(LDAvis_prepared, f)
        
# load the pre-prepared pyLDAvis data from disk
with open(LDAvis_data_filepath) as f:
    LDAvis_prepared = pickle.load(f)

pyLDAvis.save_html(LDAvis_prepared, './ldavis_prepared_'+ str(number_topics) +'.html')
# Out:
# /home/rmh/anaconda3/lib/python3.7/site-packages/pyLDAvis/_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <timed exec> in <module>
#
# TypeError: write() argument must be str, not bytes
